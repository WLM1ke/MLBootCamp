# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import time
import keras
from keras import layers
from keras import models
from keras import optimizers
from keras import callbacks
from keras import backend as K
from sklearn import model_selection
import pathlib

COORDINATES = ["Xmin", "Ymin", "Xmax", "Ymax"]
MAX_TRAIN_FORECASTS = 14
# Out:
# Using TensorFlow backend.

# %%
votes = pd.read_csv("../raw/train_data.csv").set_index("itemId")

# %%
answers = pd.read_csv("../raw/train_answers.csv").set_index("itemId")
answers.columns = COORDINATES

# %%
votes_test = pd.read_csv("../raw/test_data.csv").set_index("itemId")

# %%
def yield_batch(batch_size):
    while True:
        item_id = np.random.choice(votes.index, 1)
        forecasts = votes.loc[item_id].set_index("userId")
        x = np.zeros((1, len(forecasts), 4),)
        y = np.zeros((1, 4))
        
        x[0] = forecasts.sample(len(forecasts))
        y[0] = answers.loc[item_id]
        yield x, y

# %%
def intersection_over_union(boxes_pred, boxes_true):

    x_min = K.stack([boxes_pred[:, 0], boxes_true[:, 0]], axis=-1)
    y_min = K.stack([boxes_pred[:, 1], boxes_true[:, 1]], axis=-1)
    x_max = K.stack([boxes_pred[:, 2], boxes_true[:, 2]], axis=-1)
    y_max = K.stack([boxes_pred[:, 3], boxes_true[:, 3]], axis=-1)

    x_min = K.max(x_min, axis=-1)
    y_min = K.max(y_min, axis=-1)
    x_max = K.min(x_max, axis=-1)
    y_max = K.min(y_max, axis=-1)

    zeros = K.zeros_like(x_max)

    x_inter = K.stack([zeros, x_max - x_min], axis=-1)
    y_inter = K.stack([zeros, y_max - y_min], axis=-1)

    x_inter = K.max(x_inter, axis=-1)
    y_inter = K.max(y_inter, axis=-1)
    inter_area = x_inter * y_inter
    
    area_pred = (K.max(K.stack([zeros, boxes_pred[:, 2] - boxes_pred[:, 0]], axis=-1), axis=-1) * 
                 K.max(K.stack([zeros, boxes_pred[:, 3] - boxes_pred[:, 1]], axis=-1), axis=-1))
    area_true = (K.max(K.stack([zeros, boxes_true[:, 2] - boxes_true[:, 0]], axis=-1), axis=-1) * 
                 K.max(K.stack([zeros, boxes_true[:, 3] - boxes_true[:, 1]], axis=-1), axis=-1))

    iou = inter_area / (area_pred + area_true - inter_area + K.epsilon())
    
    return -K.mean(iou, axis=-1)

# %%
def make_model(filters):
    K.clear_session()
    
    y = x = layers.Input(shape=(None, 4))
    y_rez = layers.GlobalAveragePooling1D()(y)
    
    y = layers.Bidirectional(layers.LSTM(
        units=filters * 4,
        return_sequences=False
    ))(y)
    # y = layers.GlobalAveragePooling1D()(y)
    
    y = layers.Dense(
        units=filters * 4,
        activation="relu"
    )(y)
    y = layers.Dense(
        units=filters * 2,
        activation="relu"
    )(y)
    y = layers.Dense(
        units=filters,
        activation="relu"
    )(y)
    y = layers.Dense(
        units=filters // 2,
        activation="relu"
    )(y)
    y = layers.Dense(
        units=4,
        activation=None
    )(y)
    y = layers.add([y_rez, y])
    y = layers.Activation("relu")(y)
    
    model = models.Model(inputs=x, outputs=y)
    model.summary()
    return model

# %%
def train_model(batch_size, units, epochs=100):
    model = make_model(units)
    
    lr=0.002
    
    model.compile(optimizer=optimizers.Nadam(lr=lr, beta_1=0.9, beta_2=0.999, epsilon=None, schedule_decay=0.004),
                  loss=intersection_over_union,
                  metrics=None
    )
    cb = [
        callbacks.ModelCheckpoint("../processed/model.h5", monitor="loss", verbose=1, save_best_only=True),
        callbacks.EarlyStopping(monitor='loss', patience=epochs // 10, verbose=10),
        callbacks.ReduceLROnPlateau(monitor='loss', factor=0.8, patience=1, verbose=1)
    ]
    rez = model.fit_generator(
        yield_batch(batch_size),
        steps_per_epoch=1000 // batch_size,
        epochs=epochs,
        callbacks=cb,
        # validation_data=[make_feat(votes), answers],
    )
    return rez, model

# %%
rez, model = train_model(1, 32)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, 4)      0
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 256)          136192      input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          32896       bidirectional_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 32)           2080        dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 16)           528         dense_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 4)            0           input_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 4)            68          dense_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 4)            0           global_average_pooling1d_1[0][0]
#                                                                  dense_5[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 4)            0           add_1[0][0]
# ==================================================================================================
# Total params: 180,020
# Trainable params: 180,020
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 1000/1000 [==============================] - 9s 9ms/step - loss: -0.5099
#
# Epoch 00001: loss improved from inf to -0.50990, saving model to ../processed/model.h5
# Epoch 2/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5091
#
# Epoch 00002: loss did not improve from -0.50990
#
# Epoch 00002: ReduceLROnPlateau reducing learning rate to 0.001600000075995922.
# Epoch 3/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5210
#
# Epoch 00003: loss improved from -0.50990 to -0.52098, saving model to ../processed/model.h5
# Epoch 4/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5178
#
# Epoch 00004: loss did not improve from -0.52098
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0012800000607967378.
# Epoch 5/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5329
#
# Epoch 00005: loss improved from -0.52098 to -0.53291, saving model to ../processed/model.h5
# Epoch 6/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5413
#
# Epoch 00006: loss improved from -0.53291 to -0.54127, saving model to ../processed/model.h5
# Epoch 7/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5347
#
# Epoch 00007: loss did not improve from -0.54127
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0010240000672638416.
# Epoch 8/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5428
#
# Epoch 00008: loss improved from -0.54127 to -0.54279, saving model to ../processed/model.h5
# Epoch 9/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5383
#
# Epoch 00009: loss did not improve from -0.54279
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0008192000910639763.
# Epoch 10/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5406
#
# Epoch 00010: loss did not improve from -0.54279
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0006553600542247295.
# Epoch 11/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5431
#
# Epoch 00011: loss improved from -0.54279 to -0.54305, saving model to ../processed/model.h5
# Epoch 12/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5309
#
# Epoch 00012: loss did not improve from -0.54305
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0005242880433797836.
# Epoch 13/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5452
#
# Epoch 00013: loss improved from -0.54305 to -0.54524, saving model to ../processed/model.h5
# Epoch 14/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5466
#
# Epoch 00014: loss improved from -0.54524 to -0.54658, saving model to ../processed/model.h5
# Epoch 15/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5472
#
# Epoch 00015: loss improved from -0.54658 to -0.54718, saving model to ../processed/model.h5
# Epoch 16/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5365
#
# Epoch 00016: loss did not improve from -0.54718
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0004194304347038269.
# Epoch 17/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5452
#
# Epoch 00017: loss did not improve from -0.54718
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0003355443477630615.
# Epoch 18/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5422
#
# Epoch 00018: loss did not improve from -0.54718
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.00026843547821044924.
# Epoch 19/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5511
#
# Epoch 00019: loss improved from -0.54718 to -0.55110, saving model to ../processed/model.h5
# Epoch 20/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5543
#
# Epoch 00020: loss improved from -0.55110 to -0.55429, saving model to ../processed/model.h5
# Epoch 21/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5343
#
# Epoch 00021: loss did not improve from -0.55429
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.00021474838722497226.
# Epoch 22/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5532
#
# Epoch 00022: loss did not improve from -0.55429
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.00017179871210828426.
# Epoch 23/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5562
#
# Epoch 00023: loss improved from -0.55429 to -0.55618, saving model to ../processed/model.h5
# Epoch 24/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5453
#
# Epoch 00024: loss did not improve from -0.55618
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.00013743897434324027.
# Epoch 25/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5471
#
# Epoch 00025: loss did not improve from -0.55618
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.00010995117481797934.
# Epoch 26/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5490
#
# Epoch 00026: loss did not improve from -0.55618
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 8.796093752607704e-05.
# Epoch 27/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5518
#
# Epoch 00027: loss did not improve from -0.55618
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 7.036874885670842e-05.
# Epoch 28/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5477
#
# Epoch 00028: loss did not improve from -0.55618
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 5.629499792121351e-05.
# Epoch 29/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5483
#
# Epoch 00029: loss did not improve from -0.55618
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 4.50359977548942e-05.
# Epoch 30/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5576
#
# Epoch 00030: loss improved from -0.55618 to -0.55763, saving model to ../processed/model.h5
# Epoch 31/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5437
#
# Epoch 00031: loss did not improve from -0.55763
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 3.602879878599197e-05.
# Epoch 32/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5543
#
# Epoch 00032: loss did not improve from -0.55763
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 2.8823039610870185e-05.
# Epoch 33/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5503
#
# Epoch 00033: loss did not improve from -0.55763
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 2.3058432270772757e-05.
# Epoch 34/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5564
#
# Epoch 00034: loss did not improve from -0.55763
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 1.8446745525579902e-05.
# Epoch 35/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5457
#
# Epoch 00035: loss did not improve from -0.55763
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 1.475739700254053e-05.
# Epoch 36/100
# 1000/1000 [==============================] - 7s 7ms/step - loss: -0.5526
#
# Epoch 00036: loss did not improve from -0.55763
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 1.1805917893070728e-05.
# Epoch 37/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5515
#
# Epoch 00037: loss did not improve from -0.55763
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 9.444734314456583e-06.
# Epoch 38/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5426
#
# Epoch 00038: loss did not improve from -0.55763
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 7.555787306046113e-06.
# Epoch 39/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5428
#
# Epoch 00039: loss did not improve from -0.55763
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 6.044629844836891e-06.
# Epoch 40/100
# 1000/1000 [==============================] - 8s 8ms/step - loss: -0.5494
#
# Epoch 00040: loss did not improve from -0.55763
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 4.8357040213886655e-06.
# Epoch 00040: early stopping

# %%
pd.DataFrame(rez.history)[["loss", "val_loss"]].plot(figsize=(16, 8))

# %%
def make_forecast(model):
    subdir = time.strftime('%Y-%m-%d_%H-%M')
    path = pathlib.Path(f"../processed/{subdir}")
    path.mkdir(exist_ok=True)
    feat = make_feat(votes_test)
    df = model.predict(feat)
    df = pd.DataFrame(df, index=feat.index)
    df.to_csv(path / "_sub_full.csv", header=False)
    # path.rename(path.parent / f"{subdir}-{score:0.1f}")

# %%
make_forecast(model)
