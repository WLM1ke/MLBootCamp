# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import time
import catboost
from sklearn import model_selection
import pathlib

COORDINATES = ["Xmin", "Ymin", "Xmax", "Ymax"]

# %%
def area(box):
    return (box[2] - box[0]) * (box[3] - box[1])


def intersection_over_union(boxes):
    assert(len(boxes) == 8)
    boxA = boxes[:4].values
    boxB = boxes[4:].values
    
    boxAArea = area(boxA)
    boxBArea = area(boxB)
    
    if (boxAArea == 0 or boxBArea == 0):
        return 0
        
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])

    interArea = max(0, xB - xA) * max(0, yB - yA)

    
    iou = interArea / float(boxAArea + boxBArea - interArea)
    return iou

# %%
votes = pd.read_csv("../raw/train_data.csv").set_index("itemId")

# %%
answers = pd.read_csv("../raw/train_answers.csv").set_index("itemId")

# %%
votes_test = pd.read_csv("../raw/test_data.csv").set_index("itemId")

# %%
def make_feat(df):
    counts = df[["userId"]].groupby("itemId").count()
    feat = df.groupby("itemId")[COORDINATES].agg(["min", "max", "std", "median", "mean"])
    feat["count"] = counts
    return feat

# %%
SEED = 284702
FOLDS = 5
ITERATIONS = 20000
LEARNING_RATE = 0.5

CLF_PARAMS = dict(
    loss_function="MAE",
    eval_metric=None,
    random_state=SEED,
    depth=6,
    od_type="Iter",
    od_wait=ITERATIONS // 10,
    verbose=ITERATIONS // 20,
    learning_rate=LEARNING_RATE,
    iterations=ITERATIONS,
    allow_writing_files=False
)

# %%
def train_catboost(x_train, y_train, x_test, name, subdir):
    print(f"Прогнозирование {name}")
    pool_test = catboost.Pool(
            data=x_test,
            label=None,
            cat_features=None,
            weight=None
        )
    y_oof = pd.Series(0, index=x_train.index, name=f"oof_{name}")
    y_pred = pd.Series(0, index=x_test.index, name=name)
    trees = []
    scores = []

    for index_train, index_valid in model_selection.KFold(FOLDS, shuffle=True, random_state=SEED).split(x_train):
        pool_train = catboost.Pool(
            data=x_train.iloc[index_train],
            label=y_train.iloc[index_train],
            cat_features=None,
            weight=None
        )
        pool_valid = catboost.Pool(
            data=x_train.iloc[index_valid],
            label=y_train.iloc[index_valid],
            cat_features=None,
            weight=None
        )
        clf = catboost.CatBoostRegressor(**CLF_PARAMS)
        clf.fit(
            X=pool_train,
            eval_set=[pool_valid],
        )
        trees.append(clf.tree_count_)
        scores.append(clf.best_score_['validation']['MAE'])
        y_oof.iloc[index_valid] = clf.predict(pool_valid)
        y_pred += clf.predict(pool_test) / FOLDS

    print(f"Количество деревьев: {sorted(trees)}")
    print(f"Среднее количество деревьев: {np.mean(trees):.0f} +/- {np.std(trees):.0f}")
    print(f"MAE на кроссвалидации: " + str(np.round(sorted(scores), 5)))
    print(f"MAE среднее: {np.mean(scores):0.3f} +/- {np.std(scores):0.2f}")

    y_oof.to_csv(f"../processed/{subdir}/oof_{name}.csv", header=True)
    y_pred.to_csv(f"../processed/{subdir}/sub_{name}.csv", header=True)
    return y_pred, np.mean(scores)

# %%
def make_forecast():
    subdir = time.strftime('%Y-%m-%d_%H-%M')
    path = pathlib.Path(f"../processed/{subdir}")
    path.mkdir()
    x_train = make_feat(votes)
    y_train = answers.loc[x_train.index]
    x_test = make_feat(votes_test)
    scores = []
    rez = []
    for name in COORDINATES:
        y_pred, score = train_catboost(x_train, y_train[f"{name}_true"], x_test, name, subdir)
        scores.append(score)
        rez.append(y_pred)
    pd.concat(rez, axis=1).to_csv(path / "_sub_full.csv", header=False)
    path.rename(path.parent / f"{subdir}-{np.mean(scores):0.1f}")

# %%
make_forecast()
# Out:
# Прогнозирование Xmin
# 0:	learn: 84.3637411	test: 76.6505328	best: 76.6505328 (0)	total: 7.32ms	remaining: 2m 26s
# 1000:	learn: 42.3355144	test: 45.1991929	best: 45.1991929 (1000)	total: 7.51s	remaining: 2m 22s
# 2000:	learn: 36.7080378	test: 45.0026379	best: 44.8625122 (1500)	total: 14.9s	remaining: 2m 13s
# 3000:	learn: 32.7224531	test: 45.4627290	best: 44.8625122 (1500)	total: 22.2s	remaining: 2m 5s
# Stopped by overfitting detector  (2000 iterations wait)
#
# bestTest = 44.86251216
# bestIteration = 1500
#
# Shrink model to first 1501 iterations.
# 0:	learn: 80.8744827	test: 90.5627668	best: 90.5627668 (0)	total: 7.4ms	remaining: 2m 27s
# 1000:	learn: 39.8712803	test: 54.9443583	best: 54.9443583 (1000)	total: 7.34s	remaining: 2m 19s
# 2000:	learn: 34.4586841	test: 52.9336084	best: 52.9336084 (2000)	total: 14.8s	remaining: 2m 12s
# 3000:	learn: 30.5026433	test: 52.4763524	best: 52.4680139 (2985)	total: 22.3s	remaining: 2m 6s
# 4000:	learn: 27.2498395	test: 52.2046414	best: 52.2022569 (3997)	total: 29.5s	remaining: 1m 57s
# 5000:	learn: 24.5168270	test: 51.9281953	best: 51.9281953 (5000)	total: 36.7s	remaining: 1m 50s
# 6000:	learn: 22.2363107	test: 51.7375126	best: 51.7362740 (5999)	total: 44.2s	remaining: 1m 43s
# 7000:	learn: 20.3452829	test: 51.6016675	best: 51.5727059 (6755)	total: 51.3s	remaining: 1m 35s
# 8000:	learn: 18.6883160	test: 51.4801816	best: 51.4772517 (7999)	total: 58.7s	remaining: 1m 28s
# 9000:	learn: 17.2170551	test: 51.3818054	best: 51.3618798 (8818)	total: 1m 5s	remaining: 1m 20s
# 10000:	learn: 15.8693921	test: 51.3840344	best: 51.3618798 (8818)	total: 1m 13s	remaining: 1m 13s
# 11000:	learn: 14.7030584	test: 51.3661477	best: 51.3386634 (10543)	total: 1m 21s	remaining: 1m 6s
# 12000:	learn: 13.6118140	test: 51.3706087	best: 51.3386634 (10543)	total: 1m 28s	remaining: 59.2s
# Stopped by overfitting detector  (2000 iterations wait)
#
# bestTest = 51.33866335
# bestIteration = 10543
#
# Shrink model to first 10544 iterations.
# 0:	learn: 84.9309343	test: 74.3885053	best: 74.3885053 (0)	total: 9.29ms	remaining: 3m 5s
# 1000:	learn: 43.5648705	test: 40.4306473	best: 40.4306473 (1000)	total: 7.51s	remaining: 2m 22s
# 2000:	learn: 37.8052383	test: 40.2605688	best: 40.0486109 (1257)	total: 14.7s	remaining: 2m 12s
# 3000:	learn: 33.7772865	test: 40.8470192	best: 40.0486109 (1257)	total: 22s	remaining: 2m 4s
# Stopped by overfitting detector  (2000 iterations wait)
#
# bestTest = 40.04861093
# bestIteration = 1257
#
# Shrink model to first 1258 iterations.
# 0:	learn: 82.8751265	test: 82.6219142	best: 82.6219142 (0)	total: 10.5ms	remaining: 3m 30s
# 1000:	learn: 41.9804927	test: 48.6670327	best: 48.6670327 (1000)	total: 7.62s	remaining: 2m 24s
# 2000:	learn: 37.2122958	test: 47.5404322	best: 47.5396855 (1999)	total: 14.9s	remaining: 2m 13s
# 3000:	learn: 33.2767519	test: 47.3130476	best: 47.3130476 (3000)	total: 22.1s	remaining: 2m 5s
# 4000:	learn: 30.0136530	test: 47.1748024	best: 47.1748024 (4000)	total: 29.4s	remaining: 1m 57s
# 5000:	learn: 27.2948741	test: 47.1503714	best: 47.1328746 (4137)	total: 36.6s	remaining: 1m 49s
# 6000:	learn: 24.9932852	test: 47.1978871	best: 47.1328746 (4137)	total: 43.9s	remaining: 1m 42s
# Stopped by overfitting detector  (2000 iterations wait)
#
# bestTest = 47.13287456
# bestIteration = 4137
#
# Shrink model to first 4138 iterations.
# 0:	learn: 81.0634093	test: 89.9224184	best: 89.9224184 (0)	total: 7.8ms	remaining: 2m 35s
# 1000:	learn: 40.3321401	test: 52.9202270	best: 52.9202270 (1000)	total: 7.57s	remaining: 2m 23s
# 2000:	learn: 34.9078632	test: 52.4935916	best: 52.4884576 (1997)	total: 15.2s	remaining: 2m 16s
# 3000:	learn: 30.9661357	test: 52.5614950	best: 52.4128472 (2197)	total: 22.4s	remaining: 2m 6s
# 4000:	learn: 27.9339095	test: 52.9508601	best: 52.4128472 (2197)	total: 29.6s	remaining: 1m 58s
# Stopped by overfitting detector  (2000 iterations wait)
#
# bestTest = 52.41284723
# bestIteration = 2197
#
# Shrink model to first 2198 iterations.
# Количество деревьев: [1258, 1501, 2198, 4138, 10544]
# Среднее количество деревьев: 3928 +/- 3459
# MAE на кроссвалидации: [40.04861 44.86251 47.13287 51.33866 52.41285]
# MAE среднее: 47.159 +/- 4.49
# Прогнозирование Ymin
# 0:	learn: 631.2822815	test: 608.6221315	best: 608.6221315 (0)	total: 7.34ms	remaining: 2m 26s
# 1000:	learn: 392.7893362	test: 372.0933388	best: 372.0933388 (1000)	total: 4.74s	remaining: 1m 30s
# 2000:	learn: 200.3322427	test: 188.8012106	best: 188.8012106 (2000)	total: 12.4s	remaining: 1m 51s
# 3000:	learn: 85.8201683	test: 85.1785370	best: 85.1785370 (3000)	total: 19.7s	remaining: 1m 51s
# 4000:	learn: 38.2995004	test: 46.3590226	best: 46.3590226 (4000)	total: 27.1s	remaining: 1m 48s
# 5000:	learn: 26.1375942	test: 38.7420489	best: 38.7420489 (5000)	total: 34.4s	remaining: 1m 43s
# 6000:	learn: 22.9190273	test: 37.2170557	best: 37.2170557 (6000)	total: 42.2s	remaining: 1m 38s
# 7000:	learn: 20.1091719	test: 35.9400500	best: 35.9357143 (6998)	total: 49.4s	remaining: 1m 31s
# 8000:	learn: 18.1660442	test: 35.9789940	best: 35.8623590 (7490)	total: 56.6s	remaining: 1m 24s
# 9000:	learn: 16.4006264	test: 36.1056977	best: 35.8623590 (7490)	total: 1m 3s	remaining: 1m 17s
# Stopped by overfitting detector  (2000 iterations wait)
#
# bestTest = 35.86235904
# bestIteration = 7490
#
# Shrink model to first 7491 iterations.
# 0:	learn: 624.5592133	test: 635.4418042	best: 635.4418042 (0)	total: 7.67ms	remaining: 2m 33s
# 1000:	learn: 386.2689797	test: 398.0037909	best: 398.0037909 (1000)	total: 4.23s	remaining: 1m 20s
# 2000:	learn: 195.2959235	test: 206.4659486	best: 206.4659486 (2000)	total: 11.5s	remaining: 1m 43s
# 3000:	learn: 81.9592176	test: 94.1496974	best: 94.1496974 (3000)	total: 18.8s	remaining: 1m 46s
# 4000:	learn: 38.4065039	test: 51.0067312	best: 51.0067312 (4000)	total: 26s	remaining: 1m 44s
# 5000:	learn: 25.8649661	test: 40.1577140	best: 40.1577140 (5000)	total: 33.3s	remaining: 1m 39s
# 6000:	learn: 21.9154538	test: 39.5832586	best: 39.5799980 (5997)	total: 40.5s	remaining: 1m 34s
# 7000:	learn: 19.0290569	test: 39.5706670	best: 39.4294430 (6356)	total: 47.7s	remaining: 1m 28s
# 8000:	learn: 17.1641847	test: 39.9747629	best: 39.4294430 (6356)	total: 55.1s	remaining: 1m 22s
# Stopped by overfitting detector  (2000 iterations wait)
#
# bestTest = 39.429443
# bestIteration = 6356
#
# Shrink model to first 6357 iterations.
# 0:	learn: 628.3788259	test: 620.2036901	best: 620.2036901 (0)	total: 7.44ms	remaining: 2m 28s
# 1000:	learn: 389.9236052	test: 383.1780747	best: 383.1780747 (1000)	total: 4.63s	remaining: 1m 27s
# 2000:	learn: 198.0215590	test: 198.0128761	best: 198.0128761 (2000)	total: 12.5s	remaining: 1m 52s
# 3000:	learn: 83.2853809	test: 91.4883016	best: 91.4883016 (3000)	total: 20.5s	remaining: 1m 56s
# 4000:	learn: 37.3897259	test: 48.9312598	best: 48.9312598 (4000)	total: 27.8s	remaining: 1m 51s
# 5000:	learn: 26.4218583	test: 38.5403053	best: 38.5393154 (4999)	total: 35.2s	remaining: 1m 45s
# 6000:	learn: 22.8006292	test: 37.1769634	best: 37.1746106 (5998)	total: 42.5s	remaining: 1m 39s
# 7000:	learn: 20.3359356	test: 36.3283445	best: 36.3097338 (6934)	total: 50s	remaining: 1m 32s
# 8000:	learn: 18.5573792	test: 36.2775042	best: 36.2767150 (7996)	total: 57.3s	remaining: 1m 25s
# 9000:	learn: 17.0145507	test: 36.2041329	best: 36.1636644 (8579)	total: 1m 4s	remaining: 1m 19s
# 10000:	learn: 15.6379240	test: 36.0785615	best: 36.0701531 (9982)	total: 1m 12s	remaining: 1m 12s
# 11000:	learn: 14.4590406	test: 36.1627941	best: 36.0701531 (9982)	total: 1m 19s	remaining: 1m 5s
# 12000:	learn: 13.4557587	test: 36.0635180	best: 36.0593134 (11998)	total: 1m 26s	remaining: 57.9s
# 13000:	learn: 12.4411360	test: 36.0189423	best: 35.9801685 (12816)	total: 1m 34s	remaining: 50.8s
# 14000:	learn: 11.5728097	test: 36.0695172	best: 35.9728133 (13160)	total: 1m 41s	remaining: 43.5s
# 15000:	learn: 10.7732993	test: 36.0882262	best: 35.9728133 (13160)	total: 1m 48s	remaining: 36.3s
# Stopped by overfitting detector  (2000 iterations wait)
#
# bestTest = 35.97281331
# bestIteration = 13160
#
# Shrink model to first 13161 iterations.
# 0:	learn: 625.1181332	test: 633.3017162	best: 633.3017162 (0)	total: 8ms	remaining: 2m 39s
# 1000:	learn: 386.4512704	test: 399.4541808	best: 399.4541808 (1000)	total: 4.18s	remaining: 1m 19s
# 2000:	learn: 194.7456796	test: 212.2052941	best: 212.2052941 (2000)	total: 12s	remaining: 1m 48s
# 3000:	learn: 81.8263515	test: 96.5998159	best: 96.5998159 (3000)	total: 19.6s	remaining: 1m 51s
# 4000:	learn: 37.2772022	test: 50.4438913	best: 50.4438913 (4000)	total: 27.1s	remaining: 1m 48s
# 5000:	learn: 25.8432286	test: 41.9518718	best: 41.9518718 (5000)	total: 34.5s	remaining: 1m 43s
# 6000:	learn: 22.4734587	test: 40.9982327	best: 40.9948449 (5991)	total: 42s	remaining: 1m 37s
# 7000:	learn: 19.4820602	test: 40.2268867	best: 40.2216962 (6969)	total: 49.6s	remaining: 1m 32s
# 8000:	learn: 17.6052455	test: 40.1449840	best: 40.1252593 (7832)	total: 57s	remaining: 1m 25s
# 9000:	learn: 16.0554806	test: 40.0658837	best: 40.0354366 (8492)	total: 1m 4s	remaining: 1m 18s
# 10000:	learn: 14.6231287	test: 40.1342563	best: 40.0354366 (8492)	total: 1m 12s	remaining: 1m 12s
# Stopped by overfitting detector  (2000 iterations wait)
#
# bestTest = 40.03543655
# bestIteration = 8492
#
# Shrink model to first 8493 iterations.
# 0:	learn: 624.3892528	test: 636.2415968	best: 636.2415968 (0)	total: 10.9ms	remaining: 3m 37s
# 1000:	learn: 386.4043786	test: 398.3192805	best: 398.3192805 (1000)	total: 4.38s	remaining: 1m 23s
# 2000:	learn: 195.5595253	test: 205.4429743	best: 205.4429743 (2000)	total: 11.7s	remaining: 1m 45s
# 3000:	learn: 82.9361449	test: 92.1828001	best: 92.1828001 (3000)	total: 19.1s	remaining: 1m 48s
# 4000:	learn: 37.3984503	test: 51.3147360	best: 51.3147360 (4000)	total: 26.3s	remaining: 1m 45s
# 5000:	learn: 25.6655659	test: 42.6368529	best: 42.6368529 (5000)	total: 33.6s	remaining: 1m 40s
# 6000:	learn: 22.6158431	test: 41.3892688	best: 41.3892688 (6000)	total: 41.3s	remaining: 1m 36s
# 7000:	learn: 19.7292814	test: 39.8553243	best: 39.8542750 (6999)	total: 48.6s	remaining: 1m 30s
# 8000:	learn: 17.9667479	test: 39.4756365	best: 39.4755243 (7999)	total: 55.7s	remaining: 1m 23s
# 9000:	learn: 16.4569142	test: 39.2533529	best: 39.2498812 (8995)	total: 1m 3s	remaining: 1m 17s
# 10000:	learn: 15.0976378	test: 39.0345936	best: 39.0298921 (9996)	total: 1m 10s	remaining: 1m 10s
# 11000:	learn: 13.9011922	test: 38.8182045	best: 38.8118532 (10996)	total: 1m 17s	remaining: 1m 3s
# 12000:	learn: 12.8107945	test: 38.6100357	best: 38.6100357 (12000)	total: 1m 25s	remaining: 57s
# 13000:	learn: 11.8496858	test: 38.4995912	best: 38.4987240 (12564)	total: 1m 33s	remaining: 50.1s
# 14000:	learn: 11.0151884	test: 38.5094280	best: 38.4707942 (13223)	total: 1m 40s	remaining: 43s
# 15000:	learn: 10.2786805	test: 38.4485981	best: 38.4467778 (14983)	total: 1m 47s	remaining: 35.8s
# 16000:	learn: 9.6679668	test: 38.4796402	best: 38.4202050 (15438)	total: 1m 54s	remaining: 28.6s
# 17000:	learn: 9.0588732	test: 38.4525702	best: 38.4202050 (15438)	total: 2m 1s	remaining: 21.5s
# Stopped by overfitting detector  (2000 iterations wait)
#
# bestTest = 38.42020499
# bestIteration = 15438
#
# Shrink model to first 15439 iterations.
# Количество деревьев: [6357, 7491, 8493, 13161, 15439]
# Среднее количество деревьев: 10188 +/- 3500
# MAE на кроссвалидации: [35.86236 35.97281 38.4202  39.42944 40.03544]
# MAE среднее: 37.944 +/- 1.73
# Прогнозирование Xmax
# 0:	learn: 468.3313531	test: 461.2358881	best: 461.2358881 (0)	total: 7.57ms	remaining: 2m 31s
# 1000:	learn: 252.0962504	test: 252.1704460	best: 252.1704460 (1000)	total: 7.28s	remaining: 2m 18s
# 2000:	learn: 125.5763762	test: 129.5831392	best: 129.5831392 (2000)	total: 14.6s	remaining: 2m 11s
# 3000:	learn: 69.1660811	test: 78.2151276	best: 78.2151276 (3000)	total: 22s	remaining: 2m 4s
# 4000:	learn: 55.9423497	test: 63.0031527	best: 63.0031527 (4000)	total: 29.3s	remaining: 1m 57s
# 5000:	learn: 50.7613576	test: 60.3940167	best: 60.3936181 (4999)	total: 36.7s	remaining: 1m 50s
# 6000:	learn: 46.6001926	test: 59.5458200	best: 59.5458200 (6000)	total: 43.9s	remaining: 1m 42s
# 7000:	learn: 43.4828418	test: 59.2157732	best: 59.1942090 (6818)	total: 51.2s	remaining: 1m 35s
# 8000:	learn: 40.6528589	test: 58.8359883	best: 58.8359883 (8000)	total: 58.4s	remaining: 1m 27s
# 9000:	learn: 37.8541579	test: 58.6246735	best: 58.6239257 (8995)	total: 1m 5s	remaining: 1m 20s
# 10000:	learn: 35.3913146	test: 58.4712435	best: 58.4587306 (9831)	total: 1m 12s	remaining: 1m 12s
# 11000:	learn: 33.1981474	test: 58.4562694	best: 58.4390552 (10464)	total: 1m 20s	remaining: 1m 5s
# 12000:	learn: 31.2765453	test: 58.5467647	best: 58.4044848 (11113)	total: 1m 27s	remaining: 58.5s
# 13000:	learn: 29.5585672	test: 58.7726087	best: 58.4044848 (11113)	total: 1m 35s	remaining: 51.2s
# Stopped by overfitting detector  (2000 iterations wait)
#
# bestTest = 58.40448485
# bestIteration = 11113
#
# Shrink model to first 11114 iterations.
# 0:	learn: 464.7820250	test: 475.3941851	best: 475.3941851 (0)	total: 16.6ms	remaining: 5m 32s
# 1000:	learn: 248.7537407	test: 264.3079411	best: 264.3079411 (1000)	total: 5.76s	remaining: 1m 49s
# 2000:	learn: 123.7130212	test: 134.5636574	best: 134.5636574 (2000)	total: 13.7s	remaining: 2m 2s
# 3000:	learn: 67.6235435	test: 78.8150710	best: 78.8150710 (3000)	total: 21.2s	remaining: 2m
# 4000:	learn: 52.7794966	test: 68.1845703	best: 68.1821047 (3999)	total: 28.8s	remaining: 1m 55s
# 5000:	learn: 47.3137385	test: 67.3710683	best: 67.3419524 (4757)	total: 36.3s	remaining: 1m 48s
# 6000:	learn: 43.5093489	test: 67.8603315	best: 67.3419524 (4757)	total: 43.6s	remaining: 1m 41s
# Stopped by overfitting detector  (2000 iterations wait)
#
# bestTest = 67.34195236
# bestIteration = 4757
#
# Shrink model to first 4758 iterations.
# 0:	learn: 470.8496481	test: 451.1878171	best: 451.1878171 (0)	total: 7.79ms	remaining: 2m 35s
# 1000:	learn: 256.5212110	test: 235.0843186	best: 235.0843186 (1000)	total: 5.83s	remaining: 1m 50s
# 2000:	learn: 128.9787920	test: 116.2696185	best: 116.2696185 (2000)	total: 13.2s	remaining: 1m 58s
# 3000:	learn: 71.2443067	test: 69.0447739	best: 69.0447739 (3000)	total: 20.5s	remaining: 1m 56s
# 4000:	learn: 54.4742421	test: 65.2613606	best: 65.2557757 (3999)	total: 27.7s	remaining: 1m 50s
# 5000:	learn: 49.7522898	test: 65.0117342	best: 64.9648640 (4645)	total: 35s	remaining: 1m 44s
# 6000:	learn: 46.2378823	test: 65.3861208	best: 64.9648640 (4645)	total: 42.2s	remaining: 1m 38s
# Stopped by overfitting detector  (2000 iterations wait)
#
# bestTest = 64.96486402
# bestIteration = 4645
#
# Shrink model to first 4646 iterations.
# 0:	learn: 470.8969412	test: 450.9400141	best: 450.9400141 (0)	total: 7.72ms	remaining: 2m 34s
# 1000:	learn: 256.1479000	test: 236.8480130	best: 236.8480130 (1000)	total: 5.81s	remaining: 1m 50s
# 2000:	learn: 126.6710141	test: 121.3200693	best: 121.3200693 (2000)	total: 13.2s	remaining: 1m 58s
# 3000:	learn: 68.8295426	test: 76.0854834	best: 76.0854834 (3000)	total: 20.4s	remaining: 1m 55s
# 4000:	learn: 54.7410271	test: 65.1221985	best: 65.1221985 (4000)	total: 28.2s	remaining: 1m 52s
# 5000:	learn: 49.7879553	test: 63.1851370	best: 63.1828025 (4998)	total: 35.4s	remaining: 1m 46s
# 6000:	learn: 46.0890330	test: 62.9716539	best: 62.9617535 (5975)	total: 43.2s	remaining: 1m 40s
# 7000:	learn: 42.6514330	test: 63.0700016	best: 62.9614449 (6060)	total: 50.8s	remaining: 1m 34s
# 8000:	learn: 39.6666120	test: 63.0969584	best: 62.9614449 (6060)	total: 58.5s	remaining: 1m 27s
# Stopped by overfitting detector  (2000 iterations wait)
#
# bestTest = 62.96144491
# bestIteration = 6060
#
# Shrink model to first 6061 iterations.
# 0:	learn: 459.7097826	test: 495.8798947	best: 495.8798947 (0)	total: 8.75ms	remaining: 2m 54s
# 1000:	learn: 245.0426382	test: 280.3953952	best: 280.3953952 (1000)	total: 5.99s	remaining: 1m 53s
# 2000:	learn: 119.4096416	test: 151.6742369	best: 151.6742369 (2000)	total: 13.6s	remaining: 2m 2s
# 3000:	learn: 65.8284626	test: 90.9325421	best: 90.9325421 (3000)	total: 20.9s	remaining: 1m 58s
# 4000:	learn: 51.2912914	test: 77.0751718	best: 77.0751718 (4000)	total: 28.3s	remaining: 1m 53s
# 5000:	learn: 46.6711612	test: 74.6833669	best: 74.6833669 (5000)	total: 35.7s	remaining: 1m 47s
# 6000:	learn: 43.0737704	test: 73.8561683	best: 73.8554835 (5999)	total: 42.9s	remaining: 1m 40s
# 7000:	learn: 39.9186819	test: 73.2744235	best: 73.2744235 (7000)	total: 50.1s	remaining: 1m 33s
# 8000:	learn: 37.0379341	test: 72.7707627	best: 72.7655400 (7992)	total: 57.3s	remaining: 1m 25s
# 9000:	learn: 34.2892917	test: 72.3309530	best: 72.3287102 (8999)	total: 1m 4s	remaining: 1m 18s
# 10000:	learn: 32.0915845	test: 72.2470620	best: 72.2150809 (9306)	total: 1m 12s	remaining: 1m 12s
# 11000:	learn: 30.1636614	test: 72.2823110	best: 72.2150809 (9306)	total: 1m 19s	remaining: 1m 4s
# Stopped by overfitting detector  (2000 iterations wait)
#
# bestTest = 72.21508089
# bestIteration = 9306
#
# Shrink model to first 9307 iterations.
# Количество деревьев: [4646, 4758, 6061, 9307, 11114]
# Среднее количество деревьев: 7177 +/- 2590
# MAE на кроссвалидации: [58.40448 62.96144 64.96486 67.34195 72.21508]
# MAE среднее: 65.178 +/- 4.58
# Прогнозирование Ymax
# 0:	learn: 949.3472682	test: 930.7491156	best: 930.7491156 (0)	total: 19.5ms	remaining: 6m 29s
# 1000:	learn: 700.9074348	test: 682.1418636	best: 682.1418636 (1000)	total: 1.6s	remaining: 30.3s
# 2000:	learn: 454.1797651	test: 434.9203342	best: 434.9203342 (2000)	total: 3.5s	remaining: 31.5s
# 3000:	learn: 253.7853728	test: 241.2732033	best: 241.2732033 (3000)	total: 10.6s	remaining: 59.8s
# 4000:	learn: 124.6195644	test: 127.6316599	best: 127.6316599 (4000)	total: 17.9s	remaining: 1m 11s
# 5000:	learn: 69.0539334	test: 83.6209563	best: 83.6209563 (5000)	total: 25.1s	remaining: 1m 15s
# 6000:	learn: 50.6548237	test: 71.1408550	best: 71.1408550 (6000)	total: 32.3s	remaining: 1m 15s
# 7000:	learn: 41.8102437	test: 64.8748908	best: 64.8748908 (7000)	total: 39.5s	remaining: 1m 13s
# 8000:	learn: 37.4119902	test: 62.5444841	best: 62.5444841 (8000)	total: 46.7s	remaining: 1m 10s
# 9000:	learn: 34.2030619	test: 61.3530418	best: 61.3476791 (8995)	total: 54.6s	remaining: 1m 6s
# 10000:	learn: 31.6210148	test: 60.8833682	best: 60.8832016 (9999)	total: 1m 2s	remaining: 1m 2s
# 11000:	learn: 29.2708908	test: 60.7063687	best: 60.7017124 (10990)	total: 1m 9s	remaining: 57.2s
# 12000:	learn: 27.2107296	test: 60.6734771	best: 60.6297708 (11396)	total: 1m 17s	remaining: 52s
# 13000:	learn: 25.4642722	test: 60.5912992	best: 60.5803590 (12835)	total: 1m 25s	remaining: 46.1s
# 14000:	learn: 23.8861424	test: 60.5117130	best: 60.4860483 (13857)	total: 1m 33s	remaining: 40s
# 15000:	learn: 22.4856183	test: 60.4188436	best: 60.3910466 (14704)	total: 1m 40s	remaining: 33.5s
# 16000:	learn: 21.2235727	test: 60.2840284	best: 60.2694181 (15966)	total: 1m 47s	remaining: 26.9s
# 17000:	learn: 20.0790944	test: 60.2675891	best: 60.2269968 (16659)	total: 1m 55s	remaining: 20.3s
# 18000:	learn: 19.0154706	test: 60.2311155	best: 60.2145586 (17538)	total: 2m 2s	remaining: 13.6s
# 19000:	learn: 18.0322098	test: 60.2449028	best: 60.2145586 (17538)	total: 2m 9s	remaining: 6.8s
# 19999:	learn: 17.1230070	test: 60.1724858	best: 60.1608388 (19875)	total: 2m 16s	remaining: 0us
#
# bestTest = 60.16083876
# bestIteration = 19875
#
# Shrink model to first 19876 iterations.
# 0:	learn: 941.2448897	test: 963.0714338	best: 963.0714338 (0)	total: 7.34ms	remaining: 2m 26s
# 1000:	learn: 692.7780590	test: 714.8756758	best: 714.8756758 (1000)	total: 1.46s	remaining: 27.7s
# 2000:	learn: 445.7692090	test: 468.7740106	best: 468.7740106 (2000)	total: 3.1s	remaining: 27.9s
# 3000:	learn: 247.3959988	test: 268.6283258	best: 268.6283258 (3000)	total: 9.83s	remaining: 55.7s
# 4000:	learn: 123.6836425	test: 139.4631892	best: 139.4631892 (4000)	total: 17.2s	remaining: 1m 8s
# 5000:	learn: 70.8026707	test: 83.5348314	best: 83.5348314 (5000)	total: 24.5s	remaining: 1m 13s
# 6000:	learn: 52.1061183	test: 64.9832251	best: 64.9832251 (6000)	total: 31.8s	remaining: 1m 14s
# 7000:	learn: 43.3420955	test: 58.8687902	best: 58.8687902 (7000)	total: 39s	remaining: 1m 12s
# 8000:	learn: 38.7523285	test: 56.7973134	best: 56.7938205 (7999)	total: 46.5s	remaining: 1m 9s
# 9000:	learn: 35.9647158	test: 56.3194825	best: 56.3092899 (8974)	total: 55s	remaining: 1m 7s
# 10000:	learn: 33.7377655	test: 56.1002642	best: 56.0846053 (9955)	total: 1m 2s	remaining: 1m 2s
# 11000:	learn: 31.6754358	test: 56.0209100	best: 56.0098056 (10898)	total: 1m 9s	remaining: 57.2s
# 12000:	learn: 29.7923634	test: 55.9650931	best: 55.9380258 (11611)	total: 1m 17s	remaining: 51.4s
# 13000:	learn: 28.1217635	test: 55.8813651	best: 55.8687234 (12883)	total: 1m 24s	remaining: 45.5s
# 14000:	learn: 26.5379222	test: 55.6778513	best: 55.6575877 (13798)	total: 1m 31s	remaining: 39.3s
# 15000:	learn: 25.1354278	test: 55.4814185	best: 55.4706564 (14971)	total: 1m 39s	remaining: 33s
# 16000:	learn: 23.8799975	test: 55.4098379	best: 55.3884590 (15961)	total: 1m 46s	remaining: 26.6s
# 17000:	learn: 22.7685520	test: 55.3076397	best: 55.3046587 (16969)	total: 1m 53s	remaining: 20s
# 18000:	learn: 21.6965575	test: 55.2059506	best: 55.1990477 (17925)	total: 2m	remaining: 13.4s
# 19000:	learn: 20.6735242	test: 55.0981899	best: 55.0664212 (18564)	total: 2m 7s	remaining: 6.72s
# 19999:	learn: 19.7576431	test: 54.9965439	best: 54.9937001 (19859)	total: 2m 15s	remaining: 0us
#
# bestTest = 54.9937001
# bestIteration = 19859
#
# Shrink model to first 19860 iterations.
# 0:	learn: 949.1533617	test: 931.5211504	best: 931.5211504 (0)	total: 7.52ms	remaining: 2m 30s
# 1000:	learn: 700.6839446	test: 683.1248839	best: 683.1248839 (1000)	total: 1.44s	remaining: 27.4s
# 2000:	learn: 453.7449057	test: 436.5197822	best: 436.5197822 (2000)	total: 3.3s	remaining: 29.7s
# 3000:	learn: 252.5219858	test: 244.8834830	best: 244.8834830 (3000)	total: 11.2s	remaining: 1m 3s
# 4000:	learn: 126.0931913	test: 123.5659355	best: 123.5659355 (4000)	total: 18.8s	remaining: 1m 15s
# 5000:	learn: 71.8030992	test: 70.8742392	best: 70.8742392 (5000)	total: 26.1s	remaining: 1m 18s
# 6000:	learn: 52.4550440	test: 58.5159444	best: 58.5159444 (6000)	total: 33.5s	remaining: 1m 18s
# 7000:	learn: 43.9621077	test: 55.1732851	best: 55.1618586 (6959)	total: 40.8s	remaining: 1m 15s
# 8000:	learn: 39.7971279	test: 54.3621688	best: 54.3601694 (7991)	total: 48s	remaining: 1m 11s
# 9000:	learn: 36.9540745	test: 53.8274470	best: 53.8241153 (8999)	total: 55.3s	remaining: 1m 7s
# 10000:	learn: 34.7002326	test: 53.4874945	best: 53.4874945 (10000)	total: 1m 2s	remaining: 1m 2s
# 11000:	learn: 32.5866140	test: 53.1719461	best: 53.1719461 (11000)	total: 1m 9s	remaining: 56.9s
# 12000:	learn: 30.6277826	test: 53.0455293	best: 53.0375973 (11792)	total: 1m 16s	remaining: 51.1s
# 13000:	learn: 28.8545227	test: 52.8183632	best: 52.8155070 (12926)	total: 1m 23s	remaining: 45.2s
# 14000:	learn: 27.1605336	test: 52.7701347	best: 52.7420550 (13529)	total: 1m 31s	remaining: 39s
# 15000:	learn: 25.6288236	test: 52.7304826	best: 52.7107756 (14566)	total: 1m 38s	remaining: 32.7s
# 16000:	learn: 24.1594324	test: 52.6979947	best: 52.6713954 (15889)	total: 1m 45s	remaining: 26.4s
# 17000:	learn: 22.8611881	test: 52.7215530	best: 52.6629634 (16262)	total: 1m 53s	remaining: 20s
# 18000:	learn: 21.5447791	test: 52.6228279	best: 52.6223990 (17974)	total: 2m	remaining: 13.4s
# 19000:	learn: 20.3974604	test: 52.7634843	best: 52.6192597 (18015)	total: 2m 7s	remaining: 6.73s
# 19999:	learn: 19.3662809	test: 52.8523750	best: 52.6192597 (18015)	total: 2m 15s	remaining: 0us
#
# bestTest = 52.6192597
# bestIteration = 18015
#
# Shrink model to first 18016 iterations.
# 0:	learn: 949.0731001	test: 931.7963971	best: 931.7963971 (0)	total: 7.75ms	remaining: 2m 35s
# 1000:	learn: 700.6132737	test: 683.2975626	best: 683.2975626 (1000)	total: 1.71s	remaining: 32.5s
# 2000:	learn: 453.8173440	test: 436.1205271	best: 436.1205271 (2000)	total: 3.56s	remaining: 32s
# 3000:	learn: 254.7598220	test: 239.5333324	best: 239.5333324 (3000)	total: 10.6s	remaining: 60s
# 4000:	learn: 127.5708108	test: 118.7172504	best: 118.7172504 (4000)	total: 17.9s	remaining: 1m 11s
# 5000:	learn: 71.7247799	test: 71.4148036	best: 71.4148036 (5000)	total: 25.4s	remaining: 1m 16s
# 6000:	learn: 52.1644497	test: 62.1442289	best: 62.1438451 (5999)	total: 32.7s	remaining: 1m 16s
# 7000:	learn: 43.5773029	test: 57.2346001	best: 57.2345413 (6997)	total: 39.9s	remaining: 1m 14s
# 8000:	learn: 38.3371336	test: 54.7382644	best: 54.7375123 (7998)	total: 47.1s	remaining: 1m 10s
# 9000:	learn: 35.2170651	test: 54.2896821	best: 54.2570215 (8799)	total: 54.3s	remaining: 1m 6s
# 10000:	learn: 32.8850885	test: 54.2762771	best: 54.2412444 (9469)	total: 1m 1s	remaining: 1m 1s
# 11000:	learn: 30.8919489	test: 54.1946765	best: 54.1810549 (10746)	total: 1m 8s	remaining: 56.4s
# 12000:	learn: 29.1890390	test: 54.2726522	best: 54.1733433 (11026)	total: 1m 16s	remaining: 50.8s
# 13000:	learn: 27.6840776	test: 54.3014564	best: 54.1733433 (11026)	total: 1m 23s	remaining: 44.9s
# Stopped by overfitting detector  (2000 iterations wait)
#
# bestTest = 54.17334333
# bestIteration = 11026
#
# Shrink model to first 11027 iterations.
# 0:	learn: 939.3031601	test: 971.0447883	best: 971.0447883 (0)	total: 11.2ms	remaining: 3m 43s
# 1000:	learn: 690.8473568	test: 722.8887172	best: 722.8887172 (1000)	total: 1.48s	remaining: 28.1s
# 2000:	learn: 443.7119290	test: 477.0325963	best: 477.0325963 (2000)	total: 3.15s	remaining: 28.3s
# 3000:	learn: 245.2629440	test: 278.0770533	best: 278.0770533 (3000)	total: 9.81s	remaining: 55.6s
# 4000:	learn: 119.2212914	test: 150.2945986	best: 150.2945986 (4000)	total: 17.1s	remaining: 1m 8s
# 5000:	learn: 65.1732893	test: 97.7733025	best: 97.7733025 (5000)	total: 24.4s	remaining: 1m 13s
# 6000:	learn: 48.5819169	test: 77.2645121	best: 77.2645121 (6000)	total: 31.5s	remaining: 1m 13s
# 7000:	learn: 39.4807267	test: 67.6477484	best: 67.6477484 (7000)	total: 38.7s	remaining: 1m 11s
# 8000:	learn: 35.3220274	test: 64.9152178	best: 64.9152178 (8000)	total: 46s	remaining: 1m 8s
# 9000:	learn: 32.6488635	test: 64.0398520	best: 64.0329750 (8991)	total: 53.2s	remaining: 1m 4s
# 10000:	learn: 30.3924897	test: 63.8382973	best: 63.8157001 (9777)	total: 1m	remaining: 1m
# 11000:	learn: 28.4686048	test: 63.7448379	best: 63.7383663 (10906)	total: 1m 8s	remaining: 55.9s
# 12000:	learn: 26.7437825	test: 63.6383551	best: 63.6345475 (11994)	total: 1m 15s	remaining: 50.5s
# 13000:	learn: 25.2076001	test: 63.5346497	best: 63.5340420 (12980)	total: 1m 23s	remaining: 44.7s
# 14000:	learn: 23.7761081	test: 63.4016205	best: 63.3920490 (13946)	total: 1m 30s	remaining: 38.9s
# 15000:	learn: 22.4678606	test: 63.4245730	best: 63.3696880 (14049)	total: 1m 38s	remaining: 32.7s
# 16000:	learn: 21.2025555	test: 63.4341575	best: 63.3696880 (14049)	total: 1m 45s	remaining: 26.3s
# Stopped by overfitting detector  (2000 iterations wait)
#
# bestTest = 63.369688
# bestIteration = 14049
#
# Shrink model to first 14050 iterations.
# Количество деревьев: [11027, 14050, 18016, 19860, 19876]
# Среднее количество деревьев: 16566 +/- 3491
# MAE на кроссвалидации: [52.61926 54.17334 54.9937  60.16084 63.36969]
# MAE среднее: 57.063 +/- 4.04
