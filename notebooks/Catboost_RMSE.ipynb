# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import time
import catboost
from sklearn import model_selection
import pathlib

COORDINATES = ["Xmin", "Ymin", "Xmax", "Ymax"]

# %%
def area(box):
    return (box[2] - box[0]) * (box[3] - box[1])


def intersection_over_union(boxes):
    assert(len(boxes) == 8)
    boxA = boxes[:4].values
    boxB = boxes[4:].values
    
    boxAArea = area(boxA)
    boxBArea = area(boxB)
    
    if (boxAArea == 0 or boxBArea == 0):
        return 0
        
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])

    interArea = max(0, xB - xA) * max(0, yB - yA)

    
    iou = interArea / float(boxAArea + boxBArea - interArea)
    return iou

# %%
votes = pd.read_csv("../raw/train_data.csv").set_index("itemId")

# %%
answers = pd.read_csv("../raw/train_answers.csv").set_index("itemId")

# %%
votes_test = pd.read_csv("../raw/test_data.csv").set_index("itemId")

# %%
def make_feat(df):
    counts = df[["userId"]].groupby("itemId").count()
    feat = df.groupby("itemId")[COORDINATES].agg(["min", "max", "std", "median", "mean"])
    feat["count"] = counts
    return feat

# %%
SEED = 284702
FOLDS = 5
ITERATIONS = 3000
LEARNING_RATE = 0.03

CLF_PARAMS = dict(
    loss_function="RMSE",
    eval_metric=None,
    random_state=SEED,
    depth=6,
    od_type="Iter",
    od_wait=ITERATIONS // 10,
    verbose=ITERATIONS // 20,
    learning_rate=LEARNING_RATE,
    iterations=ITERATIONS,
    allow_writing_files=False
)

# %%
def train_catboost(x_train, y_train, x_test, name, subdir):
    print(f"Прогнозирование {name}")
    pool_test = catboost.Pool(
            data=x_test,
            label=None,
            cat_features=None,
            weight=None
        )
    y_oof = pd.Series(0, index=x_train.index, name=f"oof_{name}")
    y_pred = pd.Series(0, index=x_test.index, name=name)
    trees = []
    scores = []

    for index_train, index_valid in model_selection.KFold(FOLDS, shuffle=True, random_state=SEED).split(x_train):
        pool_train = catboost.Pool(
            data=x_train.iloc[index_train],
            label=y_train.iloc[index_train],
            cat_features=None,
            weight=None
        )
        pool_valid = catboost.Pool(
            data=x_train.iloc[index_valid],
            label=y_train.iloc[index_valid],
            cat_features=None,
            weight=None
        )
        clf = catboost.CatBoostRegressor(**CLF_PARAMS)
        clf.fit(
            X=pool_train,
            eval_set=[pool_valid],
        )
        trees.append(clf.tree_count_)
        scores.append(clf.best_score_['validation']['RMSE'])
        y_oof.iloc[index_valid] = clf.predict(pool_valid)
        y_pred += clf.predict(pool_test) / FOLDS

    print(f"Количество деревьев: {sorted(trees)}")
    print(f"Среднее количество деревьев: {np.mean(trees):.0f} +/- {np.std(trees):.0f}")
    print(f"RMSE на кроссвалидации: " + str(np.round(sorted(scores), 5)))
    print(f"RMSE среднее: {np.mean(scores):0.3f} +/- {np.std(scores):0.2f}")

    y_oof.to_csv(f"../processed/{subdir}/oof_{name}.csv", header=True)
    y_pred.to_csv(f"../processed/{subdir}/sub_{name}.csv", header=True)
    return y_pred, np.mean(scores)

# %%
def make_forecast():
    subdir = time.strftime('%Y-%m-%d_%H-%M')
    path = pathlib.Path(f"../processed/{subdir}")
    path.mkdir()
    x_train = make_feat(votes)
    y_train = answers.loc[x_train.index]
    x_test = make_feat(votes_test)
    scores = []
    rez = []
    for name in COORDINATES:
        y_pred, score = train_catboost(x_train, y_train[f"{name}_true"], x_test, name, subdir)
        scores.append(score)
        rez.append(y_pred)
    pd.concat(rez, axis=1).to_csv(path / "_sub_full.csv", header=False)
    path.rename(path.parent / f"{subdir}-{np.mean(scores):0.1f}")

# %%
make_forecast()
# Out:
# Прогнозирование Xmin
# 0:	learn: 111.5402728	test: 104.8273471	best: 104.8273471 (0)	total: 7.48ms	remaining: 22.4s
# 150:	learn: 59.7302110	test: 65.4232606	best: 65.3350909 (121)	total: 1.25s	remaining: 23.6s
# 300:	learn: 54.1716804	test: 66.2301222	best: 65.3350909 (121)	total: 2.41s	remaining: 21.6s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 65.33509086
# bestIteration = 121
#
# Shrink model to first 122 iterations.
# 0:	learn: 106.8936397	test: 122.9012358	best: 122.9012358 (0)	total: 7.35ms	remaining: 22.1s
# 150:	learn: 57.1572373	test: 75.7793896	best: 75.7793896 (150)	total: 1.16s	remaining: 21.8s
# 300:	learn: 50.4323600	test: 74.3909928	best: 74.3164113 (296)	total: 2.31s	remaining: 20.7s
# 450:	learn: 45.4360621	test: 74.3209401	best: 74.1893924 (331)	total: 3.46s	remaining: 19.6s
# 600:	learn: 42.5610015	test: 74.6577149	best: 74.1893924 (331)	total: 4.65s	remaining: 18.5s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 74.18939242
# bestIteration = 331
#
# Shrink model to first 332 iterations.
# 0:	learn: 113.8378799	test: 94.4395914	best: 94.4395914 (0)	total: 7.48ms	remaining: 22.4s
# 150:	learn: 61.7846076	test: 55.4879212	best: 55.3597028 (137)	total: 1.21s	remaining: 22.9s
# 300:	learn: 55.3540055	test: 55.9145535	best: 55.3597028 (137)	total: 2.36s	remaining: 21.2s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 55.35970281
# bestIteration = 137
#
# Shrink model to first 138 iterations.
# 0:	learn: 110.4395338	test: 109.6337710	best: 109.6337710 (0)	total: 7.66ms	remaining: 23s
# 150:	learn: 60.1764243	test: 66.1497826	best: 66.1416002 (148)	total: 1.22s	remaining: 23s
# 300:	learn: 54.9499645	test: 65.5204822	best: 65.4631037 (231)	total: 2.52s	remaining: 22.6s
# 450:	learn: 50.1671547	test: 65.5730947	best: 65.3703393 (368)	total: 3.82s	remaining: 21.6s
# 600:	learn: 46.6595012	test: 66.0390499	best: 65.3703393 (368)	total: 5.1s	remaining: 20.4s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 65.37033931
# bestIteration = 368
#
# Shrink model to first 369 iterations.
# 0:	learn: 108.3115533	test: 117.4501517	best: 117.4501517 (0)	total: 7.63ms	remaining: 22.9s
# 150:	learn: 57.4676856	test: 73.9694451	best: 73.8979866 (142)	total: 1.19s	remaining: 22.5s
# 300:	learn: 50.5367099	test: 74.8401140	best: 73.8979866 (142)	total: 2.37s	remaining: 21.3s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 73.89798661
# bestIteration = 142
#
# Shrink model to first 143 iterations.
# Количество деревьев: [122, 138, 143, 332, 369]
# Среднее количество деревьев: 221 +/- 107
# RMSE на кроссвалидации: [55.3597  65.33509 65.37034 73.89799 74.18939]
# RMSE среднее: 66.831 +/- 6.93
# Прогнозирование Ymin
# 0:	learn: 664.2907756	test: 642.9968739	best: 642.9968739 (0)	total: 7.88ms	remaining: 23.6s
# 150:	learn: 56.7030975	test: 60.1707804	best: 60.1707804 (150)	total: 1.24s	remaining: 23.3s
# 300:	learn: 50.4672446	test: 57.1771635	best: 57.1771635 (300)	total: 2.53s	remaining: 22.7s
# 450:	learn: 49.1527096	test: 56.8288890	best: 56.8288890 (450)	total: 3.66s	remaining: 20.7s
# 600:	learn: 48.5121740	test: 56.6967910	best: 56.6967910 (600)	total: 4.5s	remaining: 17.9s
# 750:	learn: 47.8648521	test: 56.7346202	best: 56.6170407 (637)	total: 5.44s	remaining: 16.3s
# 900:	learn: 47.1771709	test: 56.7622801	best: 56.6170407 (637)	total: 6.39s	remaining: 14.9s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 56.6170407
# bestIteration = 637
#
# Shrink model to first 638 iterations.
# 0:	learn: 658.8939615	test: 664.5541533	best: 664.5541533 (0)	total: 16ms	remaining: 47.9s
# 150:	learn: 56.7504291	test: 62.5338827	best: 62.5338827 (150)	total: 1.48s	remaining: 27.8s
# 300:	learn: 49.2244008	test: 59.9749722	best: 59.9749722 (300)	total: 2.71s	remaining: 24.3s
# 450:	learn: 47.5827074	test: 59.9464644	best: 59.9137462 (389)	total: 4.07s	remaining: 23s
# 600:	learn: 46.7339147	test: 59.9418422	best: 59.8902599 (565)	total: 5.24s	remaining: 20.9s
# 750:	learn: 46.3776348	test: 59.9478137	best: 59.8902599 (565)	total: 6.45s	remaining: 19.3s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 59.89025987
# bestIteration = 565
#
# Shrink model to first 566 iterations.
# 0:	learn: 660.7965013	test: 655.7964134	best: 655.7964134 (0)	total: 10.3ms	remaining: 30.9s
# 150:	learn: 58.2030232	test: 54.9007573	best: 54.9007573 (150)	total: 1.22s	remaining: 23s
# 300:	learn: 50.9210932	test: 49.9747457	best: 49.9737493 (299)	total: 2.35s	remaining: 21.1s
# 450:	learn: 49.8561513	test: 49.8693589	best: 49.7950264 (426)	total: 3.26s	remaining: 18.4s
# 600:	learn: 48.4719574	test: 50.0831392	best: 49.7950264 (426)	total: 4.4s	remaining: 17.5s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 49.79502637
# bestIteration = 426
#
# Shrink model to first 427 iterations.
# 0:	learn: 658.8594739	test: 665.9358287	best: 665.9358287 (0)	total: 7.58ms	remaining: 22.7s
# 150:	learn: 55.8853166	test: 59.8532275	best: 59.8532275 (150)	total: 1.22s	remaining: 23.1s
# 300:	learn: 49.3639561	test: 56.2705776	best: 56.2318682 (292)	total: 2.37s	remaining: 21.3s
# 450:	learn: 47.8877529	test: 56.5622997	best: 56.2254218 (346)	total: 3.43s	remaining: 19.4s
# 600:	learn: 46.7850786	test: 57.2599748	best: 56.2254218 (346)	total: 4.6s	remaining: 18.4s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 56.22542181
# bestIteration = 346
#
# Shrink model to first 347 iterations.
# 0:	learn: 657.6761390	test: 671.5454950	best: 671.5454950 (0)	total: 9.1ms	remaining: 27.3s
# 150:	learn: 54.2233411	test: 74.8582038	best: 74.8582038 (150)	total: 1.55s	remaining: 29.3s
# 300:	learn: 48.7888852	test: 66.9301517	best: 66.9301517 (300)	total: 2.72s	remaining: 24.4s
# 450:	learn: 46.6593934	test: 64.2033633	best: 64.2033633 (450)	total: 3.72s	remaining: 21s
# 600:	learn: 44.6724702	test: 62.9130211	best: 62.9098959 (597)	total: 4.96s	remaining: 19.8s
# 750:	learn: 43.6460897	test: 62.2940771	best: 62.2884807 (749)	total: 6.09s	remaining: 18.2s
# 900:	learn: 42.6634581	test: 61.9246941	best: 61.8873837 (898)	total: 7.13s	remaining: 16.6s
# 1050:	learn: 42.1089361	test: 61.6768148	best: 61.6496213 (1016)	total: 8.33s	remaining: 15.4s
# 1200:	learn: 41.4455408	test: 61.7531383	best: 61.6482005 (1116)	total: 9.41s	remaining: 14.1s
# 1350:	learn: 40.7732678	test: 61.7284012	best: 61.6482005 (1116)	total: 10.5s	remaining: 12.8s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 61.64820048
# bestIteration = 1116
#
# Shrink model to first 1117 iterations.
# Количество деревьев: [347, 427, 566, 638, 1117]
# Среднее количество деревьев: 619 +/- 269
# RMSE на кроссвалидации: [49.79503 56.22542 56.61704 59.89026 61.6482 ]
# RMSE среднее: 56.835 +/- 4.06
# Прогнозирование Xmax
# 0:	learn: 522.6514491	test: 523.2784373	best: 523.2784373 (0)	total: 7.5ms	remaining: 22.5s
# 150:	learn: 86.4047188	test: 88.7120548	best: 88.7120548 (150)	total: 1.34s	remaining: 25.4s
# 300:	learn: 79.4843772	test: 84.6656431	best: 84.6265002 (299)	total: 2.58s	remaining: 23.1s
# 450:	learn: 75.2192970	test: 83.3394985	best: 83.3394985 (450)	total: 3.87s	remaining: 21.9s
# 600:	learn: 72.6556258	test: 83.0318579	best: 83.0318579 (600)	total: 5.28s	remaining: 21.1s
# 750:	learn: 71.0618087	test: 82.7127349	best: 82.6533933 (728)	total: 6.49s	remaining: 19.4s
# 900:	learn: 69.5233042	test: 82.6725877	best: 82.6504358 (890)	total: 7.58s	remaining: 17.7s
# 1050:	learn: 68.2724976	test: 82.6025619	best: 82.4912983 (1040)	total: 8.7s	remaining: 16.1s
# 1200:	learn: 66.5453368	test: 82.6248394	best: 82.4912983 (1040)	total: 9.86s	remaining: 14.8s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 82.49129827
# bestIteration = 1040
#
# Shrink model to first 1041 iterations.
# 0:	learn: 519.9766496	test: 532.2465460	best: 532.2465460 (0)	total: 8.5ms	remaining: 25.5s
# 150:	learn: 83.6437616	test: 97.1092681	best: 97.1092681 (150)	total: 1.22s	remaining: 23s
# 300:	learn: 77.6302362	test: 94.6835535	best: 94.6835535 (300)	total: 2.49s	remaining: 22.3s
# 450:	learn: 74.2615867	test: 93.5804256	best: 93.5804256 (450)	total: 3.71s	remaining: 21s
# 600:	learn: 71.5073786	test: 92.9775206	best: 92.9309038 (553)	total: 5.06s	remaining: 20.2s
# 750:	learn: 69.2254189	test: 92.8085713	best: 92.7132043 (726)	total: 6.22s	remaining: 18.6s
# 900:	learn: 67.2068615	test: 92.6949835	best: 92.6438354 (894)	total: 7.39s	remaining: 17.2s
# 1050:	learn: 65.5284168	test: 92.6245479	best: 92.6120558 (1047)	total: 8.47s	remaining: 15.7s
# 1200:	learn: 63.5370465	test: 92.5302359	best: 92.4892735 (1193)	total: 9.69s	remaining: 14.5s
# 1350:	learn: 61.7412171	test: 92.5247951	best: 92.3747233 (1231)	total: 10.8s	remaining: 13.2s
# 1500:	learn: 60.5730849	test: 92.5852149	best: 92.3747233 (1231)	total: 12.1s	remaining: 12.1s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 92.37472335
# bestIteration = 1231
#
# Shrink model to first 1232 iterations.
# 0:	learn: 528.6775341	test: 497.9772674	best: 497.9772674 (0)	total: 12.6ms	remaining: 37.8s
# 150:	learn: 85.2322542	test: 87.9049935	best: 87.8667516 (149)	total: 1.81s	remaining: 34.1s
# 300:	learn: 79.8613951	test: 87.7589870	best: 87.7053550 (259)	total: 3.34s	remaining: 30s
# 450:	learn: 77.2689489	test: 87.6333775	best: 87.5509464 (399)	total: 4.76s	remaining: 26.9s
# 600:	learn: 74.4180036	test: 87.9735254	best: 87.5509464 (399)	total: 6.31s	remaining: 25.2s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 87.55094645
# bestIteration = 399
#
# Shrink model to first 400 iterations.
# 0:	learn: 526.2179364	test: 504.1743683	best: 504.1743683 (0)	total: 14.9ms	remaining: 44.7s
# 150:	learn: 84.6123714	test: 94.0905587	best: 94.0905587 (150)	total: 1.42s	remaining: 26.7s
# 300:	learn: 77.9420723	test: 91.6503835	best: 91.6318007 (296)	total: 2.7s	remaining: 24.2s
# 450:	learn: 75.1348802	test: 90.7534140	best: 90.7534140 (450)	total: 4.06s	remaining: 23s
# 600:	learn: 73.1127033	test: 90.2771455	best: 90.2237220 (580)	total: 5.24s	remaining: 20.9s
# 750:	learn: 71.1870705	test: 89.6022689	best: 89.6022689 (750)	total: 6.39s	remaining: 19.1s
# 900:	learn: 69.4591273	test: 89.2823674	best: 89.2556845 (879)	total: 7.58s	remaining: 17.7s
# 1050:	learn: 67.6908659	test: 89.2418007	best: 89.2152958 (1003)	total: 8.77s	remaining: 16.3s
# 1200:	learn: 65.7119006	test: 89.0713579	best: 88.9873313 (1176)	total: 9.95s	remaining: 14.9s
# 1350:	learn: 64.4320493	test: 88.8234469	best: 88.8043344 (1261)	total: 11.1s	remaining: 13.5s
# 1500:	learn: 62.8339988	test: 88.8692422	best: 88.7829027 (1396)	total: 12.3s	remaining: 12.3s
# 1650:	learn: 61.6991492	test: 89.0130748	best: 88.7829027 (1396)	total: 13.5s	remaining: 11s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 88.78290273
# bestIteration = 1396
#
# Shrink model to first 1397 iterations.
# 0:	learn: 514.1020760	test: 552.8941845	best: 552.8941845 (0)	total: 8.14ms	remaining: 24.4s
# 150:	learn: 84.1973028	test: 99.4274491	best: 99.4274491 (150)	total: 1.26s	remaining: 23.8s
# 300:	learn: 77.2214453	test: 94.7860390	best: 94.7860390 (300)	total: 2.44s	remaining: 21.8s
# 450:	learn: 72.8350390	test: 94.0251202	best: 94.0248680 (448)	total: 3.61s	remaining: 20.4s
# 600:	learn: 69.2065931	test: 93.8487851	best: 93.8431664 (595)	total: 4.83s	remaining: 19.3s
# 750:	learn: 66.4006189	test: 94.2444828	best: 93.8262473 (605)	total: 6.07s	remaining: 18.2s
# 900:	learn: 65.0432863	test: 94.3912553	best: 93.8262473 (605)	total: 7.31s	remaining: 17s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 93.82624734
# bestIteration = 605
#
# Shrink model to first 606 iterations.
# Количество деревьев: [400, 606, 1041, 1232, 1397]
# Среднее количество деревьев: 935 +/- 376
# RMSE на кроссвалидации: [82.4913  87.55095 88.7829  92.37472 93.82625]
# RMSE среднее: 89.005 +/- 3.98
# Прогнозирование Ymax
# 0:	learn: 963.3337770	test: 947.7356031	best: 947.7356031 (0)	total: 9.02ms	remaining: 27s
# 150:	learn: 81.2478117	test: 104.3255669	best: 104.3255669 (150)	total: 1.39s	remaining: 26.3s
# 300:	learn: 73.9720392	test: 97.9186249	best: 97.9109525 (299)	total: 2.68s	remaining: 24s
# 450:	learn: 73.0695568	test: 97.5566877	best: 97.5127924 (380)	total: 3.53s	remaining: 19.9s
# 600:	learn: 72.2240747	test: 97.3928810	best: 97.3916620 (599)	total: 4.49s	remaining: 17.9s
# 750:	learn: 71.1957999	test: 97.1934702	best: 97.1811908 (748)	total: 5.3s	remaining: 15.9s
# 900:	learn: 70.4859745	test: 96.9696486	best: 96.9319797 (889)	total: 5.91s	remaining: 13.8s
# 1050:	learn: 69.8570949	test: 96.9829593	best: 96.9319797 (889)	total: 6.58s	remaining: 12.2s
# 1200:	learn: 69.3830268	test: 96.8156152	best: 96.8156152 (1200)	total: 7.11s	remaining: 10.7s
# 1350:	learn: 68.0698077	test: 96.3294739	best: 96.3169562 (1349)	total: 7.98s	remaining: 9.74s
# 1500:	learn: 66.5059307	test: 96.2296394	best: 96.1773070 (1486)	total: 9.06s	remaining: 9.04s
# 1650:	learn: 65.2011492	test: 96.0827130	best: 96.0742674 (1638)	total: 10.1s	remaining: 8.27s
# 1800:	learn: 64.2604538	test: 96.0268587	best: 95.8989860 (1712)	total: 11.2s	remaining: 7.42s
# 1950:	learn: 63.0868558	test: 96.0557695	best: 95.8989860 (1712)	total: 12.2s	remaining: 6.57s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 95.89898596
# bestIteration = 1712
#
# Shrink model to first 1713 iterations.
# 0:	learn: 956.3522643	test: 974.7961230	best: 974.7961230 (0)	total: 7.39ms	remaining: 22.2s
# 150:	learn: 84.3335940	test: 88.0001517	best: 88.0001517 (150)	total: 1.22s	remaining: 23.1s
# 300:	learn: 78.3253383	test: 81.9618870	best: 81.9618870 (300)	total: 2.33s	remaining: 20.9s
# 450:	learn: 77.0222455	test: 80.7867329	best: 80.7839428 (446)	total: 3.16s	remaining: 17.9s
# 600:	learn: 75.7680350	test: 79.8070204	best: 79.8048587 (598)	total: 4.08s	remaining: 16.3s
# 750:	learn: 74.7997408	test: 79.1755721	best: 79.1755721 (750)	total: 4.96s	remaining: 14.8s
# 900:	learn: 73.8953039	test: 78.8544183	best: 78.8515887 (898)	total: 6.04s	remaining: 14.1s
# 1050:	learn: 73.0013155	test: 78.6351209	best: 78.5535731 (1009)	total: 7.15s	remaining: 13.3s
# 1200:	learn: 70.7468027	test: 78.3640195	best: 78.3466988 (1195)	total: 8.28s	remaining: 12.4s
# 1350:	learn: 69.6853247	test: 78.2927666	best: 78.2621614 (1330)	total: 9.42s	remaining: 11.5s
# 1500:	learn: 68.7618336	test: 78.2650804	best: 78.2621614 (1330)	total: 10.4s	remaining: 10.4s
# 1650:	learn: 67.8215151	test: 78.5029797	best: 78.2605715 (1504)	total: 11.6s	remaining: 9.47s
# 1800:	learn: 66.8367154	test: 78.7088669	best: 78.2605715 (1504)	total: 12.8s	remaining: 8.54s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 78.2605715
# bestIteration = 1504
#
# Shrink model to first 1505 iterations.
# 0:	learn: 963.9391373	test: 944.0946586	best: 944.0946586 (0)	total: 7.94ms	remaining: 23.8s
# 150:	learn: 84.3088435	test: 84.8200334	best: 84.8200334 (150)	total: 1.21s	remaining: 22.9s
# 300:	learn: 76.9016776	test: 79.4284216	best: 79.4284216 (300)	total: 2.37s	remaining: 21.2s
# 450:	learn: 75.8532541	test: 79.1492476	best: 79.1369256 (440)	total: 3.23s	remaining: 18.3s
# 600:	learn: 75.2664454	test: 79.1146892	best: 79.1042842 (597)	total: 3.8s	remaining: 15.2s
# 750:	learn: 74.0994057	test: 78.7185751	best: 78.7114946 (741)	total: 4.58s	remaining: 13.7s
# 900:	learn: 72.8326073	test: 78.4290102	best: 78.4290102 (900)	total: 5.44s	remaining: 12.7s
# 1050:	learn: 72.1250876	test: 78.4470615	best: 78.4009976 (995)	total: 6.29s	remaining: 11.7s
# 1200:	learn: 71.2465256	test: 78.3536512	best: 78.3298465 (1192)	total: 7.21s	remaining: 10.8s
# 1350:	learn: 69.7300442	test: 77.8123045	best: 77.8023677 (1347)	total: 8.23s	remaining: 10s
# 1500:	learn: 68.8670231	test: 77.6489388	best: 77.6378655 (1438)	total: 9.28s	remaining: 9.27s
# 1650:	learn: 67.8919051	test: 77.5291908	best: 77.5068021 (1644)	total: 10.3s	remaining: 8.42s
# 1800:	learn: 66.9374708	test: 77.2677737	best: 77.2657424 (1795)	total: 11.5s	remaining: 7.68s
# 1950:	learn: 66.2190610	test: 77.0334137	best: 77.0245856 (1948)	total: 12.7s	remaining: 6.85s
# 2100:	learn: 65.2865761	test: 76.7726341	best: 76.7708881 (2095)	total: 13.9s	remaining: 5.96s
# 2250:	learn: 64.1798934	test: 76.4381845	best: 76.4173369 (2246)	total: 15.1s	remaining: 5.04s
# 2400:	learn: 63.6269905	test: 76.4918188	best: 76.4173369 (2246)	total: 16s	remaining: 4s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 76.41733694
# bestIteration = 2246
#
# Shrink model to first 2247 iterations.
# 0:	learn: 965.9583226	test: 943.5277032	best: 943.5277032 (0)	total: 8.85ms	remaining: 26.5s
# 150:	learn: 81.8409074	test: 80.5367023	best: 80.5367023 (150)	total: 1.3s	remaining: 24.6s
# 300:	learn: 75.4433796	test: 78.7486063	best: 78.7483135 (298)	total: 2.42s	remaining: 21.8s
# 450:	learn: 74.3913105	test: 78.6146793	best: 78.6021754 (445)	total: 3.35s	remaining: 18.9s
# 600:	learn: 73.7591883	test: 78.5640736	best: 78.5342545 (564)	total: 4.15s	remaining: 16.6s
# 750:	learn: 73.0323215	test: 78.5844641	best: 78.5316468 (662)	total: 4.74s	remaining: 14.2s
# 900:	learn: 71.8856082	test: 78.3352004	best: 78.3267976 (895)	total: 5.65s	remaining: 13.2s
# 1050:	learn: 71.2663307	test: 78.4138419	best: 78.3267976 (895)	total: 6.38s	remaining: 11.8s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 78.32679756
# bestIteration = 895
#
# Shrink model to first 896 iterations.
# 0:	learn: 953.6968372	test: 992.6929427	best: 992.6929427 (0)	total: 8.03ms	remaining: 24.1s
# 150:	learn: 80.0436728	test: 99.7533269	best: 99.7533269 (150)	total: 1.28s	remaining: 24.2s
# 300:	learn: 72.4608240	test: 91.7041464	best: 91.7041464 (300)	total: 2.46s	remaining: 22.1s
# 450:	learn: 70.9598836	test: 90.8655808	best: 90.8655808 (450)	total: 3.51s	remaining: 19.9s
# 600:	learn: 69.7686438	test: 90.9189308	best: 90.8038874 (515)	total: 4.67s	remaining: 18.7s
# 750:	learn: 68.6175608	test: 91.1687466	best: 90.8038874 (515)	total: 5.67s	remaining: 17s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 90.8038874
# bestIteration = 515
#
# Shrink model to first 516 iterations.
# Количество деревьев: [516, 896, 1505, 1713, 2247]
# Среднее количество деревьев: 1375 +/- 610
# RMSE на кроссвалидации: [76.41734 78.26057 78.3268  90.80389 95.89899]
# RMSE среднее: 83.942 +/- 7.88
