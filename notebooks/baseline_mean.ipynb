# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import time

# %%
def area(box):
    return (box[2] - box[0]) * (box[3] - box[1])


def intersection_over_union(boxes):
    assert(len(boxes) == 8)
    boxA = boxes[:4].values
    boxB = boxes[4:].values
    
    boxAArea = area(boxA)
    boxBArea = area(boxB)
    
    if (boxAArea == 0 or boxBArea == 0):
        return 0
        
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])

    interArea = max(0, xB - xA) * max(0, yB - yA)

    
    iou = interArea / float(boxAArea + boxBArea - interArea)
    return iou

# %%
votes = pd.read_csv("../raw/train_data.csv")

# %%
answers = pd.read_csv("../raw/train_answers.csv")

# %%
votes_test = pd.read_csv("../raw/test_data.csv")

# %%
data = votes.merge(answers, on="itemId")

# %%
Xmin = data[["userId", "itemId", "Xmin", "Xmin_true"]]

# %%
Xmin["error"] = Xmin["Xmin"] - Xmin["Xmin_true"]
# Out:
# /Users/WLMike/Documents/PycharmProjects/ML_venv/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
sub = votes_test.drop("userId", axis=1).groupby("itemId").mean()
sub
# Out:
#               Xmin         Ymin        Xmax         Ymax
# itemId
# 18      135.000000   704.000000  729.000000  1071.000000
# 19       29.666667   560.666667  114.666667   725.666667
# 33       46.333333   393.666667  374.666667   633.666667
# 62       90.857143   964.857143  564.000000  1167.571429
# 114      63.333333   575.000000  207.666667   767.000000
# 146      72.000000   481.375000  577.375000   816.750000
# 156      84.333333   805.333333  155.000000   880.333333
# 163      33.333333   322.166667  203.333333   453.833333
# 164       9.333333   148.666667  366.333333   659.666667
# 179     126.000000   512.333333  322.333333   729.000000
# 186     233.857143   975.142857  918.571429  1404.571429
# 215     259.666667   660.000000  825.333333  1017.000000
# 225      45.875000   708.375000   91.500000   745.250000
# 227     306.800000   880.800000  785.800000  1309.800000
# 247      57.250000   630.500000  154.125000   725.000000
# 275     113.142857   522.428571  548.857143   864.714286
# 311     191.100000   625.100000  506.400000  1011.600000
# 399     136.166667   802.166667  339.833333  1019.166667
# 421      56.500000   935.500000  221.166667  1048.000000
# 432      73.666667   845.000000  236.333333   966.000000
# 442      40.666667   673.333333  204.000000   807.000000
# 459      20.000000   337.666667  228.333333   487.000000
# 492     134.333333  1095.333333  232.000000  1187.000000
# 507     295.333333   250.444444  883.777778   757.666667
# 631     246.333333   591.666667  847.333333  1117.333333
# 707      48.166667   818.666667   69.166667   832.666667
# 723     154.714286   193.428571  782.428571   673.142857
# 1003    111.000000   614.000000  285.714286   755.714286
# 1065    165.600000   876.300000  363.400000  1030.000000
# 1136    276.571429   875.000000  744.571429  1205.857143
# ...            ...          ...         ...          ...
# 34122   214.333333   328.000000  566.000000   654.333333
# 34143   128.142857   625.571429  501.714286   914.857143
# 34284   100.111111   682.555556  730.000000  1127.444444
# 34340    78.000000   679.333333  314.333333   899.333333
# 34455   110.000000   355.666667  434.666667   664.000000
# 34465    97.333333   327.333333  585.666667   757.666667
# 34471    70.200000   760.000000  586.400000  1079.800000
# 34483   173.000000  1225.166667  546.666667  1602.166667
# 34652   144.333333   914.333333  639.666667  1489.333333
# 34655   156.625000  1323.625000  251.625000  1422.375000
# 34796    54.375000   438.000000  181.375000   518.750000
# 34804    85.333333   647.666667  261.000000   752.333333
# 34958   320.625000   247.875000  616.500000   547.750000
# 35020    71.666667   173.000000  492.333333   690.000000
# 35021    41.666667   440.000000  119.000000   493.666667
# 35110   169.333333  1022.000000  514.166667  1701.500000
# 35118    68.000000   729.166667  480.833333   905.000000
# 35128    29.666667   468.333333  100.000000   511.666667
# 35227    37.333333   808.000000  664.000000  1141.000000
# 35307    20.666667   320.666667  242.000000   585.333333
# 35512    35.800000   939.000000  176.600000  1107.200000
# 35514    30.285714   464.142857   93.428571   511.285714
# 35544   114.000000   589.000000  372.600000   789.400000
# 35660    88.000000   268.500000  418.000000   551.750000
# 35682    54.500000  1481.750000   67.000000  1490.750000
# 35685   189.600000   323.300000  872.300000   706.600000
# 35695   146.800000   470.600000  440.400000   757.000000
# 35966    59.666667   634.333333  921.333333  1220.666667
# 35973    89.333333   917.666667  126.666667   972.333333
# 35978   107.571429   719.000000  377.428571   866.000000
#
# [630 rows x 4 columns]

# %%
sub.to_csv(
    f"../processed/sub_{time.strftime('%Y-%m-%d_%H-%M')}.csv",
    header=False
)
