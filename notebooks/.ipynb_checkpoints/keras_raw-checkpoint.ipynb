# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import time
import keras
from keras import layers
from keras import models
from keras import optimizers
from keras import callbacks
from keras import backend as K
from sklearn import model_selection
from sklearn import preprocessing
import pathlib

COORDINATES = ["Xmin", "Ymin", "Xmax", "Ymax"]

# %%
answers = pd.read_csv("../raw/train_answers.csv").set_index("itemId")
answers.columns = COORDINATES
scaler = preprocessing.StandardScaler().fit(np.vstack([answers.values, answers.values[:, [2, 3, 0, 1]]]))
answers[COORDINATES] = scaler.transform(answers[COORDINATES])
# Out:
# /Users/WLMike/Documents/PycharmProjects/ML_venv/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/WLMike/Documents/PycharmProjects/ML_venv/lib/python3.6/site-packages/ipykernel_launcher.py:4: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   after removing the cwd from sys.path.

# %%
votes = pd.read_csv("../raw/train_data.csv").set_index("itemId")
votes[COORDINATES] = scaler.transform(votes[COORDINATES])
# Out:
# /Users/WLMike/Documents/PycharmProjects/ML_venv/lib/python3.6/site-packages/ipykernel_launcher.py:2: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.

# %%
votes_test = pd.read_csv("../raw/test_data.csv").set_index("itemId")
votes_test[COORDINATES] = scaler.transform(votes_test[COORDINATES])
# Out:
# /Users/WLMike/Documents/PycharmProjects/ML_venv/lib/python3.6/site-packages/ipykernel_launcher.py:2: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.

# %%
def yield_batch(batch_size):
    while True:
        item_id = np.random.choice(votes.index, 1)
        forecasts = votes.loc[item_id].set_index("userId")
        x = np.zeros((1, len(forecasts), 4),)
        y = np.zeros((1, 4))
        
        x[0] = forecasts.sample(len(forecasts))
        y[0] = answers.loc[item_id]
        yield x, y

# %%
def yield_batch_val():
    item_ids = set(votes.index)
    while True:
        for item_id in item_ids:
            forecasts = votes.loc[item_id].set_index("userId")
            x = np.zeros((1, len(forecasts), 4),)
            y = np.zeros((1, 4))

            x[0] = forecasts
            y[0] = answers.loc[item_id]
            yield x, y

# %%
def yield_batch_test():
    item_ids = votes_test.index.unique()
    for item_id in item_ids:
        forecasts = votes_test.loc[item_id].set_index("userId")
        x = np.zeros((1, len(forecasts), 4),)
        y = np.zeros((1, 4))
        x[0] = forecasts
        yield x

# %%
def intersection_over_union(boxes_pred, boxes_true):

    x_min = K.stack([boxes_pred[:, 0], boxes_true[:, 0]], axis=-1)
    y_min = K.stack([boxes_pred[:, 1], boxes_true[:, 1]], axis=-1)
    x_max = K.stack([boxes_pred[:, 2], boxes_true[:, 2]], axis=-1)
    y_max = K.stack([boxes_pred[:, 3], boxes_true[:, 3]], axis=-1)

    x_min = K.max(x_min, axis=-1)
    y_min = K.max(y_min, axis=-1)
    x_max = K.min(x_max, axis=-1)
    y_max = K.min(y_max, axis=-1)

    zeros = K.zeros_like(x_max)

    x_inter = K.stack([zeros, x_max - x_min], axis=-1)
    y_inter = K.stack([zeros, y_max - y_min], axis=-1)

    x_inter = K.max(x_inter, axis=-1)
    y_inter = K.max(y_inter, axis=-1)
    inter_area = x_inter * y_inter
    
    area_pred = (K.max(K.stack([zeros, boxes_pred[:, 2] - boxes_pred[:, 0]], axis=-1), axis=-1) * 
                 K.max(K.stack([zeros, boxes_pred[:, 3] - boxes_pred[:, 1]], axis=-1), axis=-1))
    area_true = (K.max(K.stack([zeros, boxes_true[:, 2] - boxes_true[:, 0]], axis=-1), axis=-1) * 
                 K.max(K.stack([zeros, boxes_true[:, 3] - boxes_true[:, 1]], axis=-1), axis=-1))

    iou = inter_area / (area_pred + area_true - inter_area + K.epsilon())
    
    return -K.mean(iou, axis=-1)

# %%
def make_model(filters):
    K.clear_session()
    
    y = x = layers.Input(shape=(None, 4))
    
    mul = 4
    y = layers.Bidirectional(layers.LSTM(
        units=filters * mul,
        return_sequences=True
    ))(y)
    y = layers.Bidirectional(layers.LSTM(
        units=filters * mul,
        return_sequences=False
    ))(y)
    
    y = layers.Dense(
        units=filters * 4,
        activation="relu"
    )(y)
    y = layers.Dense(
        units=filters * 2,
        activation="relu"
    )(y)
    y = layers.Dense(
        units=filters,
        activation="relu"
    )(y)
    y = layers.Dense(
        units=4,
        activation=None
    )(y)
    
    model = models.Model(inputs=x, outputs=y)
    model.summary()
    return model

# %%
def train_model(batch_size, units, epochs=100):
    model = make_model(units)
    
    lr=0.001
    
    model.compile(optimizer=optimizers.Nadam(lr=lr, beta_1=0.9, beta_2=0.999, epsilon=None, schedule_decay=0.004),
                  loss=intersection_over_union,
                  metrics=None
    )
    cb = [
        callbacks.ModelCheckpoint("../processed/model.h5", monitor="val_loss", verbose=1, save_best_only=True),
        callbacks.EarlyStopping(monitor='val_loss', patience=epochs // 10, min_delta=0.0001, verbose=10),
        callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
    ]
    rez = model.fit_generator(
        yield_batch(batch_size),
        steps_per_epoch=1000 // batch_size,
        epochs=epochs,
        callbacks=cb,
        validation_data=yield_batch_val(),
        validation_steps=len(set(votes.index))
    )
    return rez, model

# %%
rez, model = train_model(1, 16)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, None, 4)           0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, None, 128)         35328
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 128)               98816
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 68
# =================================================================
# Total params: 145,076
# Trainable params: 145,076
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 1000/1000 [==============================] - 18s 18ms/step - loss: -0.3504 - val_loss: -0.4117
#
# Epoch 00001: val_loss improved from inf to -0.41168, saving model to ../processed/model.h5
# Epoch 2/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.4354 - val_loss: -0.4575
#
# Epoch 00002: val_loss improved from -0.41168 to -0.45747, saving model to ../processed/model.h5
# Epoch 3/100
# 1000/1000 [==============================] - 15s 15ms/step - loss: -0.4371 - val_loss: -0.4719
#
# Epoch 00003: val_loss improved from -0.45747 to -0.47190, saving model to ../processed/model.h5
# Epoch 4/100
# 1000/1000 [==============================] - 15s 15ms/step - loss: -0.4453 - val_loss: -0.4759
#
# Epoch 00004: val_loss improved from -0.47190 to -0.47592, saving model to ../processed/model.h5
# Epoch 5/100
# 1000/1000 [==============================] - 15s 15ms/step - loss: -0.4583 - val_loss: -0.4782
#
# Epoch 00005: val_loss improved from -0.47592 to -0.47823, saving model to ../processed/model.h5
# Epoch 6/100
# 1000/1000 [==============================] - 15s 15ms/step - loss: -0.4745 - val_loss: -0.4851
#
# Epoch 00006: val_loss improved from -0.47823 to -0.48509, saving model to ../processed/model.h5
# Epoch 7/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.4776 - val_loss: -0.4663
#
# Epoch 00007: val_loss did not improve from -0.48509
# Epoch 8/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.4828 - val_loss: -0.4979
#
# Epoch 00008: val_loss improved from -0.48509 to -0.49788, saving model to ../processed/model.h5
# Epoch 9/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.4716 - val_loss: -0.4894
#
# Epoch 00009: val_loss did not improve from -0.49788
# Epoch 10/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.4788 - val_loss: -0.5079
#
# Epoch 00010: val_loss improved from -0.49788 to -0.50790, saving model to ../processed/model.h5
# Epoch 11/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.4743 - val_loss: -0.4887
#
# Epoch 00011: val_loss did not improve from -0.50790
# Epoch 12/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.4868 - val_loss: -0.4898
#
# Epoch 00012: val_loss did not improve from -0.50790
# Epoch 13/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.4854 - val_loss: -0.5145
#
# Epoch 00013: val_loss improved from -0.50790 to -0.51451, saving model to ../processed/model.h5
# Epoch 14/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.4890 - val_loss: -0.5032
#
# Epoch 00014: val_loss did not improve from -0.51451
# Epoch 15/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.4927 - val_loss: -0.4782
#
# Epoch 00015: val_loss did not improve from -0.51451
# Epoch 16/100
# 1000/1000 [==============================] - 15s 15ms/step - loss: -0.5039 - val_loss: -0.4946
#
# Epoch 00016: val_loss did not improve from -0.51451
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 17/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.5126 - val_loss: -0.5332
#
# Epoch 00017: val_loss improved from -0.51451 to -0.53315, saving model to ../processed/model.h5
# Epoch 18/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.5252 - val_loss: -0.5358
#
# Epoch 00018: val_loss improved from -0.53315 to -0.53585, saving model to ../processed/model.h5
# Epoch 19/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.5198 - val_loss: -0.5483
#
# Epoch 00019: val_loss improved from -0.53585 to -0.54832, saving model to ../processed/model.h5
# Epoch 20/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.5307 - val_loss: -0.5323
#
# Epoch 00020: val_loss did not improve from -0.54832
# Epoch 21/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.5532 - val_loss: -0.5508
#
# Epoch 00021: val_loss improved from -0.54832 to -0.55081, saving model to ../processed/model.h5
# Epoch 22/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.5285 - val_loss: -0.5428
#
# Epoch 00022: val_loss did not improve from -0.55081
# Epoch 23/100
# 1000/1000 [==============================] - 15s 15ms/step - loss: -0.5362 - val_loss: -0.5517
#
# Epoch 00023: val_loss improved from -0.55081 to -0.55169, saving model to ../processed/model.h5
# Epoch 24/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.5339 - val_loss: -0.5320
#
# Epoch 00024: val_loss did not improve from -0.55169
# Epoch 25/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.5380 - val_loss: -0.5399
#
# Epoch 00025: val_loss did not improve from -0.55169
# Epoch 26/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.5398 - val_loss: -0.5248
#
# Epoch 00026: val_loss did not improve from -0.55169
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 27/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.5448 - val_loss: -0.5503
#
# Epoch 00027: val_loss did not improve from -0.55169
# Epoch 28/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.5622 - val_loss: -0.5665
#
# Epoch 00028: val_loss improved from -0.55169 to -0.56650, saving model to ../processed/model.h5
# Epoch 29/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.5680 - val_loss: -0.5569
#
# Epoch 00029: val_loss did not improve from -0.56650
# Epoch 30/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.5660 - val_loss: -0.5745
#
# Epoch 00030: val_loss improved from -0.56650 to -0.57454, saving model to ../processed/model.h5
# Epoch 31/100
# 1000/1000 [==============================] - 15s 15ms/step - loss: -0.5582 - val_loss: -0.5397
#
# Epoch 00031: val_loss did not improve from -0.57454
# Epoch 32/100
# 1000/1000 [==============================] - 15s 15ms/step - loss: -0.5675 - val_loss: -0.5535
#
# Epoch 00032: val_loss did not improve from -0.57454
# Epoch 33/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.5707 - val_loss: -0.5648
#
# Epoch 00033: val_loss did not improve from -0.57454
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 34/100
# 1000/1000 [==============================] - 15s 15ms/step - loss: -0.5688 - val_loss: -0.5832
#
# Epoch 00034: val_loss improved from -0.57454 to -0.58322, saving model to ../processed/model.h5
# Epoch 35/100
# 1000/1000 [==============================] - 15s 15ms/step - loss: -0.5889 - val_loss: -0.5803
#
# Epoch 00035: val_loss did not improve from -0.58322
# Epoch 36/100
# 1000/1000 [==============================] - 15s 15ms/step - loss: -0.5880 - val_loss: -0.5845
#
# Epoch 00036: val_loss improved from -0.58322 to -0.58447, saving model to ../processed/model.h5
# Epoch 37/100
# 1000/1000 [==============================] - 15s 15ms/step - loss: -0.5883 - val_loss: -0.5857
#
# Epoch 00037: val_loss improved from -0.58447 to -0.58566, saving model to ../processed/model.h5
# Epoch 38/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.5788 - val_loss: -0.5834
#
# Epoch 00038: val_loss did not improve from -0.58566
# Epoch 39/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.5836 - val_loss: -0.5814
#
# Epoch 00039: val_loss did not improve from -0.58566
# Epoch 40/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.5936 - val_loss: -0.5814
#
# Epoch 00040: val_loss did not improve from -0.58566
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 41/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.5962 - val_loss: -0.5909
#
# Epoch 00041: val_loss improved from -0.58566 to -0.59085, saving model to ../processed/model.h5
# Epoch 42/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.5890 - val_loss: -0.5912
#
# Epoch 00042: val_loss improved from -0.59085 to -0.59124, saving model to ../processed/model.h5
# Epoch 43/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.5998 - val_loss: -0.5819
#
# Epoch 00043: val_loss did not improve from -0.59124
# Epoch 44/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.5991 - val_loss: -0.5955
#
# Epoch 00044: val_loss improved from -0.59124 to -0.59554, saving model to ../processed/model.h5
# Epoch 45/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.5936 - val_loss: -0.5942
#
# Epoch 00045: val_loss did not improve from -0.59554
# Epoch 46/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.5904 - val_loss: -0.5945
#
# Epoch 00046: val_loss did not improve from -0.59554
# Epoch 47/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.5938 - val_loss: -0.5944
#
# Epoch 00047: val_loss did not improve from -0.59554
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 48/100
# 1000/1000 [==============================] - 15s 15ms/step - loss: -0.6045 - val_loss: -0.5979
#
# Epoch 00048: val_loss improved from -0.59554 to -0.59791, saving model to ../processed/model.h5
# Epoch 49/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.5959 - val_loss: -0.5971
#
# Epoch 00049: val_loss did not improve from -0.59791
# Epoch 50/100
# 1000/1000 [==============================] - 15s 15ms/step - loss: -0.5985 - val_loss: -0.5980
#
# Epoch 00050: val_loss improved from -0.59791 to -0.59804, saving model to ../processed/model.h5
# Epoch 51/100
# 1000/1000 [==============================] - 15s 15ms/step - loss: -0.5908 - val_loss: -0.5984
#
# Epoch 00051: val_loss improved from -0.59804 to -0.59837, saving model to ../processed/model.h5
# Epoch 52/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.6026 - val_loss: -0.5977
#
# Epoch 00052: val_loss did not improve from -0.59837
# Epoch 53/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.6106 - val_loss: -0.5969
#
# Epoch 00053: val_loss did not improve from -0.59837
# Epoch 54/100
# 1000/1000 [==============================] - 15s 15ms/step - loss: -0.5967 - val_loss: -0.5983
#
# Epoch 00054: val_loss did not improve from -0.59837
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 55/100
# 1000/1000 [==============================] - 15s 15ms/step - loss: -0.6017 - val_loss: -0.6002
#
# Epoch 00055: val_loss improved from -0.59837 to -0.60016, saving model to ../processed/model.h5
# Epoch 56/100
# 1000/1000 [==============================] - 17s 17ms/step - loss: -0.6138 - val_loss: -0.5996
#
# Epoch 00056: val_loss did not improve from -0.60016
# Epoch 57/100
# 1000/1000 [==============================] - 17s 17ms/step - loss: -0.6147 - val_loss: -0.6010
#
# Epoch 00057: val_loss improved from -0.60016 to -0.60100, saving model to ../processed/model.h5
# Epoch 58/100
# 1000/1000 [==============================] - 15s 15ms/step - loss: -0.6093 - val_loss: -0.6010
#
# Epoch 00058: val_loss did not improve from -0.60100
# Epoch 59/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.6070 - val_loss: -0.6005
#
# Epoch 00059: val_loss did not improve from -0.60100
# Epoch 60/100
# 1000/1000 [==============================] - 15s 15ms/step - loss: -0.6092 - val_loss: -0.5993
#
# Epoch 00060: val_loss did not improve from -0.60100
#
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 61/100
# 1000/1000 [==============================] - 15s 15ms/step - loss: -0.6082 - val_loss: -0.6020
#
# Epoch 00061: val_loss improved from -0.60100 to -0.60204, saving model to ../processed/model.h5
# Epoch 62/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.6014 - val_loss: -0.6024
#
# Epoch 00062: val_loss improved from -0.60204 to -0.60244, saving model to ../processed/model.h5
# Epoch 63/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.6032 - val_loss: -0.6022
#
# Epoch 00063: val_loss did not improve from -0.60244
# Epoch 64/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.6051 - val_loss: -0.6023
#
# Epoch 00064: val_loss did not improve from -0.60244
# Epoch 65/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.6076 - val_loss: -0.6027
#
# Epoch 00065: val_loss improved from -0.60244 to -0.60266, saving model to ../processed/model.h5
# Epoch 66/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.6082 - val_loss: -0.6024
#
# Epoch 00066: val_loss did not improve from -0.60266
# Epoch 67/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.6140 - val_loss: -0.6027
#
# Epoch 00067: val_loss did not improve from -0.60266
# Epoch 68/100
# 1000/1000 [==============================] - 15s 15ms/step - loss: -0.6148 - val_loss: -0.6016
#
# Epoch 00068: val_loss did not improve from -0.60266
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 69/100
# 1000/1000 [==============================] - 15s 15ms/step - loss: -0.6086 - val_loss: -0.6025
#
# Epoch 00069: val_loss did not improve from -0.60266
# Epoch 70/100
# 1000/1000 [==============================] - 15s 15ms/step - loss: -0.6085 - val_loss: -0.6029
#
# Epoch 00070: val_loss improved from -0.60266 to -0.60286, saving model to ../processed/model.h5
# Epoch 71/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.6106 - val_loss: -0.6032
#
# Epoch 00071: val_loss improved from -0.60286 to -0.60317, saving model to ../processed/model.h5
# Epoch 72/100
# 1000/1000 [==============================] - 15s 15ms/step - loss: -0.6044 - val_loss: -0.6031
#
# Epoch 00072: val_loss did not improve from -0.60317
# Epoch 73/100
# 1000/1000 [==============================] - 15s 15ms/step - loss: -0.6048 - val_loss: -0.6034
#
# Epoch 00073: val_loss improved from -0.60317 to -0.60342, saving model to ../processed/model.h5
# Epoch 74/100
# 1000/1000 [==============================] - 15s 15ms/step - loss: -0.6065 - val_loss: -0.6030
#
# Epoch 00074: val_loss did not improve from -0.60342
# Epoch 75/100
# 1000/1000 [==============================] - 15s 15ms/step - loss: -0.6128 - val_loss: -0.6030
#
# Epoch 00075: val_loss did not improve from -0.60342
# Epoch 76/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.5984 - val_loss: -0.6031
#
# Epoch 00076: val_loss did not improve from -0.60342
#
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 77/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.6126 - val_loss: -0.6032
#
# Epoch 00077: val_loss did not improve from -0.60342
# Epoch 78/100
# 1000/1000 [==============================] - 15s 15ms/step - loss: -0.6050 - val_loss: -0.6034
#
# Epoch 00078: val_loss did not improve from -0.60342
# Epoch 79/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.6062 - val_loss: -0.6033
#
# Epoch 00079: val_loss did not improve from -0.60342
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 80/100
# 1000/1000 [==============================] - 15s 15ms/step - loss: -0.6071 - val_loss: -0.6035
#
# Epoch 00080: val_loss improved from -0.60342 to -0.60354, saving model to ../processed/model.h5
# Epoch 81/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.6175 - val_loss: -0.6034
#
# Epoch 00081: val_loss did not improve from -0.60354
# Epoch 82/100
# 1000/1000 [==============================] - 17s 17ms/step - loss: -0.6117 - val_loss: -0.6035
#
# Epoch 00082: val_loss did not improve from -0.60354
# Epoch 83/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.6186 - val_loss: -0.6037
#
# Epoch 00083: val_loss improved from -0.60354 to -0.60369, saving model to ../processed/model.h5
# Epoch 84/100
# 1000/1000 [==============================] - 16s 16ms/step - loss: -0.6115 - val_loss: -0.6037
#
# Epoch 00084: val_loss did not improve from -0.60369
# Epoch 85/100
# 1000/1000 [==============================] - 17s 17ms/step - loss: -0.6178 - val_loss: -0.6037
#
# Epoch 00085: val_loss improved from -0.60369 to -0.60371, saving model to ../processed/model.h5
# Epoch 86/100
#  642/1000 [==================>...........] - ETA: 4s - loss: -0.6013

# %%
pd.DataFrame(rez.history)[["loss", "val_loss"]].plot(figsize=(16, 8))

# %%
def make_forecast(model):
    subdir = time.strftime('%Y-%m-%d_%H-%M')
    path = pathlib.Path(f"../processed/{subdir}")
    path.mkdir(exist_ok=True)
    feat = yield_batch_test()
    df = model.predict_generator(feat, steps=len(votes_test.index.unique()))
    df = scaler.inverse_transform(df)
    df = pd.DataFrame(df, index=votes_test.index.unique())
    df.to_csv(path / "_sub_full.csv", header=False)
    # path.rename(path.parent / f"{subdir}-{score:0.1f}")

# %%
make_forecast(model)
