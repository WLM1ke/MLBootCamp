# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import time
from keras import layers
from keras import models
from keras import optimizers
from keras import callbacks
from keras import backend as K
from sklearn import model_selection
from sklearn import preprocessing
import pathlib
# Out:
# Using TensorFlow backend.

# %%
COORDINATES = ["Xmin", "Ymin", "Xmax", "Ymax"]

# %%
answers = pd.read_csv("../raw/train_answers.csv").set_index("itemId")
answers.columns = COORDINATES
scaler = preprocessing.StandardScaler().fit(np.vstack([answers.values, answers.values[:, [2, 3, 0, 1]]]))
answers[COORDINATES] = scaler.transform(answers[COORDINATES])
# Out:
# /Users/WLMike/Documents/PycharmProjects/ML_venv/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/WLMike/Documents/PycharmProjects/ML_venv/lib/python3.6/site-packages/ipykernel_launcher.py:4: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   after removing the cwd from sys.path.

# %%
votes = pd.read_csv("../raw/train_data.csv").set_index("itemId")
votes[COORDINATES] = scaler.transform(votes[COORDINATES])
# Out:
# /Users/WLMike/Documents/PycharmProjects/ML_venv/lib/python3.6/site-packages/ipykernel_launcher.py:2: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.

# %%
votes_test = pd.read_csv("../raw/test_data.csv").set_index("itemId")
votes_test[COORDINATES] = scaler.transform(votes_test[COORDINATES])
# Out:
# /Users/WLMike/Documents/PycharmProjects/ML_venv/lib/python3.6/site-packages/ipykernel_launcher.py:2: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.

# %%
def find_center(y):
    center_x = (y[0, 2] + y[0, 0]) / 2
    center_y = (y[0, 3] + y[0, 1]) / 2 
    return np.array([center_x, center_y, center_x, center_y])


def scale(x, y, err=0.1):
    center = find_center(y)
    x, y = x - np.reshape(center, (1, 1, 4)), y - np.reshape(center, (1, 4))
    
    err_x, err_y = np.random.random(2)  
    
    err_x = 1 + (2 * err_x - 1) * err
    err_y = 1 + (2 * err_y - 1) * err
    
    err = np.array([err_x, err_y, err_x, err_y])
    
    return (x * np.reshape(err, (1, 1, 4)) + np.reshape(center, (1, 1, 4)), 
            y * np.reshape(err, (1, 4)) + np.reshape(center, (1, 4)))
    

def move(x, y, err=0.1):
    center = find_center(y)
    x, y = x - np.reshape(center, (1, 1, 4)), y - np.reshape(center, (1, 4))
    
    size_x = (y[0, 2] - y[0, 0]) / 2
    size_y = (y[0, 3] - y[0, 1]) / 2
    
    err_cx, err_cy = np.random.random(2)  
    
    err_cx = (2 * size_x * err_cx - size_x) * err
    err_cy = (2 * size_y * err_cy - size_y) * err
    
    err = np.array([err_cx, err_cy, err_cx, err_cy])
    
    return x + np.reshape(err + center, (1, 1, 4)), y + np.reshape(err + center, (1, 4))
    
def aug_batch(x, y, err=0.1):
    x, y = scale(x, y, err)
    x, y = move(x, y, err)
    return x, y

# %%
def yield_batch(data, batch):
    votes, answers = data
    counts = votes[["userId"]].groupby("itemId").count()
    feat = votes.groupby("itemId")[COORDINATES].agg(["min", "max", "std", "median", "mean"])
    feat["count"] = counts
    item_ids = list(set(votes.index))
    while True:
        item_id = np.random.choice(item_ids, batch)
        x = feat.loc[item_id]
        y = answers.loc[item_id]
        yield x, y

# %%
def yield_batch_val(data):
    votes, answers = data
    counts = votes[["userId"]].groupby("itemId").count()
    feat = votes.groupby("itemId")[COORDINATES].agg(["min", "max", "std", "median", "mean"])
    feat["count"] = counts
    item_ids = set(votes.index)
    while True:
        x = feat.loc[[item_ids]]
        y = answers.loc[[item_ids]]
        yield x, y

# %%
def yield_batch_test(data):
    counts = data[["userId"]].groupby("itemId").count()
    feat = data.groupby("itemId")[COORDINATES].agg(["min", "max", "std", "median", "mean"])
    feat["count"] = counts
    item_ids = data.index.unique()
    for item_id in item_ids:
        x = feat.loc[[item_id]]
        yield x

# %%
def intersection_over_union(boxes_pred, boxes_true):

    x_min = K.stack([boxes_pred[:, 0], boxes_true[:, 0]], axis=-1)
    y_min = K.stack([boxes_pred[:, 1], boxes_true[:, 1]], axis=-1)
    x_max = K.stack([boxes_pred[:, 2], boxes_true[:, 2]], axis=-1)
    y_max = K.stack([boxes_pred[:, 3], boxes_true[:, 3]], axis=-1)

    x_min = K.max(x_min, axis=-1)
    y_min = K.max(y_min, axis=-1)
    x_max = K.min(x_max, axis=-1)
    y_max = K.min(y_max, axis=-1)

    zeros = K.zeros_like(x_max)

    x_inter = K.stack([zeros, x_max - x_min], axis=-1)
    y_inter = K.stack([zeros, y_max - y_min], axis=-1)

    x_inter = K.max(x_inter, axis=-1)
    y_inter = K.max(y_inter, axis=-1)
    inter_area = x_inter * y_inter
    
    area_pred = (K.max(K.stack([zeros, boxes_pred[:, 2] - boxes_pred[:, 0]], axis=-1), axis=-1) * 
                 K.max(K.stack([zeros, boxes_pred[:, 3] - boxes_pred[:, 1]], axis=-1), axis=-1))
    area_true = (K.max(K.stack([zeros, boxes_true[:, 2] - boxes_true[:, 0]], axis=-1), axis=-1) * 
                 K.max(K.stack([zeros, boxes_true[:, 3] - boxes_true[:, 1]], axis=-1), axis=-1))

    iou = inter_area / (area_pred + area_true - inter_area + K.epsilon())
    
    return -K.mean(iou, axis=-1)

# %%
def make_model(units):
    K.clear_session()
    
    y = x = layers.Input(shape=(21,))
    
    y = layers.Dense(
        units=units * 8,
        activation="relu"
    )(y)
    y = layers.Dense(
        units=units * 4,
        activation="relu"
    )(y)
    y = layers.Dense(
        units=units * 2,
        activation="relu"
    )(y)
    y = layers.Dense(
        units=units,
        activation="relu"
    )(y)
    y = layers.Dense(
        units=4,
        activation=None
    )(y)
    
    model = models.Model(inputs=x, outputs=y)
    model.summary()
    return model

# %%
class MaxLRTest(callbacks.Callback):

    def __init__(self, base_lr=1.0e-9, max_lr=10, steps=10000):
        super().__init__()

        self.base_lr = base_lr
        self.max_lr = max_lr
        self.steps = steps
        
        self.iterations = None
        self.history = None
        
    def clr(self):
        return self.base_lr * (self.max_lr / self.base_lr) ** (self.iterations / self.steps) 
  
    def on_train_begin(self, logs=None):
        self.iterations = 0
        self.history = {}
        K.set_value(self.model.optimizer.lr, self.base_lr)     
            
    def on_batch_end(self, batch, logs=None):
        if self.iterations > self.steps:
            self.model.stop_training = True
        
        self.history.setdefault("iterations", []).append(self.iterations)
        self.history.setdefault("lr", []).append(K.get_value(self.model.optimizer.lr))
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
            
        self.iterations += 1
        K.set_value(self.model.optimizer.lr, self.clr())
        
    def plot(self, smooth=None, t_score=2):
        smooth = int(smooth or self.steps // 10)
        df = pd.DataFrame(self.history).set_index("lr").loss.rolling(smooth).agg(["mean", "std"])
        df["std"] = df["mean"] + t_score * df["std"] / smooth ** 0.5
        print(f"Max speed learning rate  - {df['std'].idxmin():.1e}")
        df.plot(logx=True, figsize=(16, 8))

# %%
class DecayingLR(callbacks.Callback):

    def __init__(self, max_lr=0.1, warm_up=1, decay_per_epoch=1):
        super().__init__()

        self.max_lr = max_lr
        self.warm_up = warm_up
        self.decay_per_epoch = decay_per_epoch
        
        self.iterations = None
        self.history = None
        
        self.d_loss_iterations = None
        self.d_loss = None
        self.d_iterations = None
        self.d_iterations2 = None
        self.d_1 = None
                
        self.steps = None
        self.decay = None

    def on_train_begin(self, logs=None):
        self.iterations = 1
        self.history = {}
        
        self.d_loss_iterations = 0
        self.d_loss = 0
        self.d_iterations = 0
        self.d_iterations2 = 0
        self.d_1 = 0
        
        self.steps = self.params["steps"]
        self.decay = (1 - 1 / self.steps) ** (1 / self.decay_per_epoch)
        
        K.set_value(self.model.optimizer.lr, self.lr())
    
    def make_decay(self, old, new):
        decay = self.decay
        return old * decay + new * (1 - decay)
    
    def lr(self):
        warm_up = self.iterations / self.steps * self.warm_up
        if warm_up <= 1:
            return self.max_lr * warm_up 
        
        lr = self.history["lr"][-1]
        speed = self.history["speed"][-1]
        
        if speed > 0:
            return lr * self.decay
        
        return lr
            
    def on_batch_end(self, batch, logs=None):
        self.history.setdefault("iterations", []).append(self.iterations)
        self.history.setdefault("lr", []).append(K.get_value(self.model.optimizer.lr))
        
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
            
        self.d_loss_iterations = self.make_decay(self.d_loss_iterations, logs["loss"] * self.iterations)
        self.d_loss = self.make_decay(self.d_loss, logs["loss"])
        self.d_iterations = self.make_decay(self.d_iterations, self.iterations)
        self.d_iterations2 = self.make_decay(self.d_iterations2, self.iterations ** 2)
        self.d_1 = self.make_decay(self.d_1, 1)
        
        cov = self.d_loss_iterations - self.d_loss * self.d_iterations / self.d_1
        var = self.d_iterations2 - self.d_iterations ** 2 / self.d_1
        
        speed = self.steps * cov / var
        self.history.setdefault("speed", []).append(speed)
        
        self.iterations += 1
        K.set_value(self.model.optimizer.lr, self.lr())     
        
    def on_epoch_end(self, epoch, logs=None):
        lr = self.history["lr"][-1]
        speed = self.history["speed"][-1]
        print(f"Learning rate: {lr:.1e}")
        print(f"Speed per epoch: {speed:.4f}")
        print()
        
    def plot(self, smooth=None):
        smooth = int(smooth or self.steps)
        df = pd.DataFrame(self.history).set_index("iterations")[["loss", "lr"]].rolling(smooth).mean()
        df.plot(figsize=(16, 8), secondary_y="lr")

# %%
def train_model(data_train, data_val, units, batch, test=False):
    
    max_lr = 3.9e-03
    
    steps_per_epoch = 1000 // batch
    epochs = 40
    
    model = make_model(units)  
    
    model.compile(optimizer=optimizers.Nadam(lr=max_lr / 100, beta_1=0.9, beta_2=0.999, epsilon=None, schedule_decay=0.004),
                      loss="mae",
                      metrics=[intersection_over_union]
        )
    rez = model.fit_generator(
            yield_batch(data_train, batch),
            steps_per_epoch=1000,
            epochs=1,
            callbacks=None,
            validation_data=yield_batch_val(data_val),
            validation_steps=1,
        )
    
    
    model.compile(optimizer=optimizers.Nadam(lr=max_lr, beta_1=0.9, beta_2=0.999, epsilon=None, schedule_decay=0.004),
                  loss=intersection_over_union,
                  metrics=None
    )
    cycle = MaxLRTest() if test else DecayingLR(max_lr=max_lr)
    cb = [
        callbacks.ModelCheckpoint("../processed/model1.h5", monitor="val_loss", verbose=1, save_best_only=True),
        cycle
    ]
    rez = model.fit_generator(
        yield_batch(data_train, batch),
        steps_per_epoch=steps_per_epoch,
        epochs=epochs,
        callbacks=cb,
        validation_data=yield_batch_val(data_val),
        validation_steps=1,
        )
    
    model = models.load_model("../processed/model1.h5", custom_objects={"intersection_over_union": intersection_over_union})
    
    return rez, cycle, model

# %%
FOLDS = 10

def train_oof(train_set, test_set, units=16, batch=1):
    x_train, y_train = train_set
    x_test = test_set

    y_oof = pd.DataFrame(0, index=y_train.index, columns=COORDINATES)
    y_pred = pd.DataFrame(0, index=x_test.index.unique(), columns=COORDINATES)
    scores = []
    folds = model_selection.KFold(n_splits=FOLDS, shuffle=True)
    
    for n, (index_train, index_valid) in enumerate(folds.split(y_train), 1):
        print(f"\nFold - {n} / {FOLDS}")
        
        ids_train = y_train.index[index_train]
        ids_valid = y_train.index[index_valid]
        
        data_train = (x_train.loc[ids_train], y_train.loc[ids_train])
        data_val = (x_train.loc[ids_valid], y_train.loc[ids_valid])
        
        rez, cycle, model = train_model(data_train, data_val, units, batch)
        
        cycle.plot()
        pd.DataFrame(rez.history)[["loss", "val_loss"]].plot(figsize=(16, 8))
        scores.append(min(rez.history["val_loss"]))
        
        feat = yield_batch_test(data_val[0])
        df = model.predict_generator(feat, steps=len(data_val[0].index.unique()))
        df = scaler.inverse_transform(df)
        y_oof.loc[ids_valid] = df
        
        feat = yield_batch_test(x_test)
        df = model.predict_generator(feat, steps=len(x_test.index.unique()))
        df = scaler.inverse_transform(df)
        y_pred += df / FOLDS

    print(f"IOU на кроссвалидации: " + str(-np.round(sorted(scores), 5)))
    print(f"IOU среднее: {-np.mean(scores):0.5f} +/- {np.std(scores):0.5f}")

    subdir = time.strftime('%Y-%m-%d_%H-%M')
    path = pathlib.Path(f"../processed/{subdir}")
    path.mkdir(exist_ok=True)
    y_oof.to_csv(path / f"oof-{-np.mean(scores):0.5f}.csv", header=False)
    y_pred.to_csv(path / f"sub-{-np.mean(scores):0.5f}.csv", header=False)

# %%
train_oof((votes, answers), votes_test)
# Out:
# Fold - 1 / 10
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 21)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               2816
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 68
# =================================================================
# Total params: 13,748
# Trainable params: 13,748
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.6316 - intersection_over_union: -0.0657 - val_loss: 0.3779 - val_intersection_over_union: -0.2281
# Epoch 1/40
#   34/1000 [>.............................] - ETA: 20s - loss: -0.2351
# /Users/WLMike/Documents/PycharmProjects/ML_venv/lib/python3.6/site-packages/ipykernel_launcher.py:70: RuntimeWarning: invalid value encountered in double_scalars
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.3335 - val_loss: -0.2272
#
# Epoch 00001: val_loss improved from inf to -0.22724, saving model to ../processed/model1.h5
# Learning rate: 3.9e-03
# Speed per epoch: -0.0162
#
# Epoch 2/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.3775 - val_loss: -0.4290
#
# Epoch 00002: val_loss improved from -0.22724 to -0.42902, saving model to ../processed/model1.h5
# Learning rate: 3.7e-03
# Speed per epoch: -0.0453
#
# Epoch 3/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4084 - val_loss: -0.3996
#
# Epoch 00003: val_loss did not improve from -0.42902
# Learning rate: 3.7e-03
# Speed per epoch: -0.0332
#
# Epoch 4/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4500 - val_loss: -0.4110
#
# Epoch 00004: val_loss did not improve from -0.42902
# Learning rate: 3.7e-03
# Speed per epoch: -0.0324
#
# Epoch 5/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4459 - val_loss: -0.5013
#
# Epoch 00005: val_loss improved from -0.42902 to -0.50129, saving model to ../processed/model1.h5
# Learning rate: 3.7e-03
# Speed per epoch: -0.0162
#
# Epoch 6/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.4582 - val_loss: -0.4625
#
# Epoch 00006: val_loss did not improve from -0.50129
# Learning rate: 3.7e-03
# Speed per epoch: -0.0108
#
# Epoch 7/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4669 - val_loss: -0.4225
#
# Epoch 00007: val_loss did not improve from -0.50129
# Learning rate: 3.7e-03
# Speed per epoch: -0.0106
#
# Epoch 8/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4612 - val_loss: -0.5122
#
# Epoch 00008: val_loss improved from -0.50129 to -0.51217, saving model to ../processed/model1.h5
# Learning rate: 3.7e-03
# Speed per epoch: -0.0042
#
# Epoch 9/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4794 - val_loss: -0.4980
#
# Epoch 00009: val_loss did not improve from -0.51217
# Learning rate: 3.7e-03
# Speed per epoch: -0.0113
#
# Epoch 10/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4797 - val_loss: -0.5036
#
# Epoch 00010: val_loss did not improve from -0.51217
# Learning rate: 3.7e-03
# Speed per epoch: -0.0100
#
# Epoch 11/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4737 - val_loss: -0.4733
#
# Epoch 00011: val_loss did not improve from -0.51217
# Learning rate: 3.4e-03
# Speed per epoch: -0.0038
#
# Epoch 12/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4915 - val_loss: -0.5048
#
# Epoch 00012: val_loss did not improve from -0.51217
# Learning rate: 3.4e-03
# Speed per epoch: -0.0075
#
# Epoch 13/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4866 - val_loss: -0.5117
#
# Epoch 00013: val_loss did not improve from -0.51217
# Learning rate: 3.4e-03
# Speed per epoch: -0.0026
#
# Epoch 14/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4859 - val_loss: -0.5246
#
# Epoch 00014: val_loss improved from -0.51217 to -0.52455, saving model to ../processed/model1.h5
# Learning rate: 2.4e-03
# Speed per epoch: 0.0001
#
# Epoch 15/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5036 - val_loss: -0.5330
#
# Epoch 00015: val_loss improved from -0.52455 to -0.53302, saving model to ../processed/model1.h5
# Learning rate: 2.2e-03
# Speed per epoch: -0.0079
#
# Epoch 16/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5144 - val_loss: -0.4944
#
# Epoch 00016: val_loss did not improve from -0.53302
# Learning rate: 2.2e-03
# Speed per epoch: -0.0111
#
# Epoch 17/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5275 - val_loss: -0.5405
#
# Epoch 00017: val_loss improved from -0.53302 to -0.54055, saving model to ../processed/model1.h5
# Learning rate: 2.2e-03
# Speed per epoch: -0.0097
#
# Epoch 18/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5080 - val_loss: -0.5250
#
# Epoch 00018: val_loss did not improve from -0.54055
# Learning rate: 1.4e-03
# Speed per epoch: -0.0011
#
# Epoch 19/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5272 - val_loss: -0.5620
#
# Epoch 00019: val_loss improved from -0.54055 to -0.56200, saving model to ../processed/model1.h5
# Learning rate: 1.4e-03
# Speed per epoch: -0.0058
#
# Epoch 20/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5274 - val_loss: -0.5510
#
# Epoch 00020: val_loss did not improve from -0.56200
# Learning rate: 1.3e-03
# Speed per epoch: 0.0006
#
# Epoch 21/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5399 - val_loss: -0.5569
#
# Epoch 00021: val_loss did not improve from -0.56200
# Learning rate: 1.2e-03
# Speed per epoch: -0.0062
#
# Epoch 22/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5459 - val_loss: -0.5409
#
# Epoch 00022: val_loss did not improve from -0.56200
# Learning rate: 1.2e-03
# Speed per epoch: -0.0044
#
# Epoch 23/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5430 - val_loss: -0.5471
#
# Epoch 00023: val_loss did not improve from -0.56200
# Learning rate: 1.2e-03
# Speed per epoch: -0.0035
#
# Epoch 24/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5400 - val_loss: -0.5581
#
# Epoch 00024: val_loss did not improve from -0.56200
# Learning rate: 8.5e-04
# Speed per epoch: -0.0018
#
# Epoch 25/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5524 - val_loss: -0.5464
#
# Epoch 00025: val_loss did not improve from -0.56200
# Learning rate: 8.5e-04
# Speed per epoch: -0.0045
#
# Epoch 26/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5545 - val_loss: -0.5672
#
# Epoch 00026: val_loss improved from -0.56200 to -0.56721, saving model to ../processed/model1.h5
# Learning rate: 8.5e-04
# Speed per epoch: -0.0068
#
# Epoch 27/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5520 - val_loss: -0.5440
#
# Epoch 00027: val_loss did not improve from -0.56721
# Learning rate: 7.2e-04
# Speed per epoch: 0.0006
#
# Epoch 28/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5710 - val_loss: -0.5681
#
# Epoch 00028: val_loss improved from -0.56721 to -0.56805, saving model to ../processed/model1.h5
# Learning rate: 6.6e-04
# Speed per epoch: -0.0066
#
# Epoch 29/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5636 - val_loss: -0.5554
#
# Epoch 00029: val_loss did not improve from -0.56805
# Learning rate: 6.5e-04
# Speed per epoch: -0.0028
#
# Epoch 30/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5580 - val_loss: -0.5678
#
# Epoch 00030: val_loss did not improve from -0.56805
# Learning rate: 3.3e-04
# Speed per epoch: -0.0017
#
# Epoch 31/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5774 - val_loss: -0.5751
#
# Epoch 00031: val_loss improved from -0.56805 to -0.57513, saving model to ../processed/model1.h5
# Learning rate: 3.3e-04
# Speed per epoch: -0.0050
#
# Epoch 32/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5620 - val_loss: -0.5831
#
# Epoch 00032: val_loss improved from -0.57513 to -0.58306, saving model to ../processed/model1.h5
# Learning rate: 1.8e-04
# Speed per epoch: -0.0004
#
# Epoch 33/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5757 - val_loss: -0.5763
#
# Epoch 00033: val_loss did not improve from -0.58306
# Learning rate: 1.8e-04
# Speed per epoch: -0.0026
#
# Epoch 34/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5718 - val_loss: -0.5925
#
# Epoch 00034: val_loss improved from -0.58306 to -0.59251, saving model to ../processed/model1.h5
# Learning rate: 1.4e-04
# Speed per epoch: -0.0018
#
# Epoch 35/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5728 - val_loss: -0.5768
#
# Epoch 00035: val_loss did not improve from -0.59251
# Learning rate: 1.2e-04
# Speed per epoch: -0.0006
#
# Epoch 36/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5807 - val_loss: -0.5855
#
# Epoch 00036: val_loss did not improve from -0.59251
# Learning rate: 1.2e-04
# Speed per epoch: -0.0030
#
# Epoch 37/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5885 - val_loss: -0.5879
#
# Epoch 00037: val_loss did not improve from -0.59251
# Learning rate: 1.2e-04
# Speed per epoch: -0.0056
#
# Epoch 38/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5762 - val_loss: -0.5920
#
# Epoch 00038: val_loss did not improve from -0.59251
# Learning rate: 8.0e-05
# Speed per epoch: 0.0000
#
# Epoch 39/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5768 - val_loss: -0.5925
#
# Epoch 00039: val_loss did not improve from -0.59251
# Learning rate: 3.5e-05
# Speed per epoch: 0.0001
#
# Epoch 40/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5809 - val_loss: -0.5923
#
# Epoch 00040: val_loss did not improve from -0.59251
# Learning rate: 2.2e-05
# Speed per epoch: -0.0012
#
#
# Fold - 2 / 10
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 21)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               2816
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 68
# =================================================================
# Total params: 13,748
# Trainable params: 13,748
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.6394 - intersection_over_union: -0.1019 - val_loss: 0.4182 - val_intersection_over_union: -0.2483
# Epoch 1/40
# 1000/1000 [==============================] - 6s 6ms/step - loss: -0.3535 - val_loss: -0.3175
#
# Epoch 00001: val_loss improved from inf to -0.31748, saving model to ../processed/model1.h5
# Learning rate: 3.9e-03
# Speed per epoch: -0.0684
#
# Epoch 2/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.3873 - val_loss: -0.4019
#
# Epoch 00002: val_loss improved from -0.31748 to -0.40187, saving model to ../processed/model1.h5
# Learning rate: 3.9e-03
# Speed per epoch: -0.0459
#
# Epoch 3/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.3938 - val_loss: -0.4363
#
# Epoch 00003: val_loss improved from -0.40187 to -0.43627, saving model to ../processed/model1.h5
# Learning rate: 3.9e-03
# Speed per epoch: -0.0225
#
# Epoch 4/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4282 - val_loss: -0.4323
#
# Epoch 00004: val_loss did not improve from -0.43627
# Learning rate: 3.9e-03
# Speed per epoch: -0.0253
#
# Epoch 5/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4349 - val_loss: -0.4043
#
# Epoch 00005: val_loss did not improve from -0.43627
# Learning rate: 3.9e-03
# Speed per epoch: -0.0175
#
# Epoch 6/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4452 - val_loss: -0.4708
#
# Epoch 00006: val_loss improved from -0.43627 to -0.47077, saving model to ../processed/model1.h5
# Learning rate: 3.9e-03
# Speed per epoch: -0.0159
#
# Epoch 7/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4448 - val_loss: -0.4773
#
# Epoch 00007: val_loss improved from -0.47077 to -0.47727, saving model to ../processed/model1.h5
# Learning rate: 3.9e-03
# Speed per epoch: -0.0098
#
# Epoch 8/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4478 - val_loss: -0.4984
#
# Epoch 00008: val_loss improved from -0.47727 to -0.49843, saving model to ../processed/model1.h5
# Learning rate: 3.9e-03
# Speed per epoch: -0.0031
#
# Epoch 9/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4690 - val_loss: -0.4711
#
# Epoch 00009: val_loss did not improve from -0.49843
# Learning rate: 3.9e-03
# Speed per epoch: -0.0110
#
# Epoch 10/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4631 - val_loss: -0.4987
#
# Epoch 00010: val_loss improved from -0.49843 to -0.49868, saving model to ../processed/model1.h5
# Learning rate: 3.9e-03
# Speed per epoch: -0.0076
#
# Epoch 11/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4896 - val_loss: -0.5231
#
# Epoch 00011: val_loss improved from -0.49868 to -0.52310, saving model to ../processed/model1.h5
# Learning rate: 3.9e-03
# Speed per epoch: -0.0116
#
# Epoch 12/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4753 - val_loss: -0.4671
#
# Epoch 00012: val_loss did not improve from -0.52310
# Learning rate: 3.9e-03
# Speed per epoch: -0.0028
#
# Epoch 13/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4824 - val_loss: -0.4929
#
# Epoch 00013: val_loss did not improve from -0.52310
# Learning rate: 3.9e-03
# Speed per epoch: -0.0030
#
# Epoch 14/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4841 - val_loss: -0.5204
#
# Epoch 00014: val_loss did not improve from -0.52310
# Learning rate: 3.9e-03
# Speed per epoch: -0.0019
#
# Epoch 15/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4915 - val_loss: -0.4899
#
# Epoch 00015: val_loss did not improve from -0.52310
# Learning rate: 3.4e-03
# Speed per epoch: -0.0044
#
# Epoch 16/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4939 - val_loss: -0.4912
#
# Epoch 00016: val_loss did not improve from -0.52310
# Learning rate: 3.4e-03
# Speed per epoch: -0.0001
#
# Epoch 17/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5000 - val_loss: -0.5279
#
# Epoch 00017: val_loss improved from -0.52310 to -0.52791, saving model to ../processed/model1.h5
# Learning rate: 2.3e-03
# Speed per epoch: -0.0068
#
# Epoch 18/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5047 - val_loss: -0.5093
#
# Epoch 00018: val_loss did not improve from -0.52791
# Learning rate: 2.1e-03
# Speed per epoch: -0.0085
#
# Epoch 19/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5235 - val_loss: -0.5435
#
# Epoch 00019: val_loss improved from -0.52791 to -0.54353, saving model to ../processed/model1.h5
# Learning rate: 2.1e-03
# Speed per epoch: -0.0091
#
# Epoch 20/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5237 - val_loss: -0.5416
#
# Epoch 00020: val_loss did not improve from -0.54353
# Learning rate: 2.1e-03
# Speed per epoch: -0.0070
#
# Epoch 21/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5265 - val_loss: -0.4861
#
# Epoch 00021: val_loss did not improve from -0.54353
# Learning rate: 2.1e-03
# Speed per epoch: -0.0052
#
# Epoch 22/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5242 - val_loss: -0.5196
#
# Epoch 00022: val_loss did not improve from -0.54353
# Learning rate: 1.7e-03
# Speed per epoch: -0.0028
#
# Epoch 23/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5296 - val_loss: -0.5658
#
# Epoch 00023: val_loss improved from -0.54353 to -0.56584, saving model to ../processed/model1.h5
# Learning rate: 1.5e-03
# Speed per epoch: -0.0031
#
# Epoch 24/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5315 - val_loss: -0.4997
#
# Epoch 00024: val_loss did not improve from -0.56584
# Learning rate: 1.5e-03
# Speed per epoch: -0.0028
#
# Epoch 25/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5344 - val_loss: -0.5610
#
# Epoch 00025: val_loss did not improve from -0.56584
# Learning rate: 1.1e-03
# Speed per epoch: -0.0053
#
# Epoch 26/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5465 - val_loss: -0.5283
#
# Epoch 00026: val_loss did not improve from -0.56584
# Learning rate: 1.1e-03
# Speed per epoch: -0.0076
#
# Epoch 27/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5481 - val_loss: -0.5643
#
# Epoch 00027: val_loss did not improve from -0.56584
# Learning rate: 1.1e-03
# Speed per epoch: -0.0058
#
# Epoch 28/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5399 - val_loss: -0.5671
#
# Epoch 00028: val_loss improved from -0.56584 to -0.56707, saving model to ../processed/model1.h5
# Learning rate: 8.6e-04
# Speed per epoch: 0.0014
#
# Epoch 29/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5566 - val_loss: -0.5707
#
# Epoch 00029: val_loss improved from -0.56707 to -0.57067, saving model to ../processed/model1.h5
# Learning rate: 7.9e-04
# Speed per epoch: -0.0045
#
# Epoch 30/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5556 - val_loss: -0.5553
#
# Epoch 00030: val_loss did not improve from -0.57067
# Learning rate: 7.9e-04
# Speed per epoch: -0.0020
#
# Epoch 31/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5481 - val_loss: -0.5716
#
# Epoch 00031: val_loss improved from -0.57067 to -0.57160, saving model to ../processed/model1.h5
# Learning rate: 4.6e-04
# Speed per epoch: 0.0007
#
# Epoch 32/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5687 - val_loss: -0.5771
#
# Epoch 00032: val_loss improved from -0.57160 to -0.57711, saving model to ../processed/model1.h5
# Learning rate: 4.1e-04
# Speed per epoch: -0.0102
#
# Epoch 33/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5609 - val_loss: -0.5738
#
# Epoch 00033: val_loss did not improve from -0.57711
# Learning rate: 4.1e-04
# Speed per epoch: -0.0000
#
# Epoch 34/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5746 - val_loss: -0.5854
#
# Epoch 00034: val_loss improved from -0.57711 to -0.58538, saving model to ../processed/model1.h5
# Learning rate: 3.4e-04
# Speed per epoch: -0.0062
#
# Epoch 35/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5638 - val_loss: -0.5651
#
# Epoch 00035: val_loss did not improve from -0.58538
# Learning rate: 3.0e-04
# Speed per epoch: -0.0013
#
# Epoch 36/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5746 - val_loss: -0.5719
#
# Epoch 00036: val_loss did not improve from -0.58538
# Learning rate: 3.0e-04
# Speed per epoch: -0.0037
#
# Epoch 37/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5742 - val_loss: -0.5804
#
# Epoch 00037: val_loss did not improve from -0.58538
# Learning rate: 2.7e-04
# Speed per epoch: 0.0006
#
# Epoch 38/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5739 - val_loss: -0.5762
#
# Epoch 00038: val_loss did not improve from -0.58538
# Learning rate: 2.0e-04
# Speed per epoch: 0.0018
#
# Epoch 39/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5798 - val_loss: -0.5768
#
# Epoch 00039: val_loss did not improve from -0.58538
# Learning rate: 1.7e-04
# Speed per epoch: -0.0010
#
# Epoch 40/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5762 - val_loss: -0.5843
#
# Epoch 00040: val_loss did not improve from -0.58538
# Learning rate: 1.4e-04
# Speed per epoch: 0.0014
#
#
# Fold - 3 / 10
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 21)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               2816
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 68
# =================================================================
# Total params: 13,748
# Trainable params: 13,748
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.5741 - intersection_over_union: -0.0947 - val_loss: 0.4260 - val_intersection_over_union: -0.2298
# Epoch 1/40
# 1000/1000 [==============================] - 6s 6ms/step - loss: -0.3634 - val_loss: -0.3392
#
# Epoch 00001: val_loss improved from inf to -0.33918, saving model to ../processed/model1.h5
# Learning rate: 3.9e-03
# Speed per epoch: -0.0131
#
# Epoch 2/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.3933 - val_loss: -0.4226
#
# Epoch 00002: val_loss improved from -0.33918 to -0.42256, saving model to ../processed/model1.h5
# Learning rate: 3.4e-03
# Speed per epoch: -0.0290
#
# Epoch 3/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4312 - val_loss: -0.4376
#
# Epoch 00003: val_loss improved from -0.42256 to -0.43764, saving model to ../processed/model1.h5
# Learning rate: 3.4e-03
# Speed per epoch: -0.0341
#
# Epoch 4/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4281 - val_loss: -0.4752
#
# Epoch 00004: val_loss improved from -0.43764 to -0.47523, saving model to ../processed/model1.h5
# Learning rate: 3.4e-03
# Speed per epoch: -0.0187
#
# Epoch 5/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4459 - val_loss: -0.4745
#
# Epoch 00005: val_loss did not improve from -0.47523
# Learning rate: 3.4e-03
# Speed per epoch: -0.0136
#
# Epoch 6/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4707 - val_loss: -0.4604
#
# Epoch 00006: val_loss did not improve from -0.47523
# Learning rate: 3.4e-03
# Speed per epoch: -0.0161
#
# Epoch 7/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4516 - val_loss: -0.4813
#
# Epoch 00007: val_loss improved from -0.47523 to -0.48129, saving model to ../processed/model1.h5
# Learning rate: 3.2e-03
# Speed per epoch: -0.0011
#
# Epoch 8/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4655 - val_loss: -0.4898
#
# Epoch 00008: val_loss improved from -0.48129 to -0.48984, saving model to ../processed/model1.h5
# Learning rate: 3.1e-03
# Speed per epoch: -0.0075
#
# Epoch 9/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4763 - val_loss: -0.4569
#
# Epoch 00009: val_loss did not improve from -0.48984
# Learning rate: 3.1e-03
# Speed per epoch: -0.0087
#
# Epoch 10/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4760 - val_loss: -0.4566
#
# Epoch 00010: val_loss did not improve from -0.48984
# Learning rate: 3.1e-03
# Speed per epoch: -0.0043
#
# Epoch 11/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4775 - val_loss: -0.4787
#
# Epoch 00011: val_loss did not improve from -0.48984
# Learning rate: 2.7e-03
# Speed per epoch: -0.0055
#
# Epoch 12/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4868 - val_loss: -0.5047
#
# Epoch 00012: val_loss improved from -0.48984 to -0.50469, saving model to ../processed/model1.h5
# Learning rate: 2.7e-03
# Speed per epoch: -0.0053
#
# Epoch 13/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4816 - val_loss: -0.4895
#
# Epoch 00013: val_loss did not improve from -0.50469
# Learning rate: 2.7e-03
# Speed per epoch: -0.0004
#
# Epoch 14/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4909 - val_loss: -0.5413
#
# Epoch 00014: val_loss improved from -0.50469 to -0.54133, saving model to ../processed/model1.h5
# Learning rate: 1.8e-03
# Speed per epoch: -0.0077
#
# Epoch 15/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5100 - val_loss: -0.5366
#
# Epoch 00015: val_loss did not improve from -0.54133
# Learning rate: 1.8e-03
# Speed per epoch: -0.0122
#
# Epoch 16/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5251 - val_loss: -0.5295
#
# Epoch 00016: val_loss did not improve from -0.54133
# Learning rate: 1.8e-03
# Speed per epoch: -0.0150
#
# Epoch 17/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5055 - val_loss: -0.5480
#
# Epoch 00017: val_loss improved from -0.54133 to -0.54805, saving model to ../processed/model1.h5
# Learning rate: 1.7e-03
# Speed per epoch: -0.0013
#
# Epoch 18/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5260 - val_loss: -0.5367
#
# Epoch 00018: val_loss did not improve from -0.54805
# Learning rate: 1.7e-03
# Speed per epoch: -0.0048
#
# Epoch 19/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5254 - val_loss: -0.5333
#
# Epoch 00019: val_loss did not improve from -0.54805
# Learning rate: 1.7e-03
# Speed per epoch: -0.0048
#
# Epoch 20/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5191 - val_loss: -0.5353
#
# Epoch 00020: val_loss did not improve from -0.54805
# Learning rate: 1.5e-03
# Speed per epoch: 0.0046
#
# Epoch 21/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5381 - val_loss: -0.5530
#
# Epoch 00021: val_loss improved from -0.54805 to -0.55295, saving model to ../processed/model1.h5
# Learning rate: 1.1e-03
# Speed per epoch: -0.0053
#
# Epoch 22/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5411 - val_loss: -0.5558
#
# Epoch 00022: val_loss improved from -0.55295 to -0.55581, saving model to ../processed/model1.h5
# Learning rate: 1.1e-03
# Speed per epoch: -0.0089
#
# Epoch 23/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5379 - val_loss: -0.5508
#
# Epoch 00023: val_loss did not improve from -0.55581
# Learning rate: 1.1e-03
# Speed per epoch: -0.0029
#
# Epoch 24/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5418 - val_loss: -0.5235
#
# Epoch 00024: val_loss did not improve from -0.55581
# Learning rate: 1.1e-03
# Speed per epoch: -0.0043
#
# Epoch 25/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5446 - val_loss: -0.5545
#
# Epoch 00025: val_loss did not improve from -0.55581
# Learning rate: 9.9e-04
# Speed per epoch: -0.0059
#
# Epoch 26/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5398 - val_loss: -0.5501
#
# Epoch 00026: val_loss did not improve from -0.55581
# Learning rate: 7.9e-04
# Speed per epoch: 0.0017
#
# Epoch 27/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5514 - val_loss: -0.5600
#
# Epoch 00027: val_loss improved from -0.55581 to -0.55997, saving model to ../processed/model1.h5
# Learning rate: 4.5e-04
# Speed per epoch: -0.0061
#
# Epoch 28/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5597 - val_loss: -0.5641
#
# Epoch 00028: val_loss improved from -0.55997 to -0.56412, saving model to ../processed/model1.h5
# Learning rate: 4.5e-04
# Speed per epoch: -0.0062
#
# Epoch 29/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5628 - val_loss: -0.5660
#
# Epoch 00029: val_loss improved from -0.56412 to -0.56601, saving model to ../processed/model1.h5
# Learning rate: 4.5e-04
# Speed per epoch: -0.0054
#
# Epoch 30/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5667 - val_loss: -0.5690
#
# Epoch 00030: val_loss improved from -0.56601 to -0.56904, saving model to ../processed/model1.h5
# Learning rate: 4.5e-04
# Speed per epoch: -0.0020
#
# Epoch 31/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5636 - val_loss: -0.5741
#
# Epoch 00031: val_loss improved from -0.56904 to -0.57407, saving model to ../processed/model1.h5
# Learning rate: 4.0e-04
# Speed per epoch: 0.0016
#
# Epoch 32/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5678 - val_loss: -0.5701
#
# Epoch 00032: val_loss did not improve from -0.57407
# Learning rate: 3.0e-04
# Speed per epoch: 0.0006
#
# Epoch 33/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5684 - val_loss: -0.5736
#
# Epoch 00033: val_loss did not improve from -0.57407
# Learning rate: 2.3e-04
# Speed per epoch: -0.0002
#
# Epoch 34/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5754 - val_loss: -0.5711
#
# Epoch 00034: val_loss did not improve from -0.57407
# Learning rate: 2.1e-04
# Speed per epoch: -0.0012
#
# Epoch 35/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5739 - val_loss: -0.5742
#
# Epoch 00035: val_loss improved from -0.57407 to -0.57417, saving model to ../processed/model1.h5
# Learning rate: 1.7e-04
# Speed per epoch: -0.0018
#
# Epoch 36/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5892 - val_loss: -0.5785
#
# Epoch 00036: val_loss improved from -0.57417 to -0.57853, saving model to ../processed/model1.h5
# Learning rate: 1.7e-04
# Speed per epoch: -0.0056
#
# Epoch 37/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5748 - val_loss: -0.5770
#
# Epoch 00037: val_loss did not improve from -0.57853
# Learning rate: 1.1e-04
# Speed per epoch: -0.0011
#
# Epoch 38/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5802 - val_loss: -0.5734
#
# Epoch 00038: val_loss did not improve from -0.57853
# Learning rate: 8.5e-05
# Speed per epoch: -0.0017
#
# Epoch 39/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5812 - val_loss: -0.5751
#
# Epoch 00039: val_loss did not improve from -0.57853
# Learning rate: 5.8e-05
# Speed per epoch: -0.0020
#
# Epoch 40/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5839 - val_loss: -0.5779
#
# Epoch 00040: val_loss did not improve from -0.57853
# Learning rate: 5.4e-05
# Speed per epoch: -0.0029
#
#
# Fold - 4 / 10
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 21)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               2816
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 68
# =================================================================
# Total params: 13,748
# Trainable params: 13,748
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.6709 - intersection_over_union: -0.0256 - val_loss: 0.4956 - val_intersection_over_union: -0.1033
# Epoch 1/40
# 1000/1000 [==============================] - 6s 6ms/step - loss: -0.3368 - val_loss: -0.3163
#
# Epoch 00001: val_loss improved from inf to -0.31631, saving model to ../processed/model1.h5
# Learning rate: 3.9e-03
# Speed per epoch: -0.0965
#
# Epoch 2/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.3660 - val_loss: -0.4223
#
# Epoch 00002: val_loss improved from -0.31631 to -0.42234, saving model to ../processed/model1.h5
# Learning rate: 3.9e-03
# Speed per epoch: -0.0429
#
# Epoch 3/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4126 - val_loss: -0.3816
#
# Epoch 00003: val_loss did not improve from -0.42234
# Learning rate: 3.9e-03
# Speed per epoch: -0.0308
#
# Epoch 4/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.4196 - val_loss: -0.3896
#
# Epoch 00004: val_loss did not improve from -0.42234
# Learning rate: 3.9e-03
# Speed per epoch: -0.0187
#
# Epoch 5/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4402 - val_loss: -0.4143
#
# Epoch 00005: val_loss did not improve from -0.42234
# Learning rate: 3.9e-03
# Speed per epoch: -0.0181
#
# Epoch 6/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4453 - val_loss: -0.4253
#
# Epoch 00006: val_loss improved from -0.42234 to -0.42525, saving model to ../processed/model1.h5
# Learning rate: 3.9e-03
# Speed per epoch: -0.0143
#
# Epoch 7/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4665 - val_loss: -0.4291
#
# Epoch 00007: val_loss improved from -0.42525 to -0.42914, saving model to ../processed/model1.h5
# Learning rate: 3.9e-03
# Speed per epoch: -0.0152
#
# Epoch 8/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4651 - val_loss: -0.4622
#
# Epoch 00008: val_loss improved from -0.42914 to -0.46220, saving model to ../processed/model1.h5
# Learning rate: 3.9e-03
# Speed per epoch: -0.0107
#
# Epoch 9/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4680 - val_loss: -0.3878
#
# Epoch 00009: val_loss did not improve from -0.46220
# Learning rate: 3.9e-03
# Speed per epoch: -0.0046
#
# Epoch 10/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4672 - val_loss: -0.4766
#
# Epoch 00010: val_loss improved from -0.46220 to -0.47663, saving model to ../processed/model1.h5
# Learning rate: 3.1e-03
# Speed per epoch: 0.0010
#
# Epoch 11/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4848 - val_loss: -0.4522
#
# Epoch 00011: val_loss did not improve from -0.47663
# Learning rate: 2.9e-03
# Speed per epoch: -0.0067
#
# Epoch 12/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4844 - val_loss: -0.4287
#
# Epoch 00012: val_loss did not improve from -0.47663
# Learning rate: 2.9e-03
# Speed per epoch: -0.0042
#
# Epoch 13/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5158 - val_loss: -0.4510
#
# Epoch 00013: val_loss did not improve from -0.47663
# Learning rate: 2.9e-03
# Speed per epoch: -0.0162
#
# Epoch 14/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5099 - val_loss: -0.4782
#
# Epoch 00014: val_loss improved from -0.47663 to -0.47816, saving model to ../processed/model1.h5
# Learning rate: 2.9e-03
# Speed per epoch: -0.0094
#
# Epoch 15/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5071 - val_loss: -0.4654
#
# Epoch 00015: val_loss did not improve from -0.47816
# Learning rate: 2.7e-03
# Speed per epoch: -0.0004
#
# Epoch 16/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5057 - val_loss: -0.4675
#
# Epoch 00016: val_loss did not improve from -0.47816
# Learning rate: 1.6e-03
# Speed per epoch: 0.0008
#
# Epoch 17/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5258 - val_loss: -0.4715
#
# Epoch 00017: val_loss did not improve from -0.47816
# Learning rate: 1.5e-03
# Speed per epoch: -0.0040
#
# Epoch 18/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5263 - val_loss: -0.4970
#
# Epoch 00018: val_loss improved from -0.47816 to -0.49698, saving model to ../processed/model1.h5
# Learning rate: 1.5e-03
# Speed per epoch: -0.0039
#
# Epoch 19/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5285 - val_loss: -0.4821
#
# Epoch 00019: val_loss did not improve from -0.49698
# Learning rate: 1.5e-03
# Speed per epoch: -0.0015
#
# Epoch 20/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5350 - val_loss: -0.4975
#
# Epoch 00020: val_loss improved from -0.49698 to -0.49750, saving model to ../processed/model1.h5
# Learning rate: 1.3e-03
# Speed per epoch: -0.0034
#
# Epoch 21/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5361 - val_loss: -0.4935
#
# Epoch 00021: val_loss did not improve from -0.49750
# Learning rate: 1.3e-03
# Speed per epoch: -0.0046
#
# Epoch 22/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5449 - val_loss: -0.4984
#
# Epoch 00022: val_loss improved from -0.49750 to -0.49839, saving model to ../processed/model1.h5
# Learning rate: 1.3e-03
# Speed per epoch: -0.0062
#
# Epoch 23/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5491 - val_loss: -0.4905
#
# Epoch 00023: val_loss did not improve from -0.49839
# Learning rate: 1.3e-03
# Speed per epoch: -0.0037
#
# Epoch 24/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5393 - val_loss: -0.4951
#
# Epoch 00024: val_loss did not improve from -0.49839
# Learning rate: 7.9e-04
# Speed per epoch: -0.0028
#
# Epoch 25/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5682 - val_loss: -0.5162
#
# Epoch 00025: val_loss improved from -0.49839 to -0.51618, saving model to ../processed/model1.h5
# Learning rate: 7.9e-04
# Speed per epoch: -0.0109
#
# Epoch 26/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5564 - val_loss: -0.4997
#
# Epoch 00026: val_loss did not improve from -0.51618
# Learning rate: 7.9e-04
# Speed per epoch: -0.0033
#
# Epoch 27/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5643 - val_loss: -0.5011
#
# Epoch 00027: val_loss did not improve from -0.51618
# Learning rate: 6.7e-04
# Speed per epoch: -0.0061
#
# Epoch 28/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5612 - val_loss: -0.5190
#
# Epoch 00028: val_loss improved from -0.51618 to -0.51901, saving model to ../processed/model1.h5
# Learning rate: 5.7e-04
# Speed per epoch: 0.0004
#
# Epoch 29/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5793 - val_loss: -0.5252
#
# Epoch 00029: val_loss improved from -0.51901 to -0.52524, saving model to ../processed/model1.h5
# Learning rate: 5.1e-04
# Speed per epoch: -0.0074
#
# Epoch 30/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5683 - val_loss: -0.5225
#
# Epoch 00030: val_loss did not improve from -0.52524
# Learning rate: 5.1e-04
# Speed per epoch: -0.0010
#
# Epoch 31/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5728 - val_loss: -0.5238
#
# Epoch 00031: val_loss did not improve from -0.52524
# Learning rate: 4.3e-04
# Speed per epoch: -0.0008
#
# Epoch 32/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5784 - val_loss: -0.5216
#
# Epoch 00032: val_loss did not improve from -0.52524
# Learning rate: 3.5e-04
# Speed per epoch: -0.0033
#
# Epoch 33/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5737 - val_loss: -0.5288
#
# Epoch 00033: val_loss improved from -0.52524 to -0.52880, saving model to ../processed/model1.h5
# Learning rate: 2.6e-04
# Speed per epoch: -0.0017
#
# Epoch 34/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5776 - val_loss: -0.5411
#
# Epoch 00034: val_loss improved from -0.52880 to -0.54111, saving model to ../processed/model1.h5
# Learning rate: 1.9e-04
# Speed per epoch: 0.0004
#
# Epoch 35/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5773 - val_loss: -0.5358
#
# Epoch 00035: val_loss did not improve from -0.54111
# Learning rate: 1.2e-04
# Speed per epoch: -0.0008
#
# Epoch 36/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5748 - val_loss: -0.5403
#
# Epoch 00036: val_loss did not improve from -0.54111
# Learning rate: 7.2e-05
# Speed per epoch: -0.0022
#
# Epoch 37/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5854 - val_loss: -0.5435
#
# Epoch 00037: val_loss improved from -0.54111 to -0.54350, saving model to ../processed/model1.h5
# Learning rate: 7.2e-05
# Speed per epoch: -0.0037
#
# Epoch 38/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5810 - val_loss: -0.5381
#
# Epoch 00038: val_loss did not improve from -0.54350
# Learning rate: 6.1e-05
# Speed per epoch: -0.0003
#
# Epoch 39/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5799 - val_loss: -0.5376
#
# Epoch 00039: val_loss did not improve from -0.54350
# Learning rate: 3.6e-05
# Speed per epoch: -0.0003
#
# Epoch 40/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5868 - val_loss: -0.5393
#
# Epoch 00040: val_loss did not improve from -0.54350
# Learning rate: 3.4e-05
# Speed per epoch: -0.0010
#
#
# Fold - 5 / 10
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 21)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               2816
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 68
# =================================================================
# Total params: 13,748
# Trainable params: 13,748
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.7908 - intersection_over_union: -5.1620e-06 - val_loss: 0.7478 - val_intersection_over_union: -1.6315e-04
# Epoch 1/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.2714 - val_loss: -0.3282
#
# Epoch 00001: val_loss improved from inf to -0.32816, saving model to ../processed/model1.h5
# Learning rate: 3.9e-03
# Speed per epoch: -0.2116
#
# Epoch 2/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.3807 - val_loss: -0.4178
#
# Epoch 00002: val_loss improved from -0.32816 to -0.41784, saving model to ../processed/model1.h5
# Learning rate: 3.9e-03
# Speed per epoch: -0.0958
#
# Epoch 3/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4141 - val_loss: -0.3584
#
# Epoch 00003: val_loss did not improve from -0.41784
# Learning rate: 3.9e-03
# Speed per epoch: -0.0407
#
# Epoch 4/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4471 - val_loss: -0.4101
#
# Epoch 00004: val_loss did not improve from -0.41784
# Learning rate: 3.9e-03
# Speed per epoch: -0.0395
#
# Epoch 5/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4376 - val_loss: -0.4366
#
# Epoch 00005: val_loss improved from -0.41784 to -0.43665, saving model to ../processed/model1.h5
# Learning rate: 3.9e-03
# Speed per epoch: -0.0181
#
# Epoch 6/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4350 - val_loss: -0.3994
#
# Epoch 00006: val_loss did not improve from -0.43665
# Learning rate: 3.9e-03
# Speed per epoch: -0.0057
#
# Epoch 7/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4680 - val_loss: -0.4510
#
# Epoch 00007: val_loss improved from -0.43665 to -0.45097, saving model to ../processed/model1.h5
# Learning rate: 3.9e-03
# Speed per epoch: -0.0164
#
# Epoch 8/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4573 - val_loss: -0.4635
#
# Epoch 00008: val_loss improved from -0.45097 to -0.46348, saving model to ../processed/model1.h5
# Learning rate: 3.9e-03
# Speed per epoch: -0.0064
#
# Epoch 9/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4744 - val_loss: -0.4439
#
# Epoch 00009: val_loss did not improve from -0.46348
# Learning rate: 3.9e-03
# Speed per epoch: -0.0085
#
# Epoch 10/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4596 - val_loss: -0.4811
#
# Epoch 00010: val_loss improved from -0.46348 to -0.48111, saving model to ../processed/model1.h5
# Learning rate: 3.7e-03
# Speed per epoch: 0.0005
#
# Epoch 11/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4805 - val_loss: -0.4888
#
# Epoch 00011: val_loss improved from -0.48111 to -0.48884, saving model to ../processed/model1.h5
# Learning rate: 3.0e-03
# Speed per epoch: -0.0088
#
# Epoch 12/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4965 - val_loss: -0.5074
#
# Epoch 00012: val_loss improved from -0.48884 to -0.50741, saving model to ../processed/model1.h5
# Learning rate: 3.0e-03
# Speed per epoch: -0.0096
#
# Epoch 13/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4975 - val_loss: -0.4852
#
# Epoch 00013: val_loss did not improve from -0.50741
# Learning rate: 3.0e-03
# Speed per epoch: -0.0076
#
# Epoch 14/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4924 - val_loss: -0.5230
#
# Epoch 00014: val_loss improved from -0.50741 to -0.52305, saving model to ../processed/model1.h5
# Learning rate: 3.0e-03
# Speed per epoch: -0.0029
#
# Epoch 15/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5026 - val_loss: -0.4897
#
# Epoch 00015: val_loss did not improve from -0.52305
# Learning rate: 2.9e-03
# Speed per epoch: -0.0051
#
# Epoch 16/40
# 1000/1000 [==============================] - 6s 6ms/step - loss: -0.4994 - val_loss: -0.4821
#
# Epoch 00016: val_loss did not improve from -0.52305
# Learning rate: 2.9e-03
# Speed per epoch: 0.0003
#
# Epoch 17/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5083 - val_loss: -0.4925
#
# Epoch 00017: val_loss did not improve from -0.52305
# Learning rate: 1.8e-03
# Speed per epoch: -0.0073
#
# Epoch 18/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5233 - val_loss: -0.5151
#
# Epoch 00018: val_loss did not improve from -0.52305
# Learning rate: 1.8e-03
# Speed per epoch: -0.0102
#
# Epoch 19/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5265 - val_loss: -0.4956
#
# Epoch 00019: val_loss did not improve from -0.52305
# Learning rate: 1.8e-03
# Speed per epoch: -0.0098
#
# Epoch 20/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5124 - val_loss: -0.5103
#
# Epoch 00020: val_loss did not improve from -0.52305
# Learning rate: 1.3e-03
# Speed per epoch: 0.0026
#
# Epoch 21/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5486 - val_loss: -0.5533
#
# Epoch 00021: val_loss improved from -0.52305 to -0.55327, saving model to ../processed/model1.h5
# Learning rate: 1.2e-03
# Speed per epoch: -0.0106
#
# Epoch 22/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5423 - val_loss: -0.5300
#
# Epoch 00022: val_loss did not improve from -0.55327
# Learning rate: 1.2e-03
# Speed per epoch: -0.0046
#
# Epoch 23/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5339 - val_loss: -0.5439
#
# Epoch 00023: val_loss did not improve from -0.55327
# Learning rate: 9.2e-04
# Speed per epoch: 0.0013
#
# Epoch 24/40
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5579 - val_loss: -0.5640
#
# ...
#
# Epoch 00015: val_loss did not improve from -0.48010
# Learning rate: 1.7e-03
# Speed per epoch: -0.0030
#
# Epoch 16/40
# 1000/1000 [==============================] - 3s 3ms/step - loss: -0.5306 - val_loss: -0.4749
#
# Epoch 00016: val_loss did not improve from -0.48010
# Learning rate: 1.7e-03
# Speed per epoch: -0.0028
#
# Epoch 17/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5285 - val_loss: -0.4556
#
# Epoch 00017: val_loss did not improve from -0.48010
# Learning rate: 1.7e-03
# Speed per epoch: -0.0005
#
# Epoch 18/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5349 - val_loss: -0.4598
#
# Epoch 00018: val_loss did not improve from -0.48010
# Learning rate: 1.1e-03
# Speed per epoch: -0.0063
#
# Epoch 19/40
# 1000/1000 [==============================] - 3s 3ms/step - loss: -0.5450 - val_loss: -0.4851
#
# Epoch 00019: val_loss improved from -0.48010 to -0.48509, saving model to ../processed/model1.h5
# Learning rate: 1.1e-03
# Speed per epoch: -0.0050
#
# Epoch 20/40
# 1000/1000 [==============================] - 3s 3ms/step - loss: -0.5539 - val_loss: -0.5078
#
# Epoch 00020: val_loss improved from -0.48509 to -0.50778, saving model to ../processed/model1.h5
# Learning rate: 1.1e-03
# Speed per epoch: -0.0051
#
# Epoch 21/40
# 1000/1000 [==============================] - 3s 3ms/step - loss: -0.5379 - val_loss: -0.5116
#
# Epoch 00021: val_loss improved from -0.50778 to -0.51159, saving model to ../processed/model1.h5
# Learning rate: 7.0e-04
# Speed per epoch: 0.0015
#
# Epoch 22/40
# 1000/1000 [==============================] - 3s 3ms/step - loss: -0.5574 - val_loss: -0.5044
#
# Epoch 00022: val_loss did not improve from -0.51159
# Learning rate: 5.1e-04
# Speed per epoch: -0.0062
#
# Epoch 23/40
# 1000/1000 [==============================] - 3s 3ms/step - loss: -0.5590 - val_loss: -0.4940
#
# Epoch 00023: val_loss did not improve from -0.51159
# Learning rate: 5.1e-04
# Speed per epoch: -0.0066
#
# Epoch 24/40
# 1000/1000 [==============================] - 3s 3ms/step - loss: -0.5594 - val_loss: -0.4983
#
# Epoch 00024: val_loss did not improve from -0.51159
# Learning rate: 5.1e-04
# Speed per epoch: -0.0047
#
# Epoch 25/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5717 - val_loss: -0.5127
#
# Epoch 00025: val_loss improved from -0.51159 to -0.51272, saving model to ../processed/model1.h5
# Learning rate: 5.1e-04
# Speed per epoch: -0.0046
#
# Epoch 26/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5617 - val_loss: -0.5194
#
# Epoch 00026: val_loss improved from -0.51272 to -0.51942, saving model to ../processed/model1.h5
# Learning rate: 4.3e-04
# Speed per epoch: 0.0010
#
# Epoch 27/40
# 1000/1000 [==============================] - 3s 3ms/step - loss: -0.5664 - val_loss: -0.5106
#
# Epoch 00027: val_loss did not improve from -0.51942
# Learning rate: 2.8e-04
# Speed per epoch: -0.0010
#
# Epoch 28/40
# 1000/1000 [==============================] - 3s 3ms/step - loss: -0.5717 - val_loss: -0.5122
#
# Epoch 00028: val_loss did not improve from -0.51942
# Learning rate: 2.6e-04
# Speed per epoch: -0.0021
#
# Epoch 29/40
# 1000/1000 [==============================] - 3s 3ms/step - loss: -0.5787 - val_loss: -0.5213
#
# Epoch 00029: val_loss improved from -0.51942 to -0.52130, saving model to ../processed/model1.h5
# Learning rate: 2.6e-04
# Speed per epoch: -0.0032
#
# Epoch 30/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5785 - val_loss: -0.5138
#
# Epoch 00030: val_loss did not improve from -0.52130
# Learning rate: 2.6e-04
# Speed per epoch: -0.0040
#
# Epoch 31/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5728 - val_loss: -0.5101
#
# Epoch 00031: val_loss did not improve from -0.52130
# Learning rate: 1.5e-04
# Speed per epoch: -0.0026
#
# Epoch 32/40
# 1000/1000 [==============================] - 3s 3ms/step - loss: -0.5730 - val_loss: -0.5177
#
# Epoch 00032: val_loss did not improve from -0.52130
# Learning rate: 1.0e-04
# Speed per epoch: 0.0013
#
# Epoch 33/40
# 1000/1000 [==============================] - 3s 3ms/step - loss: -0.5903 - val_loss: -0.5160
#
# Epoch 00033: val_loss did not improve from -0.52130
# Learning rate: 8.4e-05
# Speed per epoch: -0.0067
#
# Epoch 34/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5828 - val_loss: -0.5218
#
# Epoch 00034: val_loss improved from -0.52130 to -0.52176, saving model to ../processed/model1.h5
# Learning rate: 8.3e-05
# Speed per epoch: -0.0041
#
# Epoch 35/40
# 1000/1000 [==============================] - 3s 3ms/step - loss: -0.5863 - val_loss: -0.5180
#
# Epoch 00035: val_loss did not improve from -0.52176
# Learning rate: 8.3e-05
# Speed per epoch: -0.0012
#
# Epoch 36/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5840 - val_loss: -0.5179
#
# Epoch 00036: val_loss did not improve from -0.52176
# Learning rate: 5.5e-05
# Speed per epoch: 0.0003
#
# Epoch 37/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5833 - val_loss: -0.5155
#
# Epoch 00037: val_loss did not improve from -0.52176
# Learning rate: 2.6e-05
# Speed per epoch: -0.0002
#
# Epoch 38/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5831 - val_loss: -0.5158
#
# Epoch 00038: val_loss did not improve from -0.52176
# Learning rate: 1.9e-05
# Speed per epoch: 0.0041
#
# Epoch 39/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5828 - val_loss: -0.5178
#
# Epoch 00039: val_loss did not improve from -0.52176
# Learning rate: 8.2e-06
# Speed per epoch: 0.0026
#
# Epoch 40/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5891 - val_loss: -0.5189
#
# Epoch 00040: val_loss did not improve from -0.52176
# Learning rate: 6.1e-06
# Speed per epoch: -0.0002
#
#
# Fold - 10 / 10
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 21)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               2816
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 68
# =================================================================
# Total params: 13,748
# Trainable params: 13,748
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.5202 - intersection_over_union: -0.1507 - val_loss: 0.2977 - val_intersection_over_union: -0.3365
# Epoch 1/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.3601 - val_loss: -0.3812
#
# Epoch 00001: val_loss improved from inf to -0.38119, saving model to ../processed/model1.h5
# Learning rate: 3.9e-03
# Speed per epoch: -0.0556
#
# Epoch 2/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.3805 - val_loss: -0.4293
#
# Epoch 00002: val_loss improved from -0.38119 to -0.42933, saving model to ../processed/model1.h5
# Learning rate: 3.9e-03
# Speed per epoch: -0.0089
#
# Epoch 3/40
# 1000/1000 [==============================] - 3s 3ms/step - loss: -0.4095 - val_loss: -0.4100
#
# Epoch 00003: val_loss did not improve from -0.42933
# Learning rate: 3.9e-03
# Speed per epoch: -0.0259
#
# Epoch 4/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.4237 - val_loss: -0.4376
#
# Epoch 00004: val_loss improved from -0.42933 to -0.43757, saving model to ../processed/model1.h5
# Learning rate: 3.9e-03
# Speed per epoch: -0.0148
#
# Epoch 5/40
# 1000/1000 [==============================] - 3s 3ms/step - loss: -0.4507 - val_loss: -0.4436
#
# Epoch 00005: val_loss improved from -0.43757 to -0.44361, saving model to ../processed/model1.h5
# Learning rate: 3.9e-03
# Speed per epoch: -0.0227
#
# Epoch 6/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.4437 - val_loss: -0.4909
#
# Epoch 00006: val_loss improved from -0.44361 to -0.49087, saving model to ../processed/model1.h5
# Learning rate: 3.9e-03
# Speed per epoch: -0.0112
#
# Epoch 7/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.4405 - val_loss: -0.4396
#
# Epoch 00007: val_loss did not improve from -0.49087
# Learning rate: 3.6e-03
# Speed per epoch: -0.0033
#
# Epoch 8/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.4644 - val_loss: -0.4377
#
# Epoch 00008: val_loss did not improve from -0.49087
# Learning rate: 3.6e-03
# Speed per epoch: -0.0067
#
# Epoch 9/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.4783 - val_loss: -0.4342
#
# Epoch 00009: val_loss did not improve from -0.49087
# Learning rate: 3.6e-03
# Speed per epoch: -0.0114
#
# Epoch 10/40
# 1000/1000 [==============================] - 3s 3ms/step - loss: -0.4751 - val_loss: -0.4995
#
# Epoch 00010: val_loss improved from -0.49087 to -0.49946, saving model to ../processed/model1.h5
# Learning rate: 3.6e-03
# Speed per epoch: -0.0089
#
# Epoch 11/40
# 1000/1000 [==============================] - 3s 3ms/step - loss: -0.4729 - val_loss: -0.4984
#
# Epoch 00011: val_loss did not improve from -0.49946
# Learning rate: 3.4e-03
# Speed per epoch: -0.0066
#
# Epoch 12/40
# 1000/1000 [==============================] - 3s 3ms/step - loss: -0.4939 - val_loss: -0.5029
#
# Epoch 00012: val_loss improved from -0.49946 to -0.50293, saving model to ../processed/model1.h5
# Learning rate: 3.4e-03
# Speed per epoch: -0.0098
#
# Epoch 13/40
# 1000/1000 [==============================] - 3s 3ms/step - loss: -0.4769 - val_loss: -0.4806
#
# Epoch 00013: val_loss did not improve from -0.50293
# Learning rate: 3.1e-03
# Speed per epoch: -0.0012
#
# Epoch 14/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.4850 - val_loss: -0.5083
#
# Epoch 00014: val_loss improved from -0.50293 to -0.50835, saving model to ../processed/model1.h5
# Learning rate: 2.1e-03
# Speed per epoch: -0.0029
#
# Epoch 15/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5116 - val_loss: -0.5165
#
# Epoch 00015: val_loss improved from -0.50835 to -0.51648, saving model to ../processed/model1.h5
# Learning rate: 2.1e-03
# Speed per epoch: -0.0105
#
# Epoch 16/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5211 - val_loss: -0.5044
#
# Epoch 00016: val_loss did not improve from -0.51648
# Learning rate: 2.1e-03
# Speed per epoch: -0.0088
#
# Epoch 17/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5131 - val_loss: -0.5141
#
# Epoch 00017: val_loss did not improve from -0.51648
# Learning rate: 2.1e-03
# Speed per epoch: -0.0045
#
# Epoch 18/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5145 - val_loss: -0.5338
#
# Epoch 00018: val_loss improved from -0.51648 to -0.53379, saving model to ../processed/model1.h5
# Learning rate: 1.9e-03
# Speed per epoch: -0.0049
#
# Epoch 19/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5235 - val_loss: -0.5250
#
# Epoch 00019: val_loss did not improve from -0.53379
# Learning rate: 1.9e-03
# Speed per epoch: -0.0007
#
# Epoch 20/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5418 - val_loss: -0.5367
#
# Epoch 00020: val_loss improved from -0.53379 to -0.53670, saving model to ../processed/model1.h5
# Learning rate: 1.9e-03
# Speed per epoch: -0.0070
#
# Epoch 21/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5364 - val_loss: -0.5215
#
# Epoch 00021: val_loss did not improve from -0.53670
# Learning rate: 1.9e-03
# Speed per epoch: -0.0038
#
# Epoch 22/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5287 - val_loss: -0.5340
#
# Epoch 00022: val_loss did not improve from -0.53670
# Learning rate: 1.6e-03
# Speed per epoch: 0.0040
#
# Epoch 23/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5473 - val_loss: -0.5245
#
# Epoch 00023: val_loss did not improve from -0.53670
# Learning rate: 1.3e-03
# Speed per epoch: -0.0044
#
# Epoch 24/40
# 1000/1000 [==============================] - 3s 3ms/step - loss: -0.5425 - val_loss: -0.5303
#
# Epoch 00024: val_loss did not improve from -0.53670
# Learning rate: 1.3e-03
# Speed per epoch: -0.0025
#
# Epoch 25/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5380 - val_loss: -0.5464
#
# Epoch 00025: val_loss improved from -0.53670 to -0.54636, saving model to ../processed/model1.h5
# Learning rate: 7.9e-04
# Speed per epoch: -0.0013
#
# Epoch 26/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5550 - val_loss: -0.5331
#
# Epoch 00026: val_loss did not improve from -0.54636
# Learning rate: 7.9e-04
# Speed per epoch: -0.0045
#
# Epoch 27/40
# 1000/1000 [==============================] - 3s 3ms/step - loss: -0.5585 - val_loss: -0.5444
#
# Epoch 00027: val_loss did not improve from -0.54636
# Learning rate: 7.9e-04
# Speed per epoch: -0.0022
#
# Epoch 28/40
# 1000/1000 [==============================] - 3s 3ms/step - loss: -0.5619 - val_loss: -0.5174
#
# Epoch 00028: val_loss did not improve from -0.54636
# Learning rate: 7.9e-04
# Speed per epoch: -0.0033
#
# Epoch 29/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5593 - val_loss: -0.5351
#
# Epoch 00029: val_loss did not improve from -0.54636
# Learning rate: 7.7e-04
# Speed per epoch: -0.0029
#
# Epoch 30/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5622 - val_loss: -0.5449
#
# Epoch 00030: val_loss did not improve from -0.54636
# Learning rate: 7.0e-04
# Speed per epoch: 0.0000
#
# Epoch 31/40
# 1000/1000 [==============================] - 3s 3ms/step - loss: -0.5604 - val_loss: -0.5353
#
# Epoch 00031: val_loss did not improve from -0.54636
# Learning rate: 4.7e-04
# Speed per epoch: 0.0006
#
# Epoch 32/40
# 1000/1000 [==============================] - 3s 3ms/step - loss: -0.5727 - val_loss: -0.5530
#
# Epoch 00032: val_loss improved from -0.54636 to -0.55303, saving model to ../processed/model1.h5
# Learning rate: 3.4e-04
# Speed per epoch: -0.0064
#
# Epoch 33/40
# 1000/1000 [==============================] - 3s 3ms/step - loss: -0.5764 - val_loss: -0.5537
#
# Epoch 00033: val_loss improved from -0.55303 to -0.55374, saving model to ../processed/model1.h5
# Learning rate: 3.4e-04
# Speed per epoch: -0.0052
#
# Epoch 34/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5761 - val_loss: -0.5443
#
# Epoch 00034: val_loss did not improve from -0.55374
# Learning rate: 3.4e-04
# Speed per epoch: -0.0040
#
# Epoch 35/40
# 1000/1000 [==============================] - 3s 3ms/step - loss: -0.5730 - val_loss: -0.5460
#
# Epoch 00035: val_loss did not improve from -0.55374
# Learning rate: 2.9e-04
# Speed per epoch: -0.0003
#
# Epoch 36/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5769 - val_loss: -0.5578
#
# Epoch 00036: val_loss improved from -0.55374 to -0.55780, saving model to ../processed/model1.h5
# Learning rate: 1.5e-04
# Speed per epoch: -0.0041
#
# Epoch 37/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5806 - val_loss: -0.5564
#
# Epoch 00037: val_loss did not improve from -0.55780
# Learning rate: 1.5e-04
# Speed per epoch: -0.0022
#
# Epoch 38/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5823 - val_loss: -0.5546
#
# Epoch 00038: val_loss did not improve from -0.55780
# Learning rate: 1.4e-04
# Speed per epoch: -0.0037
#
# Epoch 39/40
# 1000/1000 [==============================] - 4s 4ms/step - loss: -0.5817 - val_loss: -0.5559
#
# Epoch 00039: val_loss did not improve from -0.55780
# Learning rate: 1.1e-04
# Speed per epoch: -0.0032
#
# Epoch 40/40
# 1000/1000 [==============================] - 3s 3ms/step - loss: -0.5799 - val_loss: -0.5570
#
# Epoch 00040: val_loss did not improve from -0.55780
# Learning rate: 8.9e-05
# Speed per epoch: 0.0012
#
# IOU на кроссвалидации: [0.59251 0.58538 0.58118 0.57932 0.57853 0.56546 0.5578  0.5435  0.53851
#  0.52176]
# IOU среднее: 0.56439 +/- 0.02215
