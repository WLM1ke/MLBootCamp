# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import time
import keras
from keras import layers
from keras import models
from keras import optimizers
from keras import callbacks
from keras import backend as K
from sklearn import model_selection
from sklearn import preprocessing
import pathlib

COORDINATES = ["Xmin", "Ymin", "Xmax", "Ymax"]
# Out:
# Using TensorFlow backend.

# %%
votes = pd.read_csv("../raw/train_data.csv").set_index("itemId")

# %%
answers = pd.read_csv("../raw/train_answers.csv").set_index("itemId")
answers.columns = COORDINATES

# %%
votes_test = pd.read_csv("../raw/test_data.csv").set_index("itemId")

# %%
scaler = preprocessing.StandardScaler().fit(np.vstack([answers.values, answers.values[:, [2, 3, 0, 1]]]))
# Out:
# /Users/WLMike/Documents/PycharmProjects/ML_venv/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
def make_feat(df):
    df = df.copy(deep=True)
    df[COORDINATES] = scaler.transform(df[COORDINATES])
    counts = df[["userId"]].groupby("itemId").count()
    feat = df.groupby("itemId")[COORDINATES].agg(["min", "max", "std", "median", "mean"])
    feat["count"] = counts
    return feat

# %%
def intersection_over_union(boxes_pred, boxes_true):

    x_min = K.stack([boxes_pred[:, 0], boxes_true[:, 0]], axis=-1)
    y_min = K.stack([boxes_pred[:, 1], boxes_true[:, 1]], axis=-1)
    x_max = K.stack([boxes_pred[:, 2], boxes_true[:, 2]], axis=-1)
    y_max = K.stack([boxes_pred[:, 3], boxes_true[:, 3]], axis=-1)

    x_min = K.max(x_min, axis=-1)
    y_min = K.max(y_min, axis=-1)
    x_max = K.min(x_max, axis=-1)
    y_max = K.min(y_max, axis=-1)

    zeros = K.zeros_like(x_max)

    x_inter = K.stack([zeros, x_max - x_min], axis=-1)
    y_inter = K.stack([zeros, y_max - y_min], axis=-1)

    x_inter = K.max(x_inter, axis=-1)
    y_inter = K.max(y_inter, axis=-1)
    inter_area = x_inter * y_inter
    
    area_pred = (K.max(K.stack([zeros, boxes_pred[:, 2] - boxes_pred[:, 0]], axis=-1), axis=-1) * 
                 K.max(K.stack([zeros, boxes_pred[:, 3] - boxes_pred[:, 1]], axis=-1), axis=-1))
    area_true = (K.max(K.stack([zeros, boxes_true[:, 2] - boxes_true[:, 0]], axis=-1), axis=-1) * 
                 K.max(K.stack([zeros, boxes_true[:, 3] - boxes_true[:, 1]], axis=-1), axis=-1))

    iou = inter_area / (area_pred + area_true - inter_area + K.epsilon())
    
    return -K.mean(iou, axis=-1)

# %%
def make_model(units):
    K.clear_session()
    
    y = x = layers.Input(shape=(21,))
    
    y = layers.Dense(
        units=units * 8,
        activation="relu"
    )(y)
    y = layers.Dense(
        units=units * 4,
        activation="relu"
    )(y)
    y = layers.Dense(
        units=units * 2,
        activation="relu"
    )(y)
    y = layers.Dense(
        units=units,
        activation="relu"
    )(y)
    y = layers.Dense(
        units=4,
        activation=None
    )(y)
    
    model = models.Model(inputs=x, outputs=y)
    model.summary()
    return model

# %%
def train_model(batch_size, units, epochs=100):
    model = make_model(units)
    
    lr=0.001
    
    y = scaler.transform(answers[COORDINATES])
    
    # ФИнальное обучение
    model.compile(optimizer=optimizers.Nadam(lr=lr, beta_1=0.9, beta_2=0.999, epsilon=None, schedule_decay=0.004),
                  loss=intersection_over_union,
                  metrics=None
    )
    cb = [
        callbacks.ModelCheckpoint("../processed/model.h5", monitor="val_loss", verbose=1, save_best_only=True),
        callbacks.EarlyStopping(monitor='val_loss', patience=epochs // 10, min_delta=0.0001, verbose=10),
        callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=1, verbose=1)
    ]
    rez = model.fit(
        x=make_feat(votes),
        y=y,
        batch_size=batch_size,
        epochs=epochs,
        callbacks=cb,
        validation_data=[make_feat(votes), y],
    )
    return rez, model

# %%
rez, model = train_model(1, 16)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 21)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                1408
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_4 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 36
# =================================================================
# Total params: 4,188
# Trainable params: 4,188
# Non-trainable params: 0
# _________________________________________________________________
# /Users/WLMike/Documents/PycharmProjects/ML_venv/lib/python3.6/site-packages/ipykernel_launcher.py:6: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#
# /Users/WLMike/Documents/PycharmProjects/ML_venv/lib/python3.6/site-packages/ipykernel_launcher.py:3: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/WLMike/Documents/PycharmProjects/ML_venv/lib/python3.6/site-packages/ipykernel_launcher.py:3: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Train on 943 samples, validate on 943 samples
# Epoch 1/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.3315 - val_loss: -0.4538
#
# Epoch 00001: val_loss improved from inf to -0.45378, saving model to ../processed/model.h5
# Epoch 2/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.4522 - val_loss: -0.4830
#
# Epoch 00002: val_loss improved from -0.45378 to -0.48298, saving model to ../processed/model.h5
# Epoch 3/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.4758 - val_loss: -0.4586
#
# Epoch 00003: val_loss did not improve from -0.48298
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# Epoch 4/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.4959 - val_loss: -0.5130
#
# Epoch 00004: val_loss improved from -0.48298 to -0.51303, saving model to ../processed/model.h5
# Epoch 5/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5042 - val_loss: -0.4885
#
# Epoch 00005: val_loss did not improve from -0.51303
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# Epoch 6/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5192 - val_loss: -0.5165
#
# Epoch 00006: val_loss improved from -0.51303 to -0.51647, saving model to ../processed/model.h5
# Epoch 7/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5181 - val_loss: -0.5401
#
# Epoch 00007: val_loss improved from -0.51647 to -0.54010, saving model to ../processed/model.h5
# Epoch 8/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5231 - val_loss: -0.5409
#
# Epoch 00008: val_loss improved from -0.54010 to -0.54091, saving model to ../processed/model.h5
# Epoch 9/100
# 943/943 [==============================] - 1s 2ms/step - loss: -0.5224 - val_loss: -0.4988
#
# Epoch 00009: val_loss did not improve from -0.54091
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
# Epoch 10/100
# 943/943 [==============================] - 1s 2ms/step - loss: -0.5326 - val_loss: -0.5535
#
# Epoch 00010: val_loss improved from -0.54091 to -0.55354, saving model to ../processed/model.h5
# Epoch 11/100
# 943/943 [==============================] - 1s 2ms/step - loss: -0.5356 - val_loss: -0.5559
#
# Epoch 00011: val_loss improved from -0.55354 to -0.55593, saving model to ../processed/model.h5
# Epoch 12/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5371 - val_loss: -0.5460
#
# Epoch 00012: val_loss did not improve from -0.55593
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
# Epoch 13/100
# 943/943 [==============================] - 1s 2ms/step - loss: -0.5452 - val_loss: -0.5332
#
# Epoch 00013: val_loss did not improve from -0.55593
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00032768002711236477.
# Epoch 14/100
# 943/943 [==============================] - 1s 2ms/step - loss: -0.5525 - val_loss: -0.5547
#
# Epoch 00014: val_loss did not improve from -0.55593
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0002621440216898918.
# Epoch 15/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5581 - val_loss: -0.5650
#
# Epoch 00015: val_loss improved from -0.55593 to -0.56502, saving model to ../processed/model.h5
# Epoch 16/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5613 - val_loss: -0.5496
#
# Epoch 00016: val_loss did not improve from -0.56502
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.00020971521735191345.
# Epoch 17/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5651 - val_loss: -0.5683
#
# Epoch 00017: val_loss improved from -0.56502 to -0.56832, saving model to ../processed/model.h5
# Epoch 18/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5650 - val_loss: -0.5710
#
# Epoch 00018: val_loss improved from -0.56832 to -0.57103, saving model to ../processed/model.h5
# Epoch 19/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5669 - val_loss: -0.5721
#
# Epoch 00019: val_loss improved from -0.57103 to -0.57213, saving model to ../processed/model.h5
# Epoch 20/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5663 - val_loss: -0.5723
#
# Epoch 00020: val_loss improved from -0.57213 to -0.57227, saving model to ../processed/model.h5
# Epoch 21/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5681 - val_loss: -0.5714
#
# Epoch 00021: val_loss did not improve from -0.57227
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.00016777217388153076.
# Epoch 22/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5715 - val_loss: -0.5783
#
# Epoch 00022: val_loss improved from -0.57227 to -0.57829, saving model to ../processed/model.h5
# Epoch 23/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5730 - val_loss: -0.5807
#
# Epoch 00023: val_loss improved from -0.57829 to -0.58071, saving model to ../processed/model.h5
# Epoch 24/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5727 - val_loss: -0.5794
#
# Epoch 00024: val_loss did not improve from -0.58071
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.00013421773910522462.
# Epoch 25/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5750 - val_loss: -0.5713
#
# Epoch 00025: val_loss did not improve from -0.58071
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.00010737419361248613.
# Epoch 26/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5778 - val_loss: -0.5879
#
# Epoch 00026: val_loss improved from -0.58071 to -0.58790, saving model to ../processed/model.h5
# Epoch 27/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5794 - val_loss: -0.5819
#
# Epoch 00027: val_loss did not improve from -0.58790
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 8.589935605414213e-05.
# Epoch 28/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5825 - val_loss: -0.5816
#
# Epoch 00028: val_loss did not improve from -0.58790
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 6.871948717162013e-05.
# Epoch 29/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5843 - val_loss: -0.5890
#
# Epoch 00029: val_loss improved from -0.58790 to -0.58901, saving model to ../processed/model.h5
# Epoch 30/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5858 - val_loss: -0.5862
#
# Epoch 00030: val_loss did not improve from -0.58901
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 5.497558740898967e-05.
# Epoch 31/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5874 - val_loss: -0.5902
#
# Epoch 00031: val_loss improved from -0.58901 to -0.59020, saving model to ../processed/model.h5
# Epoch 32/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5877 - val_loss: -0.5872
#
# Epoch 00032: val_loss did not improve from -0.59020
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 4.398046876303852e-05.
# Epoch 33/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5893 - val_loss: -0.5924
#
# Epoch 00033: val_loss improved from -0.59020 to -0.59242, saving model to ../processed/model.h5
# Epoch 34/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5895 - val_loss: -0.5911
#
# Epoch 00034: val_loss did not improve from -0.59242
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 3.518437442835421e-05.
# Epoch 35/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5906 - val_loss: -0.5931
#
# Epoch 00035: val_loss improved from -0.59242 to -0.59306, saving model to ../processed/model.h5
# Epoch 36/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5908 - val_loss: -0.5892
#
# Epoch 00036: val_loss did not improve from -0.59306
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 2.8147498960606756e-05.
# Epoch 37/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5919 - val_loss: -0.5904
#
# Epoch 00037: val_loss did not improve from -0.59306
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 2.25179988774471e-05.
# Epoch 38/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5928 - val_loss: -0.5941
# Epoch 00038: val_loss improved from -0.59306 to -0.59413, saving model to ../processed/model.h5
# Epoch 39/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5926 - val_loss: -0.5962
#
# Epoch 00039: val_loss improved from -0.59413 to -0.59615, saving model to ../processed/model.h5
# Epoch 40/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5934 - val_loss: -0.5947
#
# Epoch 00040: val_loss did not improve from -0.59615
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 1.8014399392995985e-05.
# Epoch 41/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5939 - val_loss: -0.5947
#
# Epoch 00041: val_loss did not improve from -0.59615
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 1.4411519805435093e-05.
# Epoch 42/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5948 - val_loss: -0.5963
#
# Epoch 00042: val_loss improved from -0.59615 to -0.59635, saving model to ../processed/model.h5
# Epoch 43/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5947 - val_loss: -0.5965
#
# Epoch 00043: val_loss improved from -0.59635 to -0.59653, saving model to ../processed/model.h5
# Epoch 44/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5948 - val_loss: -0.5968
#
# Epoch 00044: val_loss improved from -0.59653 to -0.59682, saving model to ../processed/model.h5
# Epoch 45/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5949 - val_loss: -0.5966
#
# Epoch 00045: val_loss did not improve from -0.59682
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 1.1529216135386379e-05.
# Epoch 46/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5956 - val_loss: -0.5965
#
# Epoch 00046: val_loss did not improve from -0.59682
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 9.223372762789951e-06.
# Epoch 47/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5961 - val_loss: -0.5972
#
# Epoch 00047: val_loss improved from -0.59682 to -0.59717, saving model to ../processed/model.h5
# Epoch 48/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5961 - val_loss: -0.5973
#
# Epoch 00048: val_loss improved from -0.59717 to -0.59725, saving model to ../processed/model.h5
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 7.378698501270265e-06.
# Epoch 49/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5968 - val_loss: -0.5972
#
# Epoch 00049: val_loss did not improve from -0.59725
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 5.902958946535364e-06.
# Epoch 50/100
# 943/943 [==============================] - 1s 2ms/step - loss: -0.5965 - val_loss: -0.5976
#
# Epoch 00050: val_loss improved from -0.59725 to -0.59762, saving model to ../processed/model.h5
# Epoch 51/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5969 - val_loss: -0.5975
#
# Epoch 00051: val_loss did not improve from -0.59762
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 4.7223671572282915e-06.
# Epoch 52/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5971 - val_loss: -0.5978
#
# Epoch 00052: val_loss improved from -0.59762 to -0.59781, saving model to ../processed/model.h5
# Epoch 53/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5971 - val_loss: -0.5978
#
# Epoch 00053: val_loss did not improve from -0.59781
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 3.7778936530230567e-06.
# Epoch 54/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5973 - val_loss: -0.5980
#
# Epoch 00054: val_loss improved from -0.59781 to -0.59797, saving model to ../processed/model.h5
# Epoch 55/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5974 - val_loss: -0.5979
#
# Epoch 00055: val_loss did not improve from -0.59797
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 3.0223149224184457e-06.
# Epoch 56/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5975 - val_loss: -0.5980
#
# Epoch 00056: val_loss improved from -0.59797 to -0.59804, saving model to ../processed/model.h5
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 2.4178520106943328e-06.
# Epoch 57/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5976 - val_loss: -0.5981
#
# Epoch 00057: val_loss improved from -0.59804 to -0.59814, saving model to ../processed/model.h5
# Epoch 58/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5978 - val_loss: -0.5980
#
# Epoch 00058: val_loss did not improve from -0.59814
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 1.9342816813150422e-06.
# Epoch 59/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5979 - val_loss: -0.5979
#
# Epoch 00059: val_loss did not improve from -0.59814
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 1.547425381431822e-06.
# Epoch 60/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5978 - val_loss: -0.5982
#
# Epoch 00060: val_loss improved from -0.59814 to -0.59819, saving model to ../processed/model.h5
#
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 1.2379403415252455e-06.
# Epoch 61/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5980 - val_loss: -0.5982
#
# Epoch 00061: val_loss did not improve from -0.59819
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 9.903522368404083e-07.
# Epoch 62/100
# 943/943 [==============================] - 1s 2ms/step - loss: -0.5980 - val_loss: -0.5982
#
# Epoch 00062: val_loss improved from -0.59819 to -0.59822, saving model to ../processed/model.h5
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 7.922817530925386e-07.
# Epoch 63/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5981 - val_loss: -0.5982
#
# Epoch 00063: val_loss improved from -0.59822 to -0.59822, saving model to ../processed/model.h5
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 6.338254024740309e-07.
# Epoch 64/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5981 - val_loss: -0.5982
#
# Epoch 00064: val_loss improved from -0.59822 to -0.59823, saving model to ../processed/model.h5
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 5.070603037893307e-07.
# Epoch 65/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5981 - val_loss: -0.5982
#
# Epoch 00065: val_loss improved from -0.59823 to -0.59825, saving model to ../processed/model.h5
# Epoch 66/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5982 - val_loss: -0.5982
#
# Epoch 00066: val_loss did not improve from -0.59825
#
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 4.056482339365175e-07.
# Epoch 67/100
# 943/943 [==============================] - 1s 2ms/step - loss: -0.5982 - val_loss: -0.5982
#
# Epoch 00067: val_loss did not improve from -0.59825
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 3.24518578054267e-07.
# Epoch 68/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5982 - val_loss: -0.5983
#
# Epoch 00068: val_loss improved from -0.59825 to -0.59827, saving model to ../processed/model.h5
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 2.5961485334846656e-07.
# Epoch 69/100
# 943/943 [==============================] - 1s 2ms/step - loss: -0.5982 - val_loss: -0.5983
#
# Epoch 00069: val_loss improved from -0.59827 to -0.59827, saving model to ../processed/model.h5
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 2.076918917737203e-07.
# Epoch 70/100
# 943/943 [==============================] - 1s 2ms/step - loss: -0.5982 - val_loss: -0.5983
#
# Epoch 00070: val_loss improved from -0.59827 to -0.59828, saving model to ../processed/model.h5
#
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 1.6615351796644973e-07.
# Epoch 71/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5982 - val_loss: -0.5983
#
# Epoch 00071: val_loss improved from -0.59828 to -0.59828, saving model to ../processed/model.h5
#
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 1.329228098256863e-07.
# Epoch 72/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5983 - val_loss: -0.5983
#
# Epoch 00072: val_loss improved from -0.59828 to -0.59828, saving model to ../processed/model.h5
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 1.0633824558681227e-07.
# Epoch 73/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5983 - val_loss: -0.5983
#
# Epoch 00073: val_loss improved from -0.59828 to -0.59828, saving model to ../processed/model.h5
#
# Epoch 00073: ReduceLROnPlateau reducing learning rate to 8.507059874318657e-08.
# Epoch 74/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5983 - val_loss: -0.5983
#
# Epoch 00074: val_loss improved from -0.59828 to -0.59828, saving model to ../processed/model.h5
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 6.80564767208125e-08.
# Epoch 75/100
# 943/943 [==============================] - 2s 2ms/step - loss: -0.5983 - val_loss: -0.5983
#
# Epoch 00075: val_loss improved from -0.59828 to -0.59829, saving model to ../processed/model.h5
#
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 5.4445183650386755e-08.
# Epoch 00075: early stopping

# %%
pd.DataFrame(rez.history)[["loss", "val_loss"]].plot(figsize=(16, 8))

# %%
def make_forecast(model):
    subdir = time.strftime('%Y-%m-%d_%H-%M')
    path = pathlib.Path(f"../processed/{subdir}")
    path.mkdir(exist_ok=True)
    feat = make_feat(votes_test)
    df = model.predict(feat)
    df = scaler.inverse_transform(df)
    df = pd.DataFrame(df, index=feat.index)
    df.to_csv(path / "_sub_full.csv", header=False)
    # path.rename(path.parent / f"{subdir}-{score:0.1f}")

# %%
make_forecast(model)
# Out:
# /Users/WLMike/Documents/PycharmProjects/ML_venv/lib/python3.6/site-packages/ipykernel_launcher.py:3: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   This is separate from the ipykernel package so we can avoid doing imports until
