# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import time
from keras import layers
from keras import models
from keras import optimizers
from keras import callbacks
from keras import backend as K
from sklearn import model_selection
from sklearn import preprocessing
import pathlib
# Out:
# Using TensorFlow backend.

# %%
COORDINATES = ["Xmin", "Ymin", "Xmax", "Ymax"]

# %%
answers = pd.read_csv("../raw/train_answers.csv").set_index("itemId")
answers.columns = COORDINATES
scaler = preprocessing.StandardScaler().fit(np.vstack([answers.values, answers.values[:, [2, 3, 0, 1]]]))
answers[COORDINATES] = scaler.transform(answers[COORDINATES])
# Out:
# /Users/WLMike/Documents/PycharmProjects/ML_venv/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/WLMike/Documents/PycharmProjects/ML_venv/lib/python3.6/site-packages/ipykernel_launcher.py:4: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   after removing the cwd from sys.path.

# %%
votes = pd.read_csv("../raw/train_data.csv").set_index("itemId")
votes[COORDINATES] = scaler.transform(votes[COORDINATES])
# Out:
# /Users/WLMike/Documents/PycharmProjects/ML_venv/lib/python3.6/site-packages/ipykernel_launcher.py:2: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.

# %%
votes_test = pd.read_csv("../raw/test_data.csv").set_index("itemId")
votes_test[COORDINATES] = scaler.transform(votes_test[COORDINATES])
# Out:
# /Users/WLMike/Documents/PycharmProjects/ML_venv/lib/python3.6/site-packages/ipykernel_launcher.py:2: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.

# %%
def yield_batch(data):
    votes, answers = data
    item_ids = list(set(votes.index))
    while True:
        item_id = np.random.choice(item_ids, 1)
        forecasts = votes.loc[item_id].set_index("userId")
        x = np.zeros((1, len(forecasts), 4),)
        y = np.zeros((1, 4))
        x[0] = forecasts.sample(len(forecasts))
        y[0] = answers.loc[item_id]
        yield x, y

# %%
def yield_batch_val(data):
    votes, answers = data
    item_ids = set(votes.index)
    while True:
        for item_id in item_ids:
            forecasts = votes.loc[item_id].set_index("userId")
            x = np.zeros((1, len(forecasts), 4),)
            y = np.zeros((1, 4))

            x[0] = forecasts
            y[0] = answers.loc[item_id]
            yield x, y

# %%
def yield_batch_test(data):
    item_ids = data.index.unique()
    for item_id in item_ids:
        forecasts = data.loc[item_id].set_index("userId")
        x = np.zeros((1, len(forecasts), 4),)
        y = np.zeros((1, 4))
        x[0] = forecasts
        yield x

# %%
def intersection_over_union(boxes_pred, boxes_true):

    x_min = K.stack([boxes_pred[:, 0], boxes_true[:, 0]], axis=-1)
    y_min = K.stack([boxes_pred[:, 1], boxes_true[:, 1]], axis=-1)
    x_max = K.stack([boxes_pred[:, 2], boxes_true[:, 2]], axis=-1)
    y_max = K.stack([boxes_pred[:, 3], boxes_true[:, 3]], axis=-1)

    x_min = K.max(x_min, axis=-1)
    y_min = K.max(y_min, axis=-1)
    x_max = K.min(x_max, axis=-1)
    y_max = K.min(y_max, axis=-1)

    zeros = K.zeros_like(x_max)

    x_inter = K.stack([zeros, x_max - x_min], axis=-1)
    y_inter = K.stack([zeros, y_max - y_min], axis=-1)

    x_inter = K.max(x_inter, axis=-1)
    y_inter = K.max(y_inter, axis=-1)
    inter_area = x_inter * y_inter
    
    area_pred = (K.max(K.stack([zeros, boxes_pred[:, 2] - boxes_pred[:, 0]], axis=-1), axis=-1) * 
                 K.max(K.stack([zeros, boxes_pred[:, 3] - boxes_pred[:, 1]], axis=-1), axis=-1))
    area_true = (K.max(K.stack([zeros, boxes_true[:, 2] - boxes_true[:, 0]], axis=-1), axis=-1) * 
                 K.max(K.stack([zeros, boxes_true[:, 3] - boxes_true[:, 1]], axis=-1), axis=-1))

    iou = inter_area / (area_pred + area_true - inter_area + K.epsilon())
    
    return -K.mean(iou, axis=-1)

# %%
def make_model(filters):
    K.clear_session()
    
    y = x = layers.Input(shape=(None, 4))
    
    mul = 4
    y = layers.Conv1D(
        filters=filters * mul,
        kernel_size=3,
        strides=1,
        padding="same"
    )(y)
    y = layers.Conv1D(
        filters=filters * mul,
        kernel_size=3,
        strides=1,
        padding="same"
    )(y)
    y = layers.Conv1D(
        filters=filters * mul,
        kernel_size=3,
        strides=1,
        padding="same"
    )(y)
    y = layers.Conv1D(
        filters=filters * mul,
        kernel_size=3,
        strides=1,
        padding="same"
    )(y)
    y = layers.Conv1D(
        filters=filters * mul,
        kernel_size=3,
        strides=1,
        padding="same"
    )(y)
    y = layers.Conv1D(
        filters=filters * mul,
        kernel_size=3,
        strides=1,
        padding="same"
    )(y)
    y = layers.GlobalAveragePooling1D()(y)
    
    y = layers.Dense(
        units=filters * 2,
        activation="relu"
    )(y)
    y = layers.Dense(
        units=4,
        activation=None
    )(y)
    
    model = models.Model(inputs=x, outputs=y)
    model.summary()
    return model

# %%
class MaxLRTest(callbacks.Callback):

    def __init__(self, base_lr=1.0e-9, max_lr=10, steps=10000):
        super().__init__()

        self.base_lr = base_lr
        self.max_lr = max_lr
        self.steps = steps
        
        self.iterations = None
        self.history = None
        
    def clr(self):
        return self.base_lr * (self.max_lr / self.base_lr) ** (self.iterations / self.steps) 
  
    def on_train_begin(self, logs=None):
        self.iterations = 0
        self.history = {}
        K.set_value(self.model.optimizer.lr, self.base_lr)     
            
    def on_batch_end(self, batch, logs=None):
        if self.iterations > self.steps:
            self.model.stop_training = True
        
        self.history.setdefault("iterations", []).append(self.iterations)
        self.history.setdefault("lr", []).append(K.get_value(self.model.optimizer.lr))
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
            
        self.iterations += 1
        K.set_value(self.model.optimizer.lr, self.clr())
        
    def plot(self, smooth=None, t_score=2):
        smooth = int(smooth or self.steps // 10)
        df = pd.DataFrame(self.history).set_index("lr").loss.rolling(smooth).agg(["mean", "std"])
        df["std"] = df["mean"] + t_score * df["std"] / smooth ** 0.5
        print(f"Max speed learning rate  - {df['std'].idxmin():.1e}")
        df.plot(logx=True, figsize=(16, 8))

# %%
class DecayingLR(callbacks.Callback):

    def __init__(self, max_lr=0.1, warm_up=1, decay_per_epoch=1, epsilon=0.0001, wait=3):
        super().__init__()

        self.max_lr = max_lr
        self.warm_up = warm_up
        self.decay_per_epoch = decay_per_epoch
        self.epsilon=epsilon
        self.wait=wait
        
        self.iterations = None
        self.history = None
        
        self.d_loss_iterations = None
        self.d_loss = None
        self.d_iterations = None
        self.d_iterations2 = None
        self.d_1 = None
                
        self.steps = None
        self.decay = None
        
        self.wait_count=None
        self.prev_loss=None

    def on_train_begin(self, logs=None):
        self.iterations = 1
        self.history = {}
        
        self.d_loss_iterations = 0.0
        self.d_loss = 0.0
        self.d_iterations = 0.0
        self.d_iterations2 = 0.0
        self.d_1 = 0.0
        
        self.steps = self.params["steps"]
        self.decay = (1 - 1 / self.steps) ** (1 / self.decay_per_epoch)
        
        self.wait_count=0
        self.prev_loss=None
        
        K.set_value(self.model.optimizer.lr, self.lr())
    
    def make_decay(self, old, new):
        decay = self.decay
        return old * decay + new * (1 - decay)
    
    def lr(self):
        warm_up = self.iterations / self.steps * self.warm_up
        if warm_up <= 1:
            return self.max_lr * warm_up 
        
        lr = self.history["lr"][-1]
        speed = self.history["speed"][-1]
        
        if speed > 0:
            return lr * self.decay
        
        return lr
            
    def on_batch_end(self, batch, logs=None):
        self.history.setdefault("iterations", []).append(self.iterations)
        self.history.setdefault("lr", []).append(K.get_value(self.model.optimizer.lr))
        
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
            
        self.d_loss_iterations = self.make_decay(self.d_loss_iterations, logs["loss"] * self.iterations)
        self.d_loss = self.make_decay(self.d_loss, logs["loss"])
        self.d_iterations = self.make_decay(self.d_iterations, self.iterations)
        self.d_iterations2 = self.make_decay(self.d_iterations2, self.iterations ** 2)
        self.d_1 = self.make_decay(self.d_1, 1)
        
        cov = self.d_loss_iterations - self.d_loss * self.d_iterations / self.d_1
        var = self.d_iterations2 - self.d_iterations ** 2 / self.d_1
        
        speed = self.steps * cov / var
        self.history.setdefault("speed", []).append(speed)
        
        self.iterations += 1
        K.set_value(self.model.optimizer.lr, self.lr())     
        
    def on_epoch_end(self, epoch, logs=None):
        lr = self.history["lr"][-1]
        speed = self.history["speed"][-1]
        print(f"Learning rate: {lr:.1e}")
        print(f"Speed per epoch: {speed:.4f}")
        
        if self.prev_loss is None:
            self.prev_loss = logs["val_loss"]
        elif abs(self.prev_loss - logs["val_loss"]) < self.epsilon:
            self.wait_count += 1
        else:
            self.wait_count = 0
        self.prev_loss = logs["val_loss"]
        print(f"Wait to stop: {self.wait - self.wait_count}\n")
        if self.wait == self.wait_count:
            self.model.stop_training = True
        
    def plot(self, smooth=None):
        smooth = int(smooth or self.steps)
        df = pd.DataFrame(self.history).set_index("iterations")[["loss", "lr"]].rolling(smooth).mean()
        df.plot(figsize=(16, 8), secondary_y="lr")

# %%
def train_model(data_train, data_val, units, test=False):
    
    max_lr =  3.8e-04
    
    steps = 100000
    steps_per_epoch = 1000
    epochs = steps // steps_per_epoch
    
    model = make_model(units)  
    
    model.compile(optimizer=optimizers.Nadam(lr=max_lr / 100, beta_1=0.9, beta_2=0.999, epsilon=None, schedule_decay=0.004),
                      loss="mae",
                      metrics=[intersection_over_union]
        )
    rez = model.fit_generator(
            yield_batch(data_train),
            steps_per_epoch=1000,
            epochs=1,
            callbacks=None,
            validation_data=yield_batch_val(data_val),
            validation_steps=len(data_val[1].index),
        )
    
    
    model.compile(optimizer=optimizers.Nadam(lr=max_lr, beta_1=0.9, beta_2=0.999, epsilon=None, schedule_decay=0.004),
                  loss=intersection_over_union,
                  metrics=None
    )
    cycle = MaxLRTest() if test else DecayingLR(max_lr=max_lr)
    cb = [
        callbacks.ModelCheckpoint("../processed/model.h5", monitor="val_loss", verbose=1, save_best_only=True),
        cycle
    ]
    rez = model.fit_generator(
        yield_batch(data_train),
        steps_per_epoch=steps_per_epoch,
        epochs=epochs,
        callbacks=cb,
        validation_data=yield_batch_val(data_val),
        validation_steps=len(data_val[1].index),
        )
    
    model = models.load_model("../processed/model.h5", custom_objects={"intersection_over_union": intersection_over_union})
    
    return rez, cycle, model

# %%
FOLDS = 10

def train_oof(train_set, test_set, units=16):
    x_train, y_train = train_set
    x_test = test_set

    y_oof = pd.DataFrame(0, index=y_train.index, columns=COORDINATES)
    y_pred = pd.DataFrame(0, index=x_test.index.unique(), columns=COORDINATES)
    scores = []
    folds = model_selection.KFold(n_splits=FOLDS, shuffle=True)
    
    for n, (index_train, index_valid) in enumerate(folds.split(y_train), 1):
        print(f"\nFold - {n} / {FOLDS}")
        
        ids_train = y_train.index[index_train]
        ids_valid = y_train.index[index_valid]
        
        data_train = (x_train.loc[ids_train], y_train.loc[ids_train])
        data_val = (x_train.loc[ids_valid], y_train.loc[ids_valid])
        
        rez, cycle, model = train_model(data_train, data_val, units)
        
        cycle.plot()
        pd.DataFrame(rez.history)[["loss", "val_loss"]].plot(figsize=(16, 8))
        scores.append(min(rez.history["val_loss"]))
        
        feat = yield_batch_test(data_val[0])
        df = model.predict_generator(feat, steps=len(data_val[0].index.unique()))
        df = scaler.inverse_transform(df)
        y_oof.loc[ids_valid] = df
        
        feat = yield_batch_test(x_test)
        df = model.predict_generator(feat, steps=len(x_test.index.unique()))
        df = scaler.inverse_transform(df)
        y_pred += df / FOLDS

    print(f"IOU на кроссвалидации: " + str(-np.round(sorted(scores), 5)))
    print(f"IOU среднее: {-np.mean(scores):0.5f} +/- {2 * np.std(scores) / len(scores) ** 2:0.5f}")

    subdir = time.strftime('%Y-%m-%d_%H-%M')
    path = pathlib.Path(f"../processed/{subdir}")
    path.mkdir(exist_ok=True)
    y_oof.to_csv(path / f"oof-{-np.mean(scores):0.5f}.csv", header=False)
    y_pred.to_csv(path / f"sub-{-np.mean(scores):0.5f}.csv", header=False)

# %%
train_oof((votes, answers), votes_test)
# Out:
# Fold - 1 / 10
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, None, 4)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, None, 64)          832
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, None, 64)          12352
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, None, 64)          12352
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, None, 64)          12352
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, None, 64)          12352
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, None, 64)          12352
# _________________________________________________________________
# global_average_pooling1d_1 ( (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 132
# =================================================================
# Total params: 64,804
# Trainable params: 64,804
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.6830 - intersection_over_union: -0.0367 - val_loss: 0.5065 - val_intersection_over_union: -0.1168
# Epoch 1/100
#   36/1000 [>.............................] - ETA: 16s - loss: -0.1679
# /Users/WLMike/Documents/PycharmProjects/ML_venv/lib/python3.6/site-packages/ipykernel_launcher.py:78: RuntimeWarning: invalid value encountered in double_scalars
# 1000/1000 [==============================] - 6s 6ms/step - loss: -0.3460 - val_loss: -0.3027
#
# Epoch 00001: val_loss improved from inf to -0.30271, saving model to ../processed/model.h5
# Learning rate: 3.8e-04
# Speed per epoch: -0.0993
# Wait to stop: 3
#
# Epoch 2/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4034 - val_loss: -0.4108
#
# Epoch 00002: val_loss improved from -0.30271 to -0.41082, saving model to ../processed/model.h5
# Learning rate: 3.8e-04
# Speed per epoch: -0.0555
# Wait to stop: 3
#
# Epoch 3/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4375 - val_loss: -0.4697
#
# Epoch 00003: val_loss improved from -0.41082 to -0.46968, saving model to ../processed/model.h5
# Learning rate: 3.8e-04
# Speed per epoch: -0.0326
# Wait to stop: 3
#
# Epoch 4/100
# 1000/1000 [==============================] - 6s 6ms/step - loss: -0.4423 - val_loss: -0.4086
#
# Epoch 00004: val_loss did not improve from -0.46968
# Learning rate: 3.8e-04
# Speed per epoch: -0.0241
# Wait to stop: 3
#
# Epoch 5/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4486 - val_loss: -0.4600
#
# Epoch 00005: val_loss did not improve from -0.46968
# Learning rate: 3.8e-04
# Speed per epoch: -0.0109
# Wait to stop: 3
#
# Epoch 6/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4579 - val_loss: -0.4426
#
# Epoch 00006: val_loss did not improve from -0.46968
# Learning rate: 3.8e-04
# Speed per epoch: -0.0118
# Wait to stop: 3
#
# Epoch 7/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4706 - val_loss: -0.4898
#
# Epoch 00007: val_loss improved from -0.46968 to -0.48978, saving model to ../processed/model.h5
# Learning rate: 3.8e-04
# Speed per epoch: -0.0093
# Wait to stop: 3
#
# Epoch 8/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4731 - val_loss: -0.4561
#
# Epoch 00008: val_loss did not improve from -0.48978
# Learning rate: 3.8e-04
# Speed per epoch: -0.0059
# Wait to stop: 3
#
# Epoch 9/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4796 - val_loss: -0.4251
#
# Epoch 00009: val_loss did not improve from -0.48978
# Learning rate: 3.8e-04
# Speed per epoch: -0.0056
# Wait to stop: 3
#
# Epoch 10/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4664 - val_loss: -0.4941
#
# Epoch 00010: val_loss improved from -0.48978 to -0.49414, saving model to ../processed/model.h5
# Learning rate: 2.3e-04
# Speed per epoch: -0.0018
# Wait to stop: 3
#
# Epoch 11/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5076 - val_loss: -0.4799
#
# Epoch 00011: val_loss did not improve from -0.49414
# Learning rate: 2.3e-04
# Speed per epoch: -0.0141
# Wait to stop: 3
#
# Epoch 12/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5136 - val_loss: -0.4920
#
# Epoch 00012: val_loss did not improve from -0.49414
# Learning rate: 2.3e-04
# Speed per epoch: -0.0100
# Wait to stop: 3
#
# Epoch 13/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5022 - val_loss: -0.4968
#
# Epoch 00013: val_loss improved from -0.49414 to -0.49681, saving model to ../processed/model.h5
# Learning rate: 2.3e-04
# Speed per epoch: -0.0029
# Wait to stop: 3
#
# Epoch 14/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5100 - val_loss: -0.4964
#
# Epoch 00014: val_loss did not improve from -0.49681
# Learning rate: 2.3e-04
# Speed per epoch: -0.0032
# Wait to stop: 3
#
# Epoch 15/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5114 - val_loss: -0.5226
#
# Epoch 00015: val_loss improved from -0.49681 to -0.52259, saving model to ../processed/model.h5
# Learning rate: 2.2e-04
# Speed per epoch: -0.0040
# Wait to stop: 3
#
# Epoch 16/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5074 - val_loss: -0.5271
#
# Epoch 00016: val_loss improved from -0.52259 to -0.52705, saving model to ../processed/model.h5
# Learning rate: 2.0e-04
# Speed per epoch: 0.0037
# Wait to stop: 3
#
# Epoch 17/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5207 - val_loss: -0.5470
#
# Epoch 00017: val_loss improved from -0.52705 to -0.54703, saving model to ../processed/model.h5
# Learning rate: 1.2e-04
# Speed per epoch: -0.0047
# Wait to stop: 3
#
# Epoch 18/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5329 - val_loss: -0.5204
#
# Epoch 00018: val_loss did not improve from -0.54703
# Learning rate: 1.2e-04
# Speed per epoch: -0.0093
# Wait to stop: 3
#
# Epoch 19/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5344 - val_loss: -0.5232
#
# Epoch 00019: val_loss did not improve from -0.54703
# Learning rate: 1.2e-04
# Speed per epoch: -0.0077
# Wait to stop: 3
#
# Epoch 20/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5329 - val_loss: -0.5170
#
# Epoch 00020: val_loss did not improve from -0.54703
# Learning rate: 1.2e-04
# Speed per epoch: -0.0003
# Wait to stop: 3
#
# Epoch 21/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5374 - val_loss: -0.5316
#
# Epoch 00021: val_loss did not improve from -0.54703
# Learning rate: 1.2e-04
# Speed per epoch: -0.0004
# Wait to stop: 3
#
# Epoch 22/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5364 - val_loss: -0.5238
#
# Epoch 00022: val_loss did not improve from -0.54703
# Learning rate: 9.3e-05
# Speed per epoch: -0.0014
# Wait to stop: 3
#
# Epoch 23/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5341 - val_loss: -0.5423
#
# Epoch 00023: val_loss did not improve from -0.54703
# Learning rate: 7.0e-05
# Speed per epoch: 0.0002
# Wait to stop: 3
#
# Epoch 24/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5451 - val_loss: -0.5407
#
# Epoch 00024: val_loss did not improve from -0.54703
# Learning rate: 6.2e-05
# Speed per epoch: -0.0053
# Wait to stop: 3
#
# Epoch 25/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5502 - val_loss: -0.5313
#
# Epoch 00025: val_loss did not improve from -0.54703
# Learning rate: 6.2e-05
# Speed per epoch: -0.0057
# Wait to stop: 3
#
# Epoch 26/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5543 - val_loss: -0.5438
#
# Epoch 00026: val_loss did not improve from -0.54703
# Learning rate: 6.2e-05
# Speed per epoch: -0.0062
# Wait to stop: 3
#
# Epoch 27/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5567 - val_loss: -0.5507
#
# Epoch 00027: val_loss improved from -0.54703 to -0.55075, saving model to ../processed/model.h5
# Learning rate: 6.2e-05
# Speed per epoch: -0.0022
# Wait to stop: 3
#
# Epoch 28/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5440 - val_loss: -0.5495
#
# Epoch 00028: val_loss did not improve from -0.55075
# Learning rate: 3.3e-05
# Speed per epoch: 0.0039
# Wait to stop: 3
#
# Epoch 29/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5630 - val_loss: -0.5538
#
# Epoch 00029: val_loss improved from -0.55075 to -0.55382, saving model to ../processed/model.h5
# Learning rate: 2.7e-05
# Speed per epoch: -0.0036
# Wait to stop: 3
#
# Epoch 30/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5715 - val_loss: -0.5562
#
# Epoch 00030: val_loss improved from -0.55382 to -0.55624, saving model to ../processed/model.h5
# Learning rate: 2.7e-05
# Speed per epoch: -0.0078
# Wait to stop: 3
#
# Epoch 31/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5643 - val_loss: -0.5541
#
# Epoch 00031: val_loss did not improve from -0.55624
# Learning rate: 2.3e-05
# Speed per epoch: -0.0017
# Wait to stop: 3
#
# Epoch 32/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5734 - val_loss: -0.5540
#
# Epoch 00032: val_loss did not improve from -0.55624
# Learning rate: 2.1e-05
# Speed per epoch: -0.0058
# Wait to stop: 3
#
# Epoch 33/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5624 - val_loss: -0.5547
#
# Epoch 00033: val_loss did not improve from -0.55624
# Learning rate: 1.3e-05
# Speed per epoch: 0.0005
# Wait to stop: 3
#
# Epoch 34/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5705 - val_loss: -0.5628
#
# Epoch 00034: val_loss improved from -0.55624 to -0.56277, saving model to ../processed/model.h5
# Learning rate: 8.4e-06
# Speed per epoch: -0.0029
# Wait to stop: 3
#
# Epoch 35/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5706 - val_loss: -0.5635
#
# Epoch 00035: val_loss improved from -0.56277 to -0.56351, saving model to ../processed/model.h5
# Learning rate: 6.0e-06
# Speed per epoch: -0.0034
# Wait to stop: 3
#
# Epoch 36/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5740 - val_loss: -0.5633
#
# Epoch 00036: val_loss did not improve from -0.56351
# Learning rate: 4.6e-06
# Speed per epoch: -0.0044
# Wait to stop: 3
#
# Epoch 37/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5751 - val_loss: -0.5639
#
# Epoch 00037: val_loss improved from -0.56351 to -0.56395, saving model to ../processed/model.h5
# Learning rate: 4.2e-06
# Speed per epoch: -0.0036
# Wait to stop: 3
#
# Epoch 38/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5823 - val_loss: -0.5605
#
# Epoch 00038: val_loss did not improve from -0.56395
# Learning rate: 4.2e-06
# Speed per epoch: -0.0011
# Wait to stop: 3
#
# Epoch 39/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5791 - val_loss: -0.5634
#
# Epoch 00039: val_loss did not improve from -0.56395
# Learning rate: 3.7e-06
# Speed per epoch: 0.0006
# Wait to stop: 3
#
# Epoch 40/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5874 - val_loss: -0.5655
#
# Epoch 00040: val_loss improved from -0.56395 to -0.56550, saving model to ../processed/model.h5
# Learning rate: 3.0e-06
# Speed per epoch: -0.0050
# Wait to stop: 3
#
# Epoch 41/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5750 - val_loss: -0.5632
#
# Epoch 00041: val_loss did not improve from -0.56550
# Learning rate: 1.6e-06
# Speed per epoch: 0.0002
# Wait to stop: 3
#
# Epoch 42/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5818 - val_loss: -0.5638
#
# Epoch 00042: val_loss did not improve from -0.56550
# Learning rate: 8.6e-07
# Speed per epoch: -0.0040
# Wait to stop: 3
#
# Epoch 43/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5805 - val_loss: -0.5647
#
# Epoch 00043: val_loss did not improve from -0.56550
# Learning rate: 5.2e-07
# Speed per epoch: -0.0001
# Wait to stop: 3
#
# Epoch 44/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5762 - val_loss: -0.5648
#
# Epoch 00044: val_loss did not improve from -0.56550
# Learning rate: 2.8e-07
# Speed per epoch: 0.0037
# Wait to stop: 2
#
# Epoch 45/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5870 - val_loss: -0.5647
#
# Epoch 00045: val_loss did not improve from -0.56550
# Learning rate: 1.8e-07
# Speed per epoch: -0.0023
# Wait to stop: 3
#
# Epoch 46/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5900 - val_loss: -0.5645
#
# Epoch 00046: val_loss did not improve from -0.56550
# Learning rate: 1.8e-07
# Speed per epoch: -0.0036
# Wait to stop: 3
#
# Epoch 47/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5786 - val_loss: -0.5648
#
# Epoch 00047: val_loss did not improve from -0.56550
# Learning rate: 8.8e-08
# Speed per epoch: 0.0001
# Wait to stop: 3
#
# Epoch 48/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5853 - val_loss: -0.5648
#
# Epoch 00048: val_loss did not improve from -0.56550
# Learning rate: 5.7e-08
# Speed per epoch: -0.0018
# Wait to stop: 2
#
# Epoch 49/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5808 - val_loss: -0.5647
#
# Epoch 00049: val_loss did not improve from -0.56550
# Learning rate: 3.6e-08
# Speed per epoch: 0.0012
# Wait to stop: 1
#
# Epoch 50/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5803 - val_loss: -0.5647
#
# Epoch 00050: val_loss did not improve from -0.56550
# Learning rate: 1.7e-08
# Speed per epoch: 0.0003
# Wait to stop: 0
#
#
# Fold - 2 / 10
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, None, 4)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, None, 64)          832
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, None, 64)          12352
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, None, 64)          12352
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, None, 64)          12352
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, None, 64)          12352
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, None, 64)          12352
# _________________________________________________________________
# global_average_pooling1d_1 ( (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 132
# =================================================================
# Total params: 64,804
# Trainable params: 64,804
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.7112 - intersection_over_union: -0.0040 - val_loss: 0.6421 - val_intersection_over_union: -0.0195
# Epoch 1/100
#   36/1000 [>.............................] - ETA: 18s - loss: -0.0115
# /Users/WLMike/Documents/PycharmProjects/ML_venv/lib/python3.6/site-packages/ipykernel_launcher.py:78: RuntimeWarning: invalid value encountered in double_scalars
# 1000/1000 [==============================] - 6s 6ms/step - loss: -0.3134 - val_loss: -0.3200
#
# Epoch 00001: val_loss improved from inf to -0.32005, saving model to ../processed/model.h5
# Learning rate: 3.8e-04
# Speed per epoch: -0.2416
# Wait to stop: 3
#
# Epoch 2/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.3983 - val_loss: -0.4239
#
# Epoch 00002: val_loss improved from -0.32005 to -0.42390, saving model to ../processed/model.h5
# Learning rate: 3.8e-04
# Speed per epoch: -0.0753
# Wait to stop: 3
#
# Epoch 3/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4232 - val_loss: -0.4649
#
# Epoch 00003: val_loss improved from -0.42390 to -0.46492, saving model to ../processed/model.h5
# Learning rate: 3.8e-04
# Speed per epoch: -0.0316
# Wait to stop: 3
#
# Epoch 4/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4392 - val_loss: -0.4596
#
# Epoch 00004: val_loss did not improve from -0.46492
# Learning rate: 3.8e-04
# Speed per epoch: -0.0203
# Wait to stop: 3
#
# Epoch 5/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4628 - val_loss: -0.4523
#
# Epoch 00005: val_loss did not improve from -0.46492
# Learning rate: 3.8e-04
# Speed per epoch: -0.0246
# Wait to stop: 3
#
# Epoch 6/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4515 - val_loss: -0.4525
#
# Epoch 00006: val_loss did not improve from -0.46492
# Learning rate: 3.8e-04
# Speed per epoch: -0.0073
# Wait to stop: 3
#
# Epoch 7/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4585 - val_loss: -0.4197
#
# Epoch 00007: val_loss did not improve from -0.46492
# Learning rate: 3.8e-04
# Speed per epoch: -0.0073
# Wait to stop: 3
#
# Epoch 8/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4587 - val_loss: -0.4446
#
# Epoch 00008: val_loss did not improve from -0.46492
# Learning rate: 3.7e-04
# Speed per epoch: -0.0013
# Wait to stop: 3
#
# Epoch 9/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4646 - val_loss: -0.4478
#
# Epoch 00009: val_loss did not improve from -0.46492
# Learning rate: 3.6e-04
# Speed per epoch: -0.0001
# Wait to stop: 3
#
# Epoch 10/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4806 - val_loss: -0.4074
#
# Epoch 00010: val_loss did not improve from -0.46492
# Learning rate: 3.3e-04
# Speed per epoch: -0.0094
# Wait to stop: 3
#
# Epoch 11/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4754 - val_loss: -0.4768
#
# Epoch 00011: val_loss improved from -0.46492 to -0.47677, saving model to ../processed/model.h5
# Learning rate: 3.3e-04
# Speed per epoch: -0.0053
# Wait to stop: 3
#
# Epoch 12/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4687 - val_loss: -0.4884
#
# Epoch 00012: val_loss improved from -0.47677 to -0.48837, saving model to ../processed/model.h5
# Learning rate: 2.5e-04
# Speed per epoch: 0.0017
# Wait to stop: 3
#
# Epoch 13/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.4921 - val_loss: -0.5007
#
# Epoch 00013: val_loss improved from -0.48837 to -0.50066, saving model to ../processed/model.h5
# Learning rate: 2.1e-04
# Speed per epoch: -0.0062
# Wait to stop: 3
#
# Epoch 14/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5031 - val_loss: -0.4776
#
# Epoch 00014: val_loss did not improve from -0.50066
# Learning rate: 2.1e-04
# Speed per epoch: -0.0109
# Wait to stop: 3
#
# Epoch 15/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5135 - val_loss: -0.4901
#
# Epoch 00015: val_loss did not improve from -0.50066
# Learning rate: 2.1e-04
# Speed per epoch: -0.0092
# Wait to stop: 3
#
# Epoch 16/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5085 - val_loss: -0.4805
#
# Epoch 00016: val_loss did not improve from -0.50066
# Learning rate: 2.1e-04
# Speed per epoch: -0.0026
# Wait to stop: 3
#
# Epoch 17/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5196 - val_loss: -0.4974
#
# Epoch 00017: val_loss did not improve from -0.50066
# Learning rate: 2.1e-04
# Speed per epoch: -0.0024
# Wait to stop: 3
#
# Epoch 18/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5166 - val_loss: -0.5034
#
# Epoch 00018: val_loss improved from -0.50066 to -0.50337, saving model to ../processed/model.h5
# Learning rate: 1.5e-04
# Speed per epoch: -0.0057
# Wait to stop: 3
#
# Epoch 19/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5220 - val_loss: -0.4939
#
# Epoch 00019: val_loss did not improve from -0.50337
# Learning rate: 1.5e-04
# Speed per epoch: -0.0037
# Wait to stop: 3
#
# Epoch 20/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5139 - val_loss: -0.5366
#
# Epoch 00020: val_loss improved from -0.50337 to -0.53664, saving model to ../processed/model.h5
# Learning rate: 1.1e-04
# Speed per epoch: 0.0013
# Wait to stop: 3
#
# Epoch 21/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5372 - val_loss: -0.5231
#
# Epoch 00021: val_loss did not improve from -0.53664
# Learning rate: 9.5e-05
# Speed per epoch: -0.0086
# Wait to stop: 3
#
# Epoch 22/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5394 - val_loss: -0.5383
#
# Epoch 00022: val_loss improved from -0.53664 to -0.53831, saving model to ../processed/model.h5
# Learning rate: 9.5e-05
# Speed per epoch: -0.0082
# Wait to stop: 3
#
# Epoch 23/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5454 - val_loss: -0.5394
#
# Epoch 00023: val_loss improved from -0.53831 to -0.53936, saving model to ../processed/model.h5
# Learning rate: 9.5e-05
# Speed per epoch: -0.0106
# Wait to stop: 3
#
# Epoch 24/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5424 - val_loss: -0.5302
#
# Epoch 00024: val_loss did not improve from -0.53936
# Learning rate: 9.5e-05
# Speed per epoch: -0.0034
# Wait to stop: 3
#
# Epoch 25/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5464 - val_loss: -0.5353
#
# Epoch 00025: val_loss did not improve from -0.53936
# Learning rate: 9.5e-05
# Speed per epoch: -0.0015
# Wait to stop: 3
#
# Epoch 26/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5418 - val_loss: -0.5348
#
# Epoch 00026: val_loss did not improve from -0.53936
# Learning rate: 7.7e-05
# Speed per epoch: 0.0028
# Wait to stop: 3
#
# Epoch 27/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5505 - val_loss: -0.5505
#
# Epoch 00027: val_loss improved from -0.53936 to -0.55053, saving model to ../processed/model.h5
# Learning rate: 3.8e-05
# Speed per epoch: -0.0042
# Wait to stop: 3
#
# Epoch 28/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5553 - val_loss: -0.5495
#
# Epoch 00028: val_loss did not improve from -0.55053
# Learning rate: 3.8e-05
# Speed per epoch: -0.0050
# Wait to stop: 3
#
# Epoch 29/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5656 - val_loss: -0.5532
#
# Epoch 00029: val_loss improved from -0.55053 to -0.55320, saving model to ../processed/model.h5
# Learning rate: 3.8e-05
# Speed per epoch: -0.0046
# Wait to stop: 3
#
# Epoch 30/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5604 - val_loss: -0.5409
#
# Epoch 00030: val_loss did not improve from -0.55320
# Learning rate: 3.6e-05
# Speed per epoch: -0.0035
# Wait to stop: 3
#
# Epoch 31/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5588 - val_loss: -0.5542
#
# Epoch 00031: val_loss improved from -0.55320 to -0.55416, saving model to ../processed/model.h5
# Learning rate: 3.1e-05
# Speed per epoch: 0.0003
# Wait to stop: 3
#
# Epoch 32/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5684 - val_loss: -0.5508
#
# Epoch 00032: val_loss did not improve from -0.55416
# Learning rate: 2.7e-05
# Speed per epoch: -0.0027
# Wait to stop: 3
#
# Epoch 33/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5622 - val_loss: -0.5552
#
# Epoch 00033: val_loss improved from -0.55416 to -0.55516, saving model to ../processed/model.h5
# Learning rate: 1.8e-05
# Speed per epoch: -0.0019
# Wait to stop: 3
#
# Epoch 34/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5649 - val_loss: -0.5526
#
# Epoch 00034: val_loss did not improve from -0.55516
# Learning rate: 1.5e-05
# Speed per epoch: -0.0002
# Wait to stop: 3
#
# Epoch 35/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5746 - val_loss: -0.5536
#
# Epoch 00035: val_loss did not improve from -0.55516
# Learning rate: 1.1e-05
# Speed per epoch: -0.0059
# Wait to stop: 3
#
# Epoch 36/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5779 - val_loss: -0.5552
#
# Epoch 00036: val_loss improved from -0.55516 to -0.55522, saving model to ../processed/model.h5
# Learning rate: 1.1e-05
# Speed per epoch: -0.0029
# Wait to stop: 3
#
# Epoch 37/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5699 - val_loss: -0.5551
#
# Epoch 00037: val_loss did not improve from -0.55522
# Learning rate: 7.0e-06
# Speed per epoch: 0.0011
# Wait to stop: 2
#
# Epoch 38/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5807 - val_loss: -0.5536
#
# Epoch 00038: val_loss did not improve from -0.55522
# Learning rate: 5.8e-06
# Speed per epoch: -0.0028
# Wait to stop: 3
#
# Epoch 39/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5707 - val_loss: -0.5550
#
# Epoch 00039: val_loss did not improve from -0.55522
# Learning rate: 3.1e-06
# Speed per epoch: -0.0011
# Wait to stop: 3
#
# Epoch 40/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5848 - val_loss: -0.5534
#
# Epoch 00040: val_loss did not improve from -0.55522
# Learning rate: 3.1e-06
# Speed per epoch: -0.0033
# Wait to stop: 3
#
# Epoch 41/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5733 - val_loss: -0.5544
#
# Epoch 00041: val_loss did not improve from -0.55522
# Learning rate: 1.9e-06
# Speed per epoch: 0.0022
# Wait to stop: 3
#
# Epoch 42/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5723 - val_loss: -0.5563
#
# Epoch 00042: val_loss improved from -0.55522 to -0.55628, saving model to ../processed/model.h5
# Learning rate: 8.1e-07
# Speed per epoch: 0.0045
# Wait to stop: 3
#
# Epoch 43/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5810 - val_loss: -0.5564
#
# Epoch 00043: val_loss improved from -0.55628 to -0.55639, saving model to ../processed/model.h5
# Learning rate: 4.8e-07
# Speed per epoch: -0.0011
# Wait to stop: 3
#
# Epoch 44/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5706 - val_loss: -0.5559
#
# Epoch 00044: val_loss did not improve from -0.55639
# Learning rate: 2.8e-07
# Speed per epoch: 0.0039
# Wait to stop: 3
#
# Epoch 45/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5768 - val_loss: -0.5559
#
# Epoch 00045: val_loss did not improve from -0.55639
# Learning rate: 1.5e-07
# Speed per epoch: 0.0005
# Wait to stop: 2
#
# Epoch 46/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5775 - val_loss: -0.5560
#
# Epoch 00046: val_loss did not improve from -0.55639
# Learning rate: 7.6e-08
# Speed per epoch: -0.0042
# Wait to stop: 1
#
# Epoch 47/100
# 1000/1000 [==============================] - 5s 5ms/step - loss: -0.5827 - val_loss: -0.5560
#
# Epoch 00047: val_loss did not improve from -0.55639
# Learning rate: 7.6e-08
# Speed per epoch: -0.0026
# Wait to stop: 0
#
#
# Fold - 3 / 10
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, None, 4)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, None, 64)          832
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, None, 64)          12352
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, None, 64)          12352
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, None, 64)          12352
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, None, 64)          12352
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, None, 64)          12352
# _________________________________________________________________
# global_average_pooling1d_1 ( (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 132
# =================================================================
# Total params: 64,804
# Trainable params: 64,804
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1
#  969/1000 [============================>.] - ETA: 0s - loss: 0.6561 - intersection_over_union: -0.0585
