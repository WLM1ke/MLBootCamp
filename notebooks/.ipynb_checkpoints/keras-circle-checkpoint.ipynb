# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import time
from keras import layers
from keras import models
from keras import optimizers
from keras import callbacks
from keras import backend as K
from sklearn import model_selection
from sklearn import preprocessing
import pathlib
# Out:
# Using TensorFlow backend.

# %%
COORDINATES = ["Xmin", "Ymin", "Xmax", "Ymax"]

# %%
answers = pd.read_csv("../raw/train_answers.csv").set_index("itemId")
answers.columns = COORDINATES
scaler = preprocessing.StandardScaler().fit(np.vstack([answers.values, answers.values[:, [2, 3, 0, 1]]]))
answers[COORDINATES] = scaler.transform(answers[COORDINATES])
# Out:
# /Users/WLMike/Documents/PycharmProjects/ML_venv/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/WLMike/Documents/PycharmProjects/ML_venv/lib/python3.6/site-packages/ipykernel_launcher.py:4: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   after removing the cwd from sys.path.

# %%
votes = pd.read_csv("../raw/train_data.csv").set_index("itemId")
votes[COORDINATES] = scaler.transform(votes[COORDINATES])
# Out:
# /Users/WLMike/Documents/PycharmProjects/ML_venv/lib/python3.6/site-packages/ipykernel_launcher.py:2: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.

# %%
votes_test = pd.read_csv("../raw/test_data.csv").set_index("itemId")
votes_test[COORDINATES] = scaler.transform(votes_test[COORDINATES])
# Out:
# /Users/WLMike/Documents/PycharmProjects/ML_venv/lib/python3.6/site-packages/ipykernel_launcher.py:2: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.

# %%
def find_center(y):
    center_x = (y[0, 2] + y[0, 0]) / 2
    center_y = (y[0, 3] + y[0, 1]) / 2 
    return np.array([center_x, center_y, center_x, center_y])


def scale(x, y, err=0.1):
    center = find_center(y)
    x, y = x - np.reshape(center, (1, 1, 4)), y - np.reshape(center, (1, 4))
    
    err_x, err_y = np.random.random(2)  
    
    err_x = 1 + (2 * err_x - 1) * err
    err_y = 1 + (2 * err_y - 1) * err
    
    err = np.array([err_x, err_y, err_x, err_y])
    
    return (x * np.reshape(err, (1, 1, 4)) + np.reshape(center, (1, 1, 4)), 
            y * np.reshape(err, (1, 4)) + np.reshape(center, (1, 4)))
    

def move(x, y, err=0.1):
    center = find_center(y)
    x, y = x - np.reshape(center, (1, 1, 4)), y - np.reshape(center, (1, 4))
    
    size_x = (y[0, 2] - y[0, 0]) / 2
    size_y = (y[0, 3] - y[0, 1]) / 2
    
    err_cx, err_cy = np.random.random(2)  
    
    err_cx = (2 * size_x * err_cx - size_x) * err
    err_cy = (2 * size_y * err_cy - size_y) * err
    
    err = np.array([err_cx, err_cy, err_cx, err_cy])
    
    return x + np.reshape(err + center, (1, 1, 4)), y + np.reshape(err + center, (1, 4))
    
def aug_batch(x, y, err=0.1):
    x, y = scale(x, y, err)
    x, y = move(x, y, err)
    return x, y

# %%
def yield_batch(data, batch):
    votes, answers = data
    counts = votes[["userId"]].groupby("itemId").count()
    feat = votes.groupby("itemId")[COORDINATES].agg(["min", "max", "std", "median", "mean"])
    feat["count"] = counts
    item_ids = list(set(votes.index))
    while True:
        item_id = np.random.choice(item_ids, batch)
        x = feat.loc[item_id]
        y = answers.loc[item_id]
        yield x, y

# %%
def yield_batch_val(data):
    votes, answers = data
    counts = votes[["userId"]].groupby("itemId").count()
    feat = votes.groupby("itemId")[COORDINATES].agg(["min", "max", "std", "median", "mean"])
    feat["count"] = counts
    item_ids = list(set(votes.index))
    while True:
        x = feat.loc[item_ids]
        y = answers.loc[item_ids]
        yield x, y

# %%
def yield_batch_test(data):
    counts = data[["userId"]].groupby("itemId").count()
    feat = data.groupby("itemId")[COORDINATES].agg(["min", "max", "std", "median", "mean"])
    feat["count"] = counts
    item_ids = data.index.unique()
    for item_id in item_ids:
        x = feat.loc[[item_id]]
        yield x

# %%
def intersection_over_union(boxes_pred, boxes_true):

    x_min = K.stack([boxes_pred[:, 0], boxes_true[:, 0]], axis=-1)
    y_min = K.stack([boxes_pred[:, 1], boxes_true[:, 1]], axis=-1)
    x_max = K.stack([boxes_pred[:, 2], boxes_true[:, 2]], axis=-1)
    y_max = K.stack([boxes_pred[:, 3], boxes_true[:, 3]], axis=-1)

    x_min = K.max(x_min, axis=-1)
    y_min = K.max(y_min, axis=-1)
    x_max = K.min(x_max, axis=-1)
    y_max = K.min(y_max, axis=-1)

    zeros = K.zeros_like(x_max)

    x_inter = K.stack([zeros, x_max - x_min], axis=-1)
    y_inter = K.stack([zeros, y_max - y_min], axis=-1)

    x_inter = K.max(x_inter, axis=-1)
    y_inter = K.max(y_inter, axis=-1)
    inter_area = x_inter * y_inter
    
    area_pred = (K.max(K.stack([zeros, boxes_pred[:, 2] - boxes_pred[:, 0]], axis=-1), axis=-1) * 
                 K.max(K.stack([zeros, boxes_pred[:, 3] - boxes_pred[:, 1]], axis=-1), axis=-1))
    area_true = (K.max(K.stack([zeros, boxes_true[:, 2] - boxes_true[:, 0]], axis=-1), axis=-1) * 
                 K.max(K.stack([zeros, boxes_true[:, 3] - boxes_true[:, 1]], axis=-1), axis=-1))

    iou = inter_area / (area_pred + area_true - inter_area + K.epsilon())
    
    return -K.mean(iou, axis=-1)

# %%
def make_model(units):
    K.clear_session()
    
    y = x = layers.Input(shape=(21,))
    
    y = layers.Dense(
        units=units * 8,
        activation="relu"
    )(y)
    y = layers.Dense(
        units=units * 4,
        activation="relu"
    )(y)
    y = layers.Dense(
        units=units * 2,
        activation="relu"
    )(y)
    y = layers.Dense(
        units=units,
        activation="relu"
    )(y)
    y = layers.Dense(
        units=4,
        activation=None
    )(y)
    
    model = models.Model(inputs=x, outputs=y)
    model.summary()
    return model

# %%
class MaxLRTest(callbacks.Callback):

    def __init__(self, base_lr=1.0e-9, max_lr=10, steps=10000):
        super().__init__()

        self.base_lr = base_lr
        self.max_lr = max_lr
        self.steps = steps
        
        self.iterations = None
        self.history = None
        
    def clr(self):
        return self.base_lr * (self.max_lr / self.base_lr) ** (self.iterations / self.steps) 
  
    def on_train_begin(self, logs=None):
        self.iterations = 0
        self.history = {}
        K.set_value(self.model.optimizer.lr, self.base_lr)     
            
    def on_batch_end(self, batch, logs=None):
        if self.iterations > self.steps:
            self.model.stop_training = True
        
        self.history.setdefault("iterations", []).append(self.iterations)
        self.history.setdefault("lr", []).append(K.get_value(self.model.optimizer.lr))
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
            
        self.iterations += 1
        K.set_value(self.model.optimizer.lr, self.clr())
        
    def plot(self, smooth=None, t_score=2):
        smooth = int(smooth or self.steps // 10)
        df = pd.DataFrame(self.history).set_index("lr").loss.rolling(smooth).agg(["mean", "std"])
        df["std"] = df["mean"] + t_score * df["std"] / smooth ** 0.5
        print(f"Max speed learning rate  - {df['std'].idxmin():.1e}")
        df.plot(logx=True, figsize=(16, 8))

# %%
class DecayingLR(callbacks.Callback):

    def __init__(self, max_lr=0.1, warm_up=1, decay_per_epoch=1):
        super().__init__()

        self.max_lr = max_lr
        self.warm_up = warm_up
        self.decay_per_epoch = decay_per_epoch
        
        self.iterations = None
        self.history = None
        
        self.d_loss_iterations = None
        self.d_loss = None
        self.d_iterations = None
        self.d_iterations2 = None
        self.d_1 = None
                
        self.steps = None
        self.decay = None

    def on_train_begin(self, logs=None):
        self.iterations = 1
        self.history = {}
        
        self.d_loss_iterations = 0
        self.d_loss = 0
        self.d_iterations = 0
        self.d_iterations2 = 0
        self.d_1 = 0
        
        self.steps = self.params["steps"]
        self.decay = (1 - 1 / self.steps) ** (1 / self.decay_per_epoch)
        
        K.set_value(self.model.optimizer.lr, self.lr())
    
    def make_decay(self, old, new):
        decay = self.decay
        return old * decay + new * (1 - decay)
    
    def lr(self):
        warm_up = self.iterations / self.steps * self.warm_up
        if warm_up <= 1:
            return self.max_lr * warm_up 
        
        lr = self.history["lr"][-1]
        speed = self.history["speed"][-1]
        
        if speed > 0:
            return lr * self.decay
        
        return lr
            
    def on_batch_end(self, batch, logs=None):
        self.history.setdefault("iterations", []).append(self.iterations)
        self.history.setdefault("lr", []).append(K.get_value(self.model.optimizer.lr))
        
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
            
        self.d_loss_iterations = self.make_decay(self.d_loss_iterations, logs["loss"] * self.iterations)
        self.d_loss = self.make_decay(self.d_loss, logs["loss"])
        self.d_iterations = self.make_decay(self.d_iterations, self.iterations)
        self.d_iterations2 = self.make_decay(self.d_iterations2, self.iterations ** 2)
        self.d_1 = self.make_decay(self.d_1, 1)
        
        cov = self.d_loss_iterations - self.d_loss * self.d_iterations / self.d_1
        var = self.d_iterations2 - self.d_iterations ** 2 / self.d_1
        
        speed = self.steps * cov / var
        self.history.setdefault("speed", []).append(speed)
        
        self.iterations += 1
        K.set_value(self.model.optimizer.lr, self.lr())     
        
    def on_epoch_end(self, epoch, logs=None):
        lr = self.history["lr"][-1]
        speed = self.history["speed"][-1]
        print(f"Learning rate: {lr:.1e}")
        print(f"Speed per epoch: {speed:.4f}")
        print()
        
    def plot(self, smooth=None):
        smooth = int(smooth or self.steps)
        df = pd.DataFrame(self.history).set_index("iterations")[["loss", "lr"]].rolling(smooth).mean()
        df.plot(figsize=(16, 8), secondary_y="lr")

# %%
def train_model(data_train, data_val, units, batch, test=False):
    
    max_lr = 2.0e-03
    
    steps_per_epoch = 1000 // batch
    epochs = 40
    
    model = make_model(units)  
    
    model.compile(optimizer=optimizers.Nadam(lr=max_lr / 100, beta_1=0.9, beta_2=0.999, epsilon=None, schedule_decay=0.004),
                      loss="mae",
                      metrics=[intersection_over_union]
        )
    rez = model.fit_generator(
            yield_batch(data_train, batch),
            steps_per_epoch=1000,
            epochs=1,
            callbacks=None,
            validation_data=yield_batch_val(data_val),
            validation_steps=1,
        )
    
    
    model.compile(optimizer=optimizers.Nadam(lr=max_lr, beta_1=0.9, beta_2=0.999, epsilon=None, schedule_decay=0.004),
                  loss=intersection_over_union,
                  metrics=None
    )
    cycle = MaxLRTest() if test else DecayingLR(max_lr=max_lr)
    cb = [
        callbacks.ModelCheckpoint("../processed/model1.h5", monitor="val_loss", verbose=1, save_best_only=True),
        cycle
    ]
    rez = model.fit_generator(
        yield_batch(data_train, batch),
        steps_per_epoch=steps_per_epoch,
        epochs=epochs,
        callbacks=cb,
        validation_data=yield_batch_val(data_val),
        validation_steps=1,
        )
    
    model = models.load_model("../processed/model1.h5", custom_objects={"intersection_over_union": intersection_over_union})
    
    return rez, cycle, model

# %%
FOLDS = 10

def train_oof(train_set, test_set, units=16, batch=1):
    x_train, y_train = train_set
    x_test = test_set

    y_oof = pd.DataFrame(0, index=y_train.index, columns=COORDINATES)
    y_pred = pd.DataFrame(0, index=x_test.index.unique(), columns=COORDINATES)
    scores = []
    folds = model_selection.KFold(n_splits=FOLDS, shuffle=True)
    
    for n, (index_train, index_valid) in enumerate(folds.split(y_train), 1):
        print(f"\nFold - {n} / {FOLDS}")
        
        ids_train = y_train.index[index_train]
        ids_valid = y_train.index[index_valid]
        
        data_train = (x_train.loc[ids_train], y_train.loc[ids_train])
        data_val = (x_train.loc[ids_valid], y_train.loc[ids_valid])
        
        rez, cycle, model = train_model(data_train, data_val, units, batch)
        
        cycle.plot()
        pd.DataFrame(rez.history)[["loss", "val_loss"]].plot(figsize=(16, 8))
        scores.append(min(rez.history["val_loss"]))
        
        feat = yield_batch_test(data_val[0])
        df = model.predict_generator(feat, steps=len(data_val[0].index.unique()))
        df = scaler.inverse_transform(df)
        y_oof.loc[ids_valid] = df
        
        feat = yield_batch_test(x_test)
        df = model.predict_generator(feat, steps=len(x_test.index.unique()))
        df = scaler.inverse_transform(df)
        y_pred += df / FOLDS

    print(f"IOU на кроссвалидации: " + str(-np.round(sorted(scores), 5)))
    print(f"IOU среднее: {-np.mean(scores):0.5f} +/- {np.std(scores):0.5f}")

    subdir = time.strftime('%Y-%m-%d_%H-%M')
    path = pathlib.Path(f"../processed/{subdir}")
    path.mkdir(exist_ok=True)
    y_oof.to_csv(path / f"oof-{-np.mean(scores):0.5f}.csv", header=False)
    y_pred.to_csv(path / f"sub-{-np.mean(scores):0.5f}.csv", header=False)

# %%
train_oof((votes, answers), votes_test, batch=16)
# Out:
# Fold - 1 / 10
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 21)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               2816
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 68
# =================================================================
# Total params: 13,748
# Trainable params: 13,748
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.6945 - intersection_over_union: -0.0550 - val_loss: 0.5168 - val_intersection_over_union: -0.1630
# Epoch 1/40
# 44/62 [====================>.........] - ETA: 0s - loss: -0.2313
# /Users/WLMike/Documents/PycharmProjects/ML_venv/lib/python3.6/site-packages/ipykernel_launcher.py:70: RuntimeWarning: invalid value encountered in double_scalars
# 62/62 [==============================] - 1s 10ms/step - loss: -0.2483 - val_loss: -0.3063
#
# Epoch 00001: val_loss improved from inf to -0.30633, saving model to ../processed/model1.h5
# Learning rate: 2.0e-03
# Speed per epoch: -0.1070
#
# Epoch 2/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.3950 - val_loss: -0.4006
#
# Epoch 00002: val_loss improved from -0.30633 to -0.40061, saving model to ../processed/model1.h5
# Learning rate: 2.0e-03
# Speed per epoch: -0.1534
#
# Epoch 3/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.4559 - val_loss: -0.4819
#
# Epoch 00003: val_loss improved from -0.40061 to -0.48191, saving model to ../processed/model1.h5
# Learning rate: 2.0e-03
# Speed per epoch: -0.0857
#
# Epoch 4/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.4686 - val_loss: -0.4557
#
# Epoch 00004: val_loss did not improve from -0.48191
# Learning rate: 2.0e-03
# Speed per epoch: -0.0436
#
# Epoch 5/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.4812 - val_loss: -0.4904
#
# Epoch 00005: val_loss improved from -0.48191 to -0.49039, saving model to ../processed/model1.h5
# Learning rate: 2.0e-03
# Speed per epoch: -0.0253
#
# Epoch 6/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5002 - val_loss: -0.5124
#
# Epoch 00006: val_loss improved from -0.49039 to -0.51244, saving model to ../processed/model1.h5
# Learning rate: 2.0e-03
# Speed per epoch: -0.0211
#
# Epoch 7/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5047 - val_loss: -0.4683
#
# Epoch 00007: val_loss did not improve from -0.51244
# Learning rate: 2.0e-03
# Speed per epoch: -0.0097
#
# Epoch 8/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5113 - val_loss: -0.4844
#
# Epoch 00008: val_loss did not improve from -0.51244
# Learning rate: 2.0e-03
# Speed per epoch: -0.0091
#
# Epoch 9/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5097 - val_loss: -0.4989
#
# Epoch 00009: val_loss did not improve from -0.51244
# Learning rate: 2.0e-03
# Speed per epoch: -0.0074
#
# Epoch 10/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5161 - val_loss: -0.4938
#
# Epoch 00010: val_loss did not improve from -0.51244
# Learning rate: 1.8e-03
# Speed per epoch: 0.0024
#
# Epoch 11/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5258 - val_loss: -0.5217
#
# Epoch 00011: val_loss improved from -0.51244 to -0.52168, saving model to ../processed/model1.h5
# Learning rate: 1.4e-03
# Speed per epoch: -0.0043
#
# Epoch 12/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5219 - val_loss: -0.5295
#
# Epoch 00012: val_loss improved from -0.52168 to -0.52952, saving model to ../processed/model1.h5
# Learning rate: 1.2e-03
# Speed per epoch: -0.0004
#
# Epoch 13/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5387 - val_loss: -0.5426
#
# Epoch 00013: val_loss improved from -0.52952 to -0.54262, saving model to ../processed/model1.h5
# Learning rate: 1.2e-03
# Speed per epoch: -0.0100
#
# Epoch 14/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5469 - val_loss: -0.5177
#
# Epoch 00014: val_loss did not improve from -0.54262
# Learning rate: 1.2e-03
# Speed per epoch: -0.0081
#
# Epoch 15/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5533 - val_loss: -0.5211
#
# Epoch 00015: val_loss did not improve from -0.54262
# Learning rate: 1.2e-03
# Speed per epoch: -0.0079
#
# Epoch 16/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5301 - val_loss: -0.5329
#
# Epoch 00016: val_loss did not improve from -0.54262
# Learning rate: 8.3e-04
# Speed per epoch: 0.0056
#
# Epoch 17/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5465 - val_loss: -0.5448
#
# Epoch 00017: val_loss improved from -0.54262 to -0.54477, saving model to ../processed/model1.h5
# Learning rate: 3.7e-04
# Speed per epoch: -0.0045
#
# Epoch 18/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5640 - val_loss: -0.5570
#
# Epoch 00018: val_loss improved from -0.54477 to -0.55702, saving model to ../processed/model1.h5
# Learning rate: 3.7e-04
# Speed per epoch: -0.0124
#
# Epoch 19/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5813 - val_loss: -0.5471
#
# Epoch 00019: val_loss did not improve from -0.55702
# Learning rate: 3.7e-04
# Speed per epoch: -0.0140
#
# Epoch 20/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5692 - val_loss: -0.5614
#
# Epoch 00020: val_loss improved from -0.55702 to -0.56136, saving model to ../processed/model1.h5
# Learning rate: 3.7e-04
# Speed per epoch: -0.0040
#
# Epoch 21/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5725 - val_loss: -0.5651
#
# Epoch 00021: val_loss improved from -0.56136 to -0.56508, saving model to ../processed/model1.h5
# Learning rate: 3.7e-04
# Speed per epoch: -0.0025
#
# Epoch 22/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5783 - val_loss: -0.5631
#
# Epoch 00022: val_loss did not improve from -0.56508
# Learning rate: 3.7e-04
# Speed per epoch: -0.0025
#
# Epoch 23/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5761 - val_loss: -0.5580
#
# Epoch 00023: val_loss did not improve from -0.56508
# Learning rate: 3.6e-04
# Speed per epoch: 0.0005
#
# Epoch 24/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5824 - val_loss: -0.5543
#
# Epoch 00024: val_loss did not improve from -0.56508
# Learning rate: 2.4e-04
# Speed per epoch: -0.0040
#
# Epoch 25/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5952 - val_loss: -0.5627
#
# Epoch 00025: val_loss did not improve from -0.56508
# Learning rate: 2.4e-04
# Speed per epoch: -0.0091
#
# Epoch 26/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5827 - val_loss: -0.5637
#
# Epoch 00026: val_loss did not improve from -0.56508
# Learning rate: 2.3e-04
# Speed per epoch: -0.0018
#
# Epoch 27/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5827 - val_loss: -0.5626
#
# Epoch 00027: val_loss did not improve from -0.56508
# Learning rate: 1.5e-04
# Speed per epoch: 0.0013
#
# Epoch 28/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5873 - val_loss: -0.5658
#
# Epoch 00028: val_loss improved from -0.56508 to -0.56577, saving model to ../processed/model1.h5
# Learning rate: 8.5e-05
# Speed per epoch: -0.0015
#
# Epoch 29/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5930 - val_loss: -0.5711
#
# Epoch 00029: val_loss improved from -0.56577 to -0.57106, saving model to ../processed/model1.h5
# Learning rate: 8.4e-05
# Speed per epoch: -0.0034
#
# Epoch 30/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5919 - val_loss: -0.5679
#
# Epoch 00030: val_loss did not improve from -0.57106
# Learning rate: 8.3e-05
# Speed per epoch: -0.0020
#
# Epoch 31/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5932 - val_loss: -0.5634
#
# Epoch 00031: val_loss did not improve from -0.57106
# Learning rate: 7.4e-05
# Speed per epoch: 0.0009
#
# Epoch 32/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5922 - val_loss: -0.5665
#
# Epoch 00032: val_loss did not improve from -0.57106
# Learning rate: 4.3e-05
# Speed per epoch: 0.0010
#
# Epoch 33/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5993 - val_loss: -0.5654
#
# Epoch 00033: val_loss did not improve from -0.57106
# Learning rate: 4.2e-05
# Speed per epoch: -0.0006
#
# Epoch 34/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.6013 - val_loss: -0.5659
#
# Epoch 00034: val_loss did not improve from -0.57106
# Learning rate: 3.4e-05
# Speed per epoch: -0.0042
#
# Epoch 35/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.6116 - val_loss: -0.5631
#
# Epoch 00035: val_loss did not improve from -0.57106
# Learning rate: 3.4e-05
# Speed per epoch: -0.0074
#
# Epoch 36/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5973 - val_loss: -0.5644
#
# Epoch 00036: val_loss did not improve from -0.57106
# Learning rate: 2.7e-05
# Speed per epoch: 0.0024
#
# Epoch 37/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.6018 - val_loss: -0.5632
#
# Epoch 00037: val_loss did not improve from -0.57106
# Learning rate: 1.2e-05
# Speed per epoch: 0.0009
#
# Epoch 38/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5940 - val_loss: -0.5648
# Epoch 00038: val_loss did not improve from -0.57106
# Learning rate: 4.9e-06
# Speed per epoch: 0.0026
#
# Epoch 39/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5863 - val_loss: -0.5647
#
# Epoch 00039: val_loss did not improve from -0.57106
# Learning rate: 1.8e-06
# Speed per epoch: 0.0066
#
# Epoch 40/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.6040 - val_loss: -0.5647
#
# Epoch 00040: val_loss did not improve from -0.57106
# Learning rate: 9.4e-07
# Speed per epoch: -0.0047
#
#
# Fold - 2 / 10
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 21)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               2816
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 68
# =================================================================
# Total params: 13,748
# Trainable params: 13,748
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.5896 - intersection_over_union: -0.0910 - val_loss: 0.3852 - val_intersection_over_union: -0.2840
# Epoch 1/40
# 62/62 [==============================] - 1s 10ms/step - loss: -0.3594 - val_loss: -0.4109
#
# Epoch 00001: val_loss improved from inf to -0.41091, saving model to ../processed/model1.h5
# Learning rate: 2.0e-03
# Speed per epoch: -0.1436
#
# Epoch 2/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.4251 - val_loss: -0.4671
#
# Epoch 00002: val_loss improved from -0.41091 to -0.46710, saving model to ../processed/model1.h5
# Learning rate: 2.0e-03
# Speed per epoch: -0.0706
#
# Epoch 3/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.4658 - val_loss: -0.4889
#
# Epoch 00003: val_loss improved from -0.46710 to -0.48887, saving model to ../processed/model1.h5
# Learning rate: 2.0e-03
# Speed per epoch: -0.0485
#
# Epoch 4/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.4905 - val_loss: -0.4349
#
# Epoch 00004: val_loss did not improve from -0.48887
# Learning rate: 2.0e-03
# Speed per epoch: -0.0282
#
# Epoch 5/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.4805 - val_loss: -0.5004
#
# Epoch 00005: val_loss improved from -0.48887 to -0.50043, saving model to ../processed/model1.h5
# Learning rate: 2.0e-03
# Speed per epoch: -0.0147
#
# Epoch 6/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.4912 - val_loss: -0.4663
#
# Epoch 00006: val_loss did not improve from -0.50043
# Learning rate: 2.0e-03
# Speed per epoch: -0.0097
#
# Epoch 7/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.4980 - val_loss: -0.4878
#
# Epoch 00007: val_loss did not improve from -0.50043
# Learning rate: 2.0e-03
# Speed per epoch: -0.0081
#
# Epoch 8/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5036 - val_loss: -0.4535
#
# Epoch 00008: val_loss did not improve from -0.50043
# Learning rate: 2.0e-03
# Speed per epoch: -0.0066
#
# Epoch 9/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5036 - val_loss: -0.4748
#
# Epoch 00009: val_loss did not improve from -0.50043
# Learning rate: 2.0e-03
# Speed per epoch: -0.0049
#
# Epoch 10/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5048 - val_loss: -0.5023
#
# Epoch 00010: val_loss improved from -0.50043 to -0.50229, saving model to ../processed/model1.h5
# Learning rate: 1.8e-03
# Speed per epoch: -0.0043
#
# Epoch 11/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5266 - val_loss: -0.5251
#
# Epoch 00011: val_loss improved from -0.50229 to -0.52512, saving model to ../processed/model1.h5
# Learning rate: 1.8e-03
# Speed per epoch: -0.0092
#
# Epoch 12/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5253 - val_loss: -0.5036
#
# Epoch 00012: val_loss did not improve from -0.52512
# Learning rate: 1.8e-03
# Speed per epoch: -0.0057
#
# Epoch 13/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5189 - val_loss: -0.5288
#
# Epoch 00013: val_loss improved from -0.52512 to -0.52885, saving model to ../processed/model1.h5
# Learning rate: 1.4e-03
# Speed per epoch: 0.0011
#
# Epoch 14/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5491 - val_loss: -0.5321
#
# Epoch 00014: val_loss improved from -0.52885 to -0.53212, saving model to ../processed/model1.h5
# Learning rate: 1.2e-03
# Speed per epoch: -0.0091
#
# Epoch 15/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5431 - val_loss: -0.5473
#
# Epoch 00015: val_loss improved from -0.53212 to -0.54727, saving model to ../processed/model1.h5
# Learning rate: 1.2e-03
# Speed per epoch: -0.0032
#
# Epoch 16/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5461 - val_loss: -0.5466
#
# Epoch 00016: val_loss did not improve from -0.54727
# Learning rate: 1.2e-03
# Speed per epoch: -0.0046
#
# Epoch 17/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5387 - val_loss: -0.5359
#
# Epoch 00017: val_loss did not improve from -0.54727
# Learning rate: 9.9e-04
# Speed per epoch: 0.0050
#
# Epoch 18/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5558 - val_loss: -0.5544
#
# Epoch 00018: val_loss improved from -0.54727 to -0.55445, saving model to ../processed/model1.h5
# Learning rate: 7.3e-04
# Speed per epoch: -0.0038
#
# Epoch 19/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5695 - val_loss: -0.5479
#
# Epoch 00019: val_loss did not improve from -0.55445
# Learning rate: 7.3e-04
# Speed per epoch: -0.0061
#
# Epoch 20/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5667 - val_loss: -0.5584
#
# Epoch 00020: val_loss improved from -0.55445 to -0.55836, saving model to ../processed/model1.h5
# Learning rate: 7.3e-04
# Speed per epoch: -0.0006
#
# Epoch 21/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5697 - val_loss: -0.5359
#
# Epoch 00021: val_loss did not improve from -0.55836
# Learning rate: 7.3e-04
# Speed per epoch: -0.0014
#
# Epoch 22/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5724 - val_loss: -0.5645
#
# Epoch 00022: val_loss improved from -0.55836 to -0.56451, saving model to ../processed/model1.h5
# Learning rate: 7.0e-04
# Speed per epoch: -0.0036
#
# Epoch 23/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5661 - val_loss: -0.5304
#
# Epoch 00023: val_loss did not improve from -0.56451
# Learning rate: 5.7e-04
# Speed per epoch: 0.0007
#
# Epoch 24/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5744 - val_loss: -0.5541
#
# Epoch 00024: val_loss did not improve from -0.56451
# Learning rate: 2.9e-04
# Speed per epoch: -0.0075
#
# Epoch 25/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5875 - val_loss: -0.5738
#
# Epoch 00025: val_loss improved from -0.56451 to -0.57380, saving model to ../processed/model1.h5
# Learning rate: 2.9e-04
# Speed per epoch: -0.0055
#
# Epoch 26/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5910 - val_loss: -0.5615
#
# Epoch 00026: val_loss did not improve from -0.57380
# Learning rate: 2.9e-04
# Speed per epoch: -0.0054
#
# Epoch 27/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5838 - val_loss: -0.5662
#
# Epoch 00027: val_loss did not improve from -0.57380
# Learning rate: 2.7e-04
# Speed per epoch: 0.0004
#
# Epoch 28/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5923 - val_loss: -0.5699
#
# Epoch 00028: val_loss did not improve from -0.57380
# Learning rate: 2.0e-04
# Speed per epoch: -0.0049
#
# Epoch 29/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5801 - val_loss: -0.5680
#
# Epoch 00029: val_loss did not improve from -0.57380
# Learning rate: 1.5e-04
# Speed per epoch: 0.0030
#
# Epoch 30/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.6026 - val_loss: -0.5699
#
# Epoch 00030: val_loss did not improve from -0.57380
# Learning rate: 1.1e-04
# Speed per epoch: -0.0090
#
# Epoch 31/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5999 - val_loss: -0.5733
#
# Epoch 00031: val_loss did not improve from -0.57380
# Learning rate: 1.1e-04
# Speed per epoch: -0.0055
#
# Epoch 32/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5963 - val_loss: -0.5677
#
# Epoch 00032: val_loss did not improve from -0.57380
# Learning rate: 8.4e-05
# Speed per epoch: -0.0027
#
# Epoch 33/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.6028 - val_loss: -0.5683
#
# Epoch 00033: val_loss did not improve from -0.57380
# Learning rate: 8.4e-05
# Speed per epoch: -0.0014
#
# Epoch 34/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5961 - val_loss: -0.5758
#
# Epoch 00034: val_loss improved from -0.57380 to -0.57583, saving model to ../processed/model1.h5
# Learning rate: 4.8e-05
# Speed per epoch: 0.0014
#
# Epoch 35/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5996 - val_loss: -0.5676
#
# Epoch 00035: val_loss did not improve from -0.57583
# Learning rate: 3.4e-05
# Speed per epoch: 0.0018
#
# Epoch 36/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.6084 - val_loss: -0.5718
#
# Epoch 00036: val_loss did not improve from -0.57583
# Learning rate: 3.0e-05
# Speed per epoch: -0.0030
#
# Epoch 37/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.6134 - val_loss: -0.5699
#
# Epoch 00037: val_loss did not improve from -0.57583
# Learning rate: 3.0e-05
# Speed per epoch: -0.0025
#
# Epoch 38/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.6086 - val_loss: -0.5697
#
# Epoch 00038: val_loss did not improve from -0.57583
# Learning rate: 2.5e-05
# Speed per epoch: 0.0001
#
# Epoch 39/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.6029 - val_loss: -0.5721
#
# Epoch 00039: val_loss did not improve from -0.57583
# Learning rate: 1.4e-05
# Speed per epoch: 0.0041
#
# Epoch 40/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.6097 - val_loss: -0.5721
#
# Epoch 00040: val_loss did not improve from -0.57583
# Learning rate: 7.2e-06
# Speed per epoch: -0.0004
#
#
# Fold - 3 / 10
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 21)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               2816
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 68
# =================================================================
# Total params: 13,748
# Trainable params: 13,748
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.4815 - intersection_over_union: -0.1900 - val_loss: 0.2728 - val_intersection_over_union: -0.3681
# Epoch 1/40
# 62/62 [==============================] - 1s 10ms/step - loss: -0.4117 - val_loss: -0.4477
#
# Epoch 00001: val_loss improved from inf to -0.44773, saving model to ../processed/model1.h5
# Learning rate: 2.0e-03
# Speed per epoch: 0.0295
#
# Epoch 2/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.4399 - val_loss: -0.4045
#
# Epoch 00002: val_loss did not improve from -0.44773
# Learning rate: 1.8e-03
# Speed per epoch: -0.0234
#
# Epoch 3/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.4470 - val_loss: -0.4722
#
# Epoch 00003: val_loss improved from -0.44773 to -0.47216, saving model to ../processed/model1.h5
# Learning rate: 1.8e-03
# Speed per epoch: -0.0177
#
# Epoch 4/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.4817 - val_loss: -0.4730
#
# Epoch 00004: val_loss improved from -0.47216 to -0.47297, saving model to ../processed/model1.h5
# Learning rate: 1.8e-03
# Speed per epoch: -0.0198
#
# Epoch 5/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.4932 - val_loss: -0.3702
#
# Epoch 00005: val_loss did not improve from -0.47297
# Learning rate: 1.8e-03
# Speed per epoch: -0.0165
#
# Epoch 6/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.4902 - val_loss: -0.5030
#
# Epoch 00006: val_loss improved from -0.47297 to -0.50302, saving model to ../processed/model1.h5
# Learning rate: 1.8e-03
# Speed per epoch: -0.0100
#
# Epoch 7/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5023 - val_loss: -0.5005
#
# Epoch 00007: val_loss did not improve from -0.50302
# Learning rate: 1.8e-03
# Speed per epoch: -0.0086
#
# Epoch 8/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5113 - val_loss: -0.5026
#
# Epoch 00008: val_loss did not improve from -0.50302
# Learning rate: 1.8e-03
# Speed per epoch: -0.0084
#
# Epoch 9/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5067 - val_loss: -0.5001
#
# Epoch 00009: val_loss did not improve from -0.50302
# Learning rate: 1.8e-03
# Speed per epoch: -0.0040
#
# Epoch 10/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5211 - val_loss: -0.4902
#
# Epoch 00010: val_loss did not improve from -0.50302
# Learning rate: 1.8e-03
# Speed per epoch: -0.0099
#
# Epoch 11/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5148 - val_loss: -0.5252
#
# Epoch 00011: val_loss improved from -0.50302 to -0.52519, saving model to ../processed/model1.h5
# Learning rate: 1.8e-03
# Speed per epoch: -0.0044
#
# Epoch 12/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5300 - val_loss: -0.5260
#
# Epoch 00012: val_loss improved from -0.52519 to -0.52597, saving model to ../processed/model1.h5
# Learning rate: 1.8e-03
# Speed per epoch: -0.0070
#
# Epoch 13/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5284 - val_loss: -0.4917
#
# Epoch 00013: val_loss did not improve from -0.52597
# Learning rate: 1.8e-03
# Speed per epoch: -0.0015
#
# Epoch 14/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5281 - val_loss: -0.5389
#
# Epoch 00014: val_loss improved from -0.52597 to -0.53891, saving model to ../processed/model1.h5
# Learning rate: 1.4e-03
# Speed per epoch: -0.0022
#
# Epoch 15/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5404 - val_loss: -0.5140
#
# Epoch 00015: val_loss did not improve from -0.53891
# Learning rate: 1.4e-03
# Speed per epoch: -0.0072
#
# Epoch 16/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5332 - val_loss: -0.5123
#
# Epoch 00016: val_loss did not improve from -0.53891
# Learning rate: 1.4e-03
# Speed per epoch: -0.0013
#
# Epoch 17/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5460 - val_loss: -0.5197
#
# Epoch 00017: val_loss did not improve from -0.53891
# Learning rate: 1.4e-03
# Speed per epoch: -0.0047
#
# Epoch 18/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5442 - val_loss: -0.5039
#
# Epoch 00018: val_loss did not improve from -0.53891
# Learning rate: 1.3e-03
# Speed per epoch: -0.0029
#
# Epoch 19/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5560 - val_loss: -0.5086
#
# Epoch 00019: val_loss did not improve from -0.53891
# Learning rate: 1.3e-03
# Speed per epoch: -0.0052
#
# Epoch 20/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5653 - val_loss: -0.5296
#
# Epoch 00020: val_loss did not improve from -0.53891
# Learning rate: 1.3e-03
# Speed per epoch: -0.0049
#
# Epoch 21/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5532 - val_loss: -0.5175
#
# Epoch 00021: val_loss did not improve from -0.53891
# Learning rate: 9.9e-04
# Speed per epoch: -0.0014
#
# Epoch 22/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5644 - val_loss: -0.5414
#
# Epoch 00022: val_loss improved from -0.53891 to -0.54142, saving model to ../processed/model1.h5
# Learning rate: 9.9e-04
# Speed per epoch: -0.0026
#
# Epoch 23/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5629 - val_loss: -0.5300
#
# Epoch 00023: val_loss did not improve from -0.54142
# Learning rate: 8.3e-04
# Speed per epoch: -0.0029
#
# Epoch 24/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5704 - val_loss: -0.5433
#
# Epoch 00024: val_loss improved from -0.54142 to -0.54327, saving model to ../processed/model1.h5
# Learning rate: 8.3e-04
# Speed per epoch: -0.0056
#
# Epoch 25/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5768 - val_loss: -0.5319
#
# Epoch 00025: val_loss did not improve from -0.54327
# Learning rate: 8.3e-04
# Speed per epoch: -0.0026
#
# Epoch 26/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5864 - val_loss: -0.5333
#
# Epoch 00026: val_loss did not improve from -0.54327
# Learning rate: 8.3e-04
# Speed per epoch: -0.0060
#
# Epoch 27/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5770 - val_loss: -0.5409
#
# Epoch 00027: val_loss did not improve from -0.54327
# Learning rate: 5.8e-04
# Speed per epoch: -0.0043
#
# Epoch 28/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5743 - val_loss: -0.5438
#
# Epoch 00028: val_loss improved from -0.54327 to -0.54381, saving model to ../processed/model1.h5
# Learning rate: 3.7e-04
# Speed per epoch: -0.0007
#
# Epoch 29/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5968 - val_loss: -0.5434
#
# Epoch 00029: val_loss did not improve from -0.54381
# Learning rate: 3.7e-04
# Speed per epoch: -0.0059
#
# Epoch 30/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5848 - val_loss: -0.5473
#
# Epoch 00030: val_loss improved from -0.54381 to -0.54725, saving model to ../processed/model1.h5
# Learning rate: 3.6e-04
# Speed per epoch: 0.0015
#
# Epoch 31/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5987 - val_loss: -0.5517
#
# Epoch 00031: val_loss improved from -0.54725 to -0.55172, saving model to ../processed/model1.h5
# Learning rate: 3.0e-04
# Speed per epoch: -0.0060
#
# Epoch 32/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.6006 - val_loss: -0.5437
#
# Epoch 00032: val_loss did not improve from -0.55172
# Learning rate: 3.0e-04
# Speed per epoch: -0.0039
#
# Epoch 33/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.6002 - val_loss: -0.5536
#
# Epoch 00033: val_loss improved from -0.55172 to -0.55360, saving model to ../processed/model1.h5
# Learning rate: 2.9e-04
# Speed per epoch: -0.0008
#
# Epoch 34/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.6005 - val_loss: -0.5454
#
# Epoch 00034: val_loss did not improve from -0.55360
# Learning rate: 1.7e-04
# Speed per epoch: -0.0033
#
# Epoch 35/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.6070 - val_loss: -0.5503
#
# Epoch 00035: val_loss did not improve from -0.55360
# Learning rate: 1.6e-04
# Speed per epoch: -0.0066
#
# Epoch 36/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.6016 - val_loss: -0.5564
#
# Epoch 00036: val_loss improved from -0.55360 to -0.55641, saving model to ../processed/model1.h5
# Learning rate: 1.3e-04
# Speed per epoch: -0.0013
#
# Epoch 37/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.6018 - val_loss: -0.5553
#
# Epoch 00037: val_loss did not improve from -0.55641
# Learning rate: 7.5e-05
# Speed per epoch: -0.0007
#
# Epoch 38/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.6067 - val_loss: -0.5521
#
# Epoch 00038: val_loss did not improve from -0.55641
# Learning rate: 6.3e-05
# Speed per epoch: 0.0003
#
# Epoch 39/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.6172 - val_loss: -0.5563
#
# Epoch 00039: val_loss did not improve from -0.55641
# Learning rate: 4.8e-05
# Speed per epoch: -0.0058
#
# Epoch 40/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.6131 - val_loss: -0.5552
#
# Epoch 00040: val_loss did not improve from -0.55641
# Learning rate: 4.5e-05
# Speed per epoch: -0.0012
#
#
# Fold - 4 / 10
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 21)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               2816
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 68
# =================================================================
# Total params: 13,748
# Trainable params: 13,748
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.7078 - intersection_over_union: -0.0162 - val_loss: 0.4973 - val_intersection_over_union: -0.0617
# Epoch 1/40
# 62/62 [==============================] - 1s 9ms/step - loss: -0.2444 - val_loss: -0.1524
#
# Epoch 00001: val_loss improved from inf to -0.15245, saving model to ../processed/model1.h5
# Learning rate: 2.0e-03
# Speed per epoch: -0.3402
#
# Epoch 2/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.3967 - val_loss: -0.4204
#
# Epoch 00002: val_loss improved from -0.15245 to -0.42035, saving model to ../processed/model1.h5
# Learning rate: 2.0e-03
# Speed per epoch: -0.1319
#
# Epoch 3/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.4506 - val_loss: -0.4412
#
# Epoch 00003: val_loss improved from -0.42035 to -0.44118, saving model to ../processed/model1.h5
# Learning rate: 2.0e-03
# Speed per epoch: -0.0729
#
# Epoch 4/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.4667 - val_loss: -0.4338
#
# Epoch 00004: val_loss did not improve from -0.44118
# Learning rate: 2.0e-03
# Speed per epoch: -0.0406
#
# Epoch 5/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.4810 - val_loss: -0.4965
#
# Epoch 00005: val_loss improved from -0.44118 to -0.49650, saving model to ../processed/model1.h5
# Learning rate: 2.0e-03
# Speed per epoch: -0.0222
#
# Epoch 6/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.4920 - val_loss: -0.4673
#
# Epoch 00006: val_loss did not improve from -0.49650
# Learning rate: 2.0e-03
# Speed per epoch: -0.0185
#
# Epoch 7/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.4872 - val_loss: -0.4984
#
# Epoch 00007: val_loss improved from -0.49650 to -0.49838, saving model to ../processed/model1.h5
# Learning rate: 2.0e-03
# Speed per epoch: -0.0090
#
# Epoch 8/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5065 - val_loss: -0.4786
#
# Epoch 00008: val_loss did not improve from -0.49838
# Learning rate: 2.0e-03
# Speed per epoch: -0.0120
#
# Epoch 9/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5104 - val_loss: -0.5068
#
# Epoch 00009: val_loss improved from -0.49838 to -0.50680, saving model to ../processed/model1.h5
# Learning rate: 2.0e-03
# Speed per epoch: -0.0061
#
# Epoch 10/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5177 - val_loss: -0.5063
#
# Epoch 00010: val_loss did not improve from -0.50680
# Learning rate: 2.0e-03
# Speed per epoch: -0.0114
#
# Epoch 11/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5102 - val_loss: -0.4944
#
# Epoch 00011: val_loss did not improve from -0.50680
# Learning rate: 2.0e-03
# Speed per epoch: -0.0014
#
# Epoch 12/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5182 - val_loss: -0.4915
#
# Epoch 00012: val_loss did not improve from -0.50680
# Learning rate: 1.9e-03
# Speed per epoch: -0.0035
#
# Epoch 13/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5231 - val_loss: -0.4503
#
# Epoch 00013: val_loss did not improve from -0.50680
# Learning rate: 1.9e-03
# Speed per epoch: -0.0032
#
# Epoch 14/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5237 - val_loss: -0.5068
#
# Epoch 00014: val_loss did not improve from -0.50680
# Learning rate: 1.5e-03
# Speed per epoch: -0.0052
#
# Epoch 15/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5450 - val_loss: -0.5367
#
# Epoch 00015: val_loss improved from -0.50680 to -0.53667, saving model to ../processed/model1.h5
# Learning rate: 1.5e-03
# Speed per epoch: -0.0122
#
# Epoch 16/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5433 - val_loss: -0.5029
#
# Epoch 00016: val_loss did not improve from -0.53667
# Learning rate: 1.5e-03
# Speed per epoch: -0.0041
#
# Epoch 17/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5504 - val_loss: -0.4807
#
# Epoch 00017: val_loss did not improve from -0.53667
# Learning rate: 1.5e-03
# Speed per epoch: -0.0063
#
# Epoch 18/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5444 - val_loss: -0.5037
#
# Epoch 00018: val_loss did not improve from -0.53667
# Learning rate: 1.4e-03
# Speed per epoch: -0.0001
#
# Epoch 19/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5577 - val_loss: -0.5244
#
# Epoch 00019: val_loss did not improve from -0.53667
# Learning rate: 1.2e-03
# Speed per epoch: -0.0041
#
# Epoch 20/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5475 - val_loss: -0.5432
#
# Epoch 00020: val_loss improved from -0.53667 to -0.54318, saving model to ../processed/model1.h5
# Learning rate: 6.8e-04
# Speed per epoch: -0.0006
#
# Epoch 21/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5687 - val_loss: -0.5361
#
# Epoch 00021: val_loss did not improve from -0.54318
# Learning rate: 6.8e-04
# Speed per epoch: -0.0079
#
# Epoch 22/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5613 - val_loss: -0.5438
#
# Epoch 00022: val_loss improved from -0.54318 to -0.54383, saving model to ../processed/model1.h5
# Learning rate: 6.8e-04
# Speed per epoch: -0.0048
#
# Epoch 23/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5734 - val_loss: -0.5517
#
# Epoch 00023: val_loss improved from -0.54383 to -0.55169, saving model to ../processed/model1.h5
# Learning rate: 6.8e-04
# Speed per epoch: -0.0018
#
# Epoch 24/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5762 - val_loss: -0.5490
#
# Epoch 00024: val_loss did not improve from -0.55169
# Learning rate: 6.8e-04
# Speed per epoch: -0.0045
#
# Epoch 25/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5692 - val_loss: -0.5431
#
# Epoch 00025: val_loss did not improve from -0.55169
# Learning rate: 5.3e-04
# Speed per epoch: -0.0010
#
# Epoch 26/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5835 - val_loss: -0.5347
#
# Epoch 00026: val_loss did not improve from -0.55169
# Learning rate: 5.3e-04
# Speed per epoch: -0.0038
#
# Epoch 27/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5771 - val_loss: -0.5423
#
# Epoch 00027: val_loss did not improve from -0.55169
# Learning rate: 4.3e-04
# Speed per epoch: -0.0035
#
# Epoch 28/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5915 - val_loss: -0.5487
#
# Epoch 00028: val_loss did not improve from -0.55169
# Learning rate: 4.3e-04
# Speed per epoch: -0.0040
#
# Epoch 29/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5772 - val_loss: -0.5441
#
# Epoch 00029: val_loss did not improve from -0.55169
# Learning rate: 3.3e-04
# Speed per epoch: 0.0035
#
# Epoch 30/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5949 - val_loss: -0.5530
#
# Epoch 00030: val_loss improved from -0.55169 to -0.55297, saving model to ../processed/model1.h5
# Learning rate: 1.8e-04
# Speed per epoch: -0.0089
#
# Epoch 31/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5926 - val_loss: -0.5505
#
# Epoch 00031: val_loss did not improve from -0.55297
# Learning rate: 1.8e-04
# Speed per epoch: -0.0044
#
# Epoch 32/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.6000 - val_loss: -0.5485
#
# Epoch 00032: val_loss did not improve from -0.55297
# Learning rate: 1.8e-04
# Speed per epoch: -0.0053
#
# Epoch 33/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5983 - val_loss: -0.5529
#
# Epoch 00033: val_loss did not improve from -0.55297
# Learning rate: 1.8e-04
# Speed per epoch: -0.0010
#
# Epoch 34/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.6006 - val_loss: -0.5518
#
# Epoch 00034: val_loss did not improve from -0.55297
# Learning rate: 1.5e-04
# Speed per epoch: -0.0026
#
# Epoch 35/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5985 - val_loss: -0.5514
#
# Epoch 00035: val_loss did not improve from -0.55297
# Learning rate: 1.1e-04
# Speed per epoch: -0.0013
#
# Epoch 36/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.6033 - val_loss: -0.5516
#
# Epoch 00036: val_loss did not improve from -0.55297
# Learning rate: 1.1e-04
# Speed per epoch: -0.0027
#
# Epoch 37/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.6013 - val_loss: -0.5482
#
# Epoch 00037: val_loss did not improve from -0.55297
# Learning rate: 8.4e-05
# Speed per epoch: -0.0008
#
# Epoch 38/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.6015 - val_loss: -0.5533
#
# Epoch 00038: val_loss improved from -0.55297 to -0.55333, saving model to ../processed/model1.h5
# Learning rate: 4.5e-05
# Speed per epoch: -0.0017
#
# Epoch 39/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.6129 - val_loss: -0.5573
#
# Epoch 00039: val_loss improved from -0.55333 to -0.55731, saving model to ../processed/model1.h5
# Learning rate: 4.5e-05
# Speed per epoch: -0.0054
#
# Epoch 40/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.6035 - val_loss: -0.5541
#
# Epoch 00040: val_loss did not improve from -0.55731
# Learning rate: 4.1e-05
# Speed per epoch: 0.0010
#
#
# Fold - 5 / 10
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 21)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               2816
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 68
# =================================================================
# Total params: 13,748
# Trainable params: 13,748
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.4513 - intersection_over_union: -0.2161 - val_loss: 0.3600 - val_intersection_over_union: -0.3276
# Epoch 1/40
# 62/62 [==============================] - 1s 9ms/step - loss: -0.3971 - val_loss: -0.4282
#
# Epoch 00001: val_loss improved from inf to -0.42823, saving model to ../processed/model1.h5
# Learning rate: 2.0e-03
# Speed per epoch: 0.0141
#
# Epoch 2/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.4337 - val_loss: -0.4754
#
# Epoch 00002: val_loss improved from -0.42823 to -0.47536, saving model to ../processed/model1.h5
# Learning rate: 1.9e-03
# Speed per epoch: -0.0361
#
# Epoch 3/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.4619 - val_loss: -0.4867
#
# Epoch 00003: val_loss improved from -0.47536 to -0.48668, saving model to ../processed/model1.h5
# Learning rate: 1.9e-03
# Speed per epoch: -0.0256
#
# Epoch 4/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.4736 - val_loss: -0.4986
#
# Epoch 00004: val_loss improved from -0.48668 to -0.49863, saving model to ../processed/model1.h5
# Learning rate: 1.9e-03
# Speed per epoch: -0.0174
#
# Epoch 5/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.4673 - val_loss: -0.4944
#
# Epoch 00005: val_loss did not improve from -0.49863
# Learning rate: 1.9e-03
# Speed per epoch: -0.0083
#
# Epoch 6/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.4955 - val_loss: -0.5306
#
# Epoch 00006: val_loss improved from -0.49863 to -0.53056, saving model to ../processed/model1.h5
# Learning rate: 1.9e-03
# Speed per epoch: -0.0111
#
# Epoch 7/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.4914 - val_loss: -0.4364
#
# Epoch 00007: val_loss did not improve from -0.53056
# Learning rate: 1.9e-03
# Speed per epoch: -0.0082
#
# Epoch 8/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5021 - val_loss: -0.4979
#
# Epoch 00008: val_loss did not improve from -0.53056
# Learning rate: 1.9e-03
# Speed per epoch: -0.0081
#
# Epoch 9/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5102 - val_loss: -0.5084
#
# Epoch 00009: val_loss did not improve from -0.53056
# Learning rate: 1.9e-03
# Speed per epoch: -0.0089
#
# Epoch 10/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5084 - val_loss: -0.4935
#
# Epoch 00010: val_loss did not improve from -0.53056
# Learning rate: 1.9e-03
# Speed per epoch: -0.0044
#
# Epoch 11/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5216 - val_loss: -0.5333
#
# Epoch 00011: val_loss improved from -0.53056 to -0.53330, saving model to ../processed/model1.h5
# Learning rate: 1.9e-03
# Speed per epoch: -0.0053
#
# Epoch 12/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5051 - val_loss: -0.5481
#
# Epoch 00012: val_loss improved from -0.53330 to -0.54808, saving model to ../processed/model1.h5
# Learning rate: 1.3e-03
# Speed per epoch: 0.0036
#
# Epoch 13/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5279 - val_loss: -0.5531
#
# Epoch 00013: val_loss improved from -0.54808 to -0.55313, saving model to ../processed/model1.h5
# Learning rate: 1.1e-03
# Speed per epoch: -0.0079
#
# Epoch 14/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5407 - val_loss: -0.5581
#
# Epoch 00014: val_loss improved from -0.55313 to -0.55814, saving model to ../processed/model1.h5
# Learning rate: 1.1e-03
# Speed per epoch: -0.0096
#
# Epoch 15/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5461 - val_loss: -0.5465
#
# Epoch 00015: val_loss did not improve from -0.55814
# Learning rate: 1.1e-03
# Speed per epoch: -0.0096
#
# Epoch 16/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5465 - val_loss: -0.5632
#
# Epoch 00016: val_loss improved from -0.55814 to -0.56319, saving model to ../processed/model1.h5
# Learning rate: 1.1e-03
# Speed per epoch: -0.0062
#
# Epoch 17/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5529 - val_loss: -0.5477
#
# Epoch 00017: val_loss did not improve from -0.56319
# Learning rate: 1.1e-03
# Speed per epoch: -0.0064
#
# Epoch 18/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5455 - val_loss: -0.5638
#
# Epoch 00018: val_loss improved from -0.56319 to -0.56375, saving model to ../processed/model1.h5
# Learning rate: 8.9e-04
# Speed per epoch: -0.0013
#
# Epoch 19/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5555 - val_loss: -0.5615
#
# Epoch 00019: val_loss did not improve from -0.56375
# Learning rate: 8.2e-04
# Speed per epoch: -0.0046
#
# Epoch 20/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5599 - val_loss: -0.5633
#
# Epoch 00020: val_loss did not improve from -0.56375
# Learning rate: 8.2e-04
# Speed per epoch: -0.0048
#
# Epoch 21/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5722 - val_loss: -0.5630
#
# Epoch 00021: val_loss did not improve from -0.56375
# Learning rate: 8.2e-04
# Speed per epoch: -0.0086
#
# Epoch 22/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5700 - val_loss: -0.5524
#
# Epoch 00022: val_loss did not improve from -0.56375
# Learning rate: 8.2e-04
# Speed per epoch: -0.0041
#
# Epoch 23/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5661 - val_loss: -0.5507
#
# Epoch 00023: val_loss did not improve from -0.56375
# Learning rate: 7.7e-04
# Speed per epoch: 0.0017
#
# Epoch 24/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5767 - val_loss: -0.5676
#
# Epoch 00024: val_loss improved from -0.56375 to -0.56759, saving model to ../processed/model1.h5
# Learning rate: 5.8e-04
# Speed per epoch: -0.0015
#
# Epoch 25/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5703 - val_loss: -0.5706
#
# Epoch 00025: val_loss improved from -0.56759 to -0.57056, saving model to ../processed/model1.h5
# Learning rate: 3.9e-04
# Speed per epoch: -0.0010
#
# Epoch 26/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5785 - val_loss: -0.5820
#
# Epoch 00026: val_loss improved from -0.57056 to -0.58200, saving model to ../processed/model1.h5
# Learning rate: 3.3e-04
# Speed per epoch: -0.0042
#
# Epoch 27/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5842 - val_loss: -0.5827
#
# Epoch 00027: val_loss improved from -0.58200 to -0.58271, saving model to ../processed/model1.h5
# Learning rate: 3.3e-04
# Speed per epoch: -0.0052
#
# Epoch 28/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5797 - val_loss: -0.5891
#
# ...
# Learning rate: 7.7e-04
# Speed per epoch: -0.0158
#
# Epoch 14/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5481 - val_loss: -0.5184
#
# Epoch 00014: val_loss did not improve from -0.52275
# Learning rate: 7.7e-04
# Speed per epoch: -0.0048
#
# Epoch 15/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5471 - val_loss: -0.5156
#
# Epoch 00015: val_loss did not improve from -0.52275
# Learning rate: 6.1e-04
# Speed per epoch: -0.0043
#
# Epoch 16/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5536 - val_loss: -0.5338
#
# Epoch 00016: val_loss improved from -0.52275 to -0.53377, saving model to ../processed/model1.h5
# Learning rate: 5.8e-04
# Speed per epoch: -0.0049
#
# Epoch 17/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5581 - val_loss: -0.5118
#
# Epoch 00017: val_loss did not improve from -0.53377
# Learning rate: 5.8e-04
# Speed per epoch: -0.0019
#
# Epoch 18/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5637 - val_loss: -0.5243
#
# Epoch 00018: val_loss did not improve from -0.53377
# Learning rate: 5.8e-04
# Speed per epoch: -0.0029
#
# Epoch 19/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5656 - val_loss: -0.5193
#
# Epoch 00019: val_loss did not improve from -0.53377
# Learning rate: 5.8e-04
# Speed per epoch: -0.0010
#
# Epoch 20/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5681 - val_loss: -0.5365
#
# Epoch 00020: val_loss improved from -0.53377 to -0.53648, saving model to ../processed/model1.h5
# Learning rate: 4.1e-04
# Speed per epoch: -0.0054
#
# Epoch 21/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5708 - val_loss: -0.5331
#
# Epoch 00021: val_loss did not improve from -0.53648
# Learning rate: 4.1e-04
# Speed per epoch: -0.0044
#
# Epoch 22/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5730 - val_loss: -0.5386
#
# Epoch 00022: val_loss improved from -0.53648 to -0.53860, saving model to ../processed/model1.h5
# Learning rate: 4.1e-04
# Speed per epoch: -0.0024
#
# Epoch 23/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5739 - val_loss: -0.5451
#
# Epoch 00023: val_loss improved from -0.53860 to -0.54509, saving model to ../processed/model1.h5
# Learning rate: 2.5e-04
# Speed per epoch: -0.0065
#
# Epoch 24/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5891 - val_loss: -0.5394
#
# Epoch 00024: val_loss did not improve from -0.54509
# Learning rate: 2.5e-04
# Speed per epoch: -0.0094
#
# Epoch 25/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5789 - val_loss: -0.5353
#
# Epoch 00025: val_loss did not improve from -0.54509
# Learning rate: 2.3e-04
# Speed per epoch: 0.0004
#
# Epoch 26/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5959 - val_loss: -0.5507
#
# Epoch 00026: val_loss improved from -0.54509 to -0.55065, saving model to ../processed/model1.h5
# Learning rate: 2.2e-04
# Speed per epoch: -0.0045
#
# Epoch 27/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5944 - val_loss: -0.5335
#
# Epoch 00027: val_loss did not improve from -0.55065
# Learning rate: 2.2e-04
# Speed per epoch: -0.0051
#
# Epoch 28/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5914 - val_loss: -0.5443
#
# Epoch 00028: val_loss did not improve from -0.55065
# Learning rate: 1.8e-04
# Speed per epoch: -0.0018
#
# Epoch 29/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5961 - val_loss: -0.5387
#
# Epoch 00029: val_loss did not improve from -0.55065
# Learning rate: 1.3e-04
# Speed per epoch: -0.0050
#
# Epoch 30/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5975 - val_loss: -0.5476
#
# Epoch 00030: val_loss did not improve from -0.55065
# Learning rate: 1.3e-04
# Speed per epoch: -0.0033
#
# Epoch 31/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.6037 - val_loss: -0.5393
#
# Epoch 00031: val_loss did not improve from -0.55065
# Learning rate: 1.3e-04
# Speed per epoch: -0.0004
#
# Epoch 32/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.6076 - val_loss: -0.5399
#
# Epoch 00032: val_loss did not improve from -0.55065
# Learning rate: 1.3e-04
# Speed per epoch: -0.0034
#
# Epoch 33/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5996 - val_loss: -0.5496
#
# Epoch 00033: val_loss did not improve from -0.55065
# Learning rate: 9.1e-05
# Speed per epoch: -0.0004
#
# Epoch 34/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.6149 - val_loss: -0.5476
#
# Epoch 00034: val_loss did not improve from -0.55065
# Learning rate: 9.1e-05
# Speed per epoch: -0.0054
#
# Epoch 35/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5991 - val_loss: -0.5483
#
# Epoch 00035: val_loss did not improve from -0.55065
# Learning rate: 7.3e-05
# Speed per epoch: 0.0044
#
# Epoch 36/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.6157 - val_loss: -0.5472
#
# Epoch 00036: val_loss did not improve from -0.55065
# Learning rate: 5.1e-05
# Speed per epoch: -0.0029
#
# Epoch 37/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.6122 - val_loss: -0.5445
#
# Epoch 00037: val_loss did not improve from -0.55065
# Learning rate: 4.9e-05
# Speed per epoch: -0.0014
#
# Epoch 38/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.6068 - val_loss: -0.5451
#
# Epoch 00038: val_loss did not improve from -0.55065
# Learning rate: 2.3e-05
# Speed per epoch: 0.0001
#
# Epoch 39/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.6084 - val_loss: -0.5474
#
# Epoch 00039: val_loss did not improve from -0.55065
# Learning rate: 1.6e-05
# Speed per epoch: 0.0019
#
# Epoch 40/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.6069 - val_loss: -0.5476
#
# Epoch 00040: val_loss did not improve from -0.55065
# Learning rate: 6.4e-06
# Speed per epoch: -0.0010
#
#
# Fold - 10 / 10
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 21)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               2816
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 68
# =================================================================
# Total params: 13,748
# Trainable params: 13,748
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.6377 - intersection_over_union: -0.0794 - val_loss: 0.3867 - val_intersection_over_union: -0.2613
# Epoch 1/40
# 62/62 [==============================] - 1s 10ms/step - loss: -0.3375 - val_loss: -0.4208
#
# Epoch 00001: val_loss improved from inf to -0.42083, saving model to ../processed/model1.h5
# Learning rate: 2.0e-03
# Speed per epoch: -0.1714
#
# Epoch 2/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.4312 - val_loss: -0.4366
#
# Epoch 00002: val_loss improved from -0.42083 to -0.43658, saving model to ../processed/model1.h5
# Learning rate: 2.0e-03
# Speed per epoch: -0.0877
#
# Epoch 3/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.4738 - val_loss: -0.4461
#
# Epoch 00003: val_loss improved from -0.43658 to -0.44606, saving model to ../processed/model1.h5
# Learning rate: 2.0e-03
# Speed per epoch: -0.0515
#
# Epoch 4/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.4824 - val_loss: -0.4319
#
# Epoch 00004: val_loss did not improve from -0.44606
# Learning rate: 2.0e-03
# Speed per epoch: -0.0299
#
# Epoch 5/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5003 - val_loss: -0.4792
#
# Epoch 00005: val_loss improved from -0.44606 to -0.47916, saving model to ../processed/model1.h5
# Learning rate: 2.0e-03
# Speed per epoch: -0.0248
#
# Epoch 6/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5081 - val_loss: -0.4524
#
# Epoch 00006: val_loss did not improve from -0.47916
# Learning rate: 2.0e-03
# Speed per epoch: -0.0142
#
# Epoch 7/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5074 - val_loss: -0.4590
#
# Epoch 00007: val_loss did not improve from -0.47916
# Learning rate: 2.0e-03
# Speed per epoch: -0.0068
#
# Epoch 8/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5284 - val_loss: -0.4544
#
# Epoch 00008: val_loss did not improve from -0.47916
# Learning rate: 2.0e-03
# Speed per epoch: -0.0126
#
# Epoch 9/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5110 - val_loss: -0.4842
#
# Epoch 00009: val_loss improved from -0.47916 to -0.48418, saving model to ../processed/model1.h5
# Learning rate: 1.9e-03
# Speed per epoch: -0.0013
#
# Epoch 10/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5183 - val_loss: -0.4893
#
# Epoch 00010: val_loss improved from -0.48418 to -0.48927, saving model to ../processed/model1.h5
# Learning rate: 1.6e-03
# Speed per epoch: -0.0011
#
# Epoch 11/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5264 - val_loss: -0.4934
#
# Epoch 00011: val_loss improved from -0.48927 to -0.49344, saving model to ../processed/model1.h5
# Learning rate: 1.6e-03
# Speed per epoch: -0.0017
#
# Epoch 12/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5356 - val_loss: -0.5056
#
# Epoch 00012: val_loss improved from -0.49344 to -0.50558, saving model to ../processed/model1.h5
# Learning rate: 1.6e-03
# Speed per epoch: -0.0043
#
# Epoch 13/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.5386 - val_loss: -0.4888
#
# Epoch 00013: val_loss did not improve from -0.50558
# Learning rate: 1.6e-03
# Speed per epoch: -0.0059
#
# Epoch 14/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5418 - val_loss: -0.4955
#
# Epoch 00014: val_loss did not improve from -0.50558
# Learning rate: 1.6e-03
# Speed per epoch: -0.0047
#
# Epoch 15/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5499 - val_loss: -0.5029
#
# Epoch 00015: val_loss did not improve from -0.50558
# Learning rate: 1.6e-03
# Speed per epoch: -0.0040
#
# Epoch 16/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5479 - val_loss: -0.5146
#
# Epoch 00016: val_loss improved from -0.50558 to -0.51461, saving model to ../processed/model1.h5
# Learning rate: 1.4e-03
# Speed per epoch: -0.0020
#
# Epoch 17/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5411 - val_loss: -0.4812
#
# Epoch 00017: val_loss did not improve from -0.51461
# Learning rate: 9.9e-04
# Speed per epoch: 0.0059
#
# Epoch 18/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5582 - val_loss: -0.4840
#
# Epoch 00018: val_loss did not improve from -0.51461
# Learning rate: 7.0e-04
# Speed per epoch: -0.0061
#
# Epoch 19/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5754 - val_loss: -0.5173
#
# Epoch 00019: val_loss improved from -0.51461 to -0.51732, saving model to ../processed/model1.h5
# Learning rate: 7.0e-04
# Speed per epoch: -0.0095
#
# Epoch 20/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5793 - val_loss: -0.5296
#
# Epoch 00020: val_loss improved from -0.51732 to -0.52958, saving model to ../processed/model1.h5
# Learning rate: 7.0e-04
# Speed per epoch: -0.0083
#
# Epoch 21/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5711 - val_loss: -0.5222
#
# Epoch 00021: val_loss did not improve from -0.52958
# Learning rate: 7.0e-04
# Speed per epoch: -0.0015
#
# Epoch 22/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5756 - val_loss: -0.5248
#
# Epoch 00022: val_loss did not improve from -0.52958
# Learning rate: 5.3e-04
# Speed per epoch: -0.0029
#
# Epoch 23/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5764 - val_loss: -0.5274
#
# Epoch 00023: val_loss did not improve from -0.52958
# Learning rate: 4.8e-04
# Speed per epoch: -0.0008
#
# Epoch 24/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5757 - val_loss: -0.5364
#
# Epoch 00024: val_loss improved from -0.52958 to -0.53643, saving model to ../processed/model1.h5
# Learning rate: 3.4e-04
# Speed per epoch: -0.0012
#
# Epoch 25/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5919 - val_loss: -0.5312
#
# Epoch 00025: val_loss did not improve from -0.53643
# Learning rate: 3.4e-04
# Speed per epoch: -0.0053
#
# Epoch 26/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5862 - val_loss: -0.5375
#
# Epoch 00026: val_loss improved from -0.53643 to -0.53755, saving model to ../processed/model1.h5
# Learning rate: 3.2e-04
# Speed per epoch: -0.0051
#
# Epoch 27/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5865 - val_loss: -0.5364
#
# Epoch 00027: val_loss did not improve from -0.53755
# Learning rate: 3.0e-04
# Speed per epoch: -0.0001
#
# Epoch 28/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5914 - val_loss: -0.5332
#
# Epoch 00028: val_loss did not improve from -0.53755
# Learning rate: 2.0e-04
# Speed per epoch: -0.0037
#
# Epoch 29/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5979 - val_loss: -0.5472
#
# Epoch 00029: val_loss improved from -0.53755 to -0.54718, saving model to ../processed/model1.h5
# Learning rate: 2.0e-04
# Speed per epoch: -0.0067
#
# Epoch 30/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5971 - val_loss: -0.5455
#
# Epoch 00030: val_loss did not improve from -0.54718
# Learning rate: 2.0e-04
# Speed per epoch: -0.0007
#
# Epoch 31/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5857 - val_loss: -0.5497
#
# Epoch 00031: val_loss improved from -0.54718 to -0.54967, saving model to ../processed/model1.h5
# Learning rate: 1.1e-04
# Speed per epoch: 0.0041
#
# Epoch 32/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.6063 - val_loss: -0.5487
#
# Epoch 00032: val_loss did not improve from -0.54967
# Learning rate: 9.1e-05
# Speed per epoch: -0.0052
#
# Epoch 33/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5956 - val_loss: -0.5327
#
# Epoch 00033: val_loss did not improve from -0.54967
# Learning rate: 8.1e-05
# Speed per epoch: -0.0013
#
# Epoch 34/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.6181 - val_loss: -0.5464
#
# Epoch 00034: val_loss did not improve from -0.54967
# Learning rate: 8.1e-05
# Speed per epoch: -0.0097
#
# Epoch 35/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.5992 - val_loss: -0.5447
#
# Epoch 00035: val_loss did not improve from -0.54967
# Learning rate: 6.7e-05
# Speed per epoch: 0.0011
#
# Epoch 36/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.6016 - val_loss: -0.5433
#
# Epoch 00036: val_loss did not improve from -0.54967
# Learning rate: 2.9e-05
# Speed per epoch: 0.0008
#
# Epoch 37/40
# 62/62 [==============================] - 0s 3ms/step - loss: -0.6014 - val_loss: -0.5485
#
# Epoch 00037: val_loss did not improve from -0.54967
# Learning rate: 1.3e-05
# Speed per epoch: 0.0003
#
# Epoch 38/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.6181 - val_loss: -0.5482
#
# Epoch 00038: val_loss did not improve from -0.54967
# Learning rate: 1.2e-05
# Speed per epoch: -0.0059
#
# Epoch 39/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.6106 - val_loss: -0.5483
#
# Epoch 00039: val_loss did not improve from -0.54967
# Learning rate: 1.2e-05
# Speed per epoch: -0.0032
#
# Epoch 40/40
# 62/62 [==============================] - 0s 4ms/step - loss: -0.6132 - val_loss: -0.5473
#
# Epoch 00040: val_loss did not improve from -0.54967
# Learning rate: 1.2e-05
# Speed per epoch: -0.0009
#
# IOU на кроссвалидации: [0.59611 0.58461 0.58101 0.57583 0.57575 0.57106 0.55731 0.55641 0.55065
#  0.54967]
# IOU среднее: 0.56984 +/- 0.01489
