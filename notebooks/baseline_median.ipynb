# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import time

# %%
def area(box):
    return (box[2] - box[0]) * (box[3] - box[1])


def intersection_over_union(boxes):
    assert(len(boxes) == 8)
    boxA = boxes[:4].values
    boxB = boxes[4:].values
    
    boxAArea = area(boxA)
    boxBArea = area(boxB)
    
    if (boxAArea == 0 or boxBArea == 0):
        return 0
        
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])

    interArea = max(0, xB - xA) * max(0, yB - yA)

    
    iou = interArea / float(boxAArea + boxBArea - interArea)
    return iou

# %%
votes = pd.read_csv("../raw/train_data.csv")

# %%
answers = pd.read_csv("../raw/train_answers.csv")

# %%
votes_test = pd.read_csv("../raw/test_data.csv")

# %%
data = votes.merge(answers, on="itemId")

# %%
Xmin = data[["userId", "itemId", "Xmin", "Xmin_true"]]

# %%
Xmin["error"] = Xmin["Xmin"] - Xmin["Xmin_true"]
# Out:
# /Users/WLMike/Documents/PycharmProjects/ML_venv/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
sub = votes_test.drop("userId", axis=1).groupby("itemId").median()
sub
# Out:
#          Xmin    Ymin   Xmax    Ymax
# itemId
# 18      135.0   704.0  729.0  1071.0
# 19       28.0   559.0  113.0   727.0
# 33       43.0   388.0  365.0   629.0
# 62       98.0   980.0  623.0  1163.0
# 114      69.0   575.0  210.0   763.0
# 146      76.5   481.0  572.0   820.0
# 156      87.0   802.0  155.0   879.0
# 163      30.5   322.0  212.0   462.5
# 164       6.0   149.0  349.0   650.0
# 179     127.0   515.0  321.0   731.0
# 186     155.0   923.0  966.0  1476.0
# 215     245.0   663.0  824.0  1027.0
# 225      46.0   708.5   97.0   753.0
# 227     303.0   888.0  758.0  1348.0
# 247      59.5   630.5  156.0   738.5
# 275      91.0   515.0  657.0   913.0
# 311     193.0   631.5  530.0  1021.0
# 399     108.5   796.0  346.5  1030.0
# 421      55.5   934.0  241.0  1060.0
# 432      56.0   846.0  296.0  1013.0
# 442      35.0   674.0  206.0   807.0
# 459      20.0   338.0  229.0   490.0
# 492     104.0  1093.0  231.0  1227.0
# 507     238.0   237.0  879.0   828.0
# 631     259.0   573.0  854.0  1125.0
# 707      48.0   820.0   68.5   833.0
# 723     134.0   180.0  880.0   719.0
# 1003    108.0   615.0  285.0   751.0
# 1065    112.0   872.5  368.0  1068.0
# 1136    281.0   881.0  748.0  1219.0
# ...       ...     ...    ...     ...
# 34122   216.0   323.0  588.0   683.0
# 34143    84.0   622.0  480.0   921.0
# 34284    45.0   673.0  724.0  1168.0
# 34340    53.0   678.0  436.0  1002.0
# 34455   141.0   355.0  443.0   672.0
# 34465   103.0   325.0  554.0   749.0
# 34471    52.0   747.0  616.0  1085.0
# 34483   205.0  1236.0  519.5  1606.5
# 34652   144.0   922.0  633.0  1499.0
# 34655   184.5  1324.0  270.5  1415.0
# 34796    55.5   440.0  163.5   520.0
# 34804    85.0   648.0  268.0   748.0
# 34958   324.5   246.5  614.5   511.5
# 35020    73.0   187.0  498.0   708.0
# 35021    42.0   439.0  120.0   494.0
# 35110   182.5  1024.0  500.0  1689.0
# 35118    71.0   733.5  495.0   899.5
# 35128    29.0   469.0  105.0   510.0
# 35227    32.0   859.0  684.0  1094.0
# 35307    22.0   321.0  223.0   604.0
# 35512    36.0   939.0  176.0  1105.0
# 35514    30.0   466.0  104.0   511.0
# 35544    33.0   596.0  380.0   787.0
# 35660   101.0   265.0  445.5   573.5
# 35682    54.0  1482.0   68.5  1491.0
# 35685   167.0   307.0  862.0   714.5
# 35695    76.0   477.0  425.0   806.0
# 35966    57.0   609.0  948.0  1242.0
# 35973    90.0   915.0  127.0   976.0
# 35978    63.0   736.0  418.0   870.0
#
# [630 rows x 4 columns]

# %%
sub.to_csv(
    f"../processed/sub_{time.strftime('%Y-%m-%d_%H-%M')}.csv",
    header=False
)
